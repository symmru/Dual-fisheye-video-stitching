# %%
import numpy as np
import cv2
import sys
import time
def GaussianPyramid(img, leveln):
    GP = [img]
    for i in range(leveln - 1):
        GP.append(cv2.pyrDown(GP[i]))
    return GP


def LaplacianPyramid(img, leveln):
    LP = []
    for i in range(leveln - 1):
        next_img = cv2.pyrDown(img)
        LP.append(img - cv2.pyrUp(next_img, img.shape[1::-1]))
        img = next_img
    LP.append(img)
    return LP


def blend_pyramid(LPA, LPB, MP):
    blended = []
    for i, M in enumerate(MP):
        blended.append(LPA[i] * M + LPB[i] * (1.0 - M))
    return blended


def reconstruct(LS):
    img = LS[-1]
    for lev_img in LS[-2::-1]:
        img = cv2.pyrUp(img, lev_img.shape[1::-1])
        img += lev_img
    return img

'''
def multi_band_blending(img1, img2, mask, leveln=6):
    max_leveln = int(np.floor(np.log2(min(img1.shape[0], img1.shape[1],
                                          img2.shape[0], img2.shape[1]))))
    if leveln is None:
        leveln = max_leveln
    if leveln < 1 or leveln > max_leveln:
        print ("warning: inappropriate number of leveln")
        leveln = max_leveln
    print(leveln)
    # Get Gaussian pyramid and Laplacian pyramid
    e1 = cv2.getTickCount()
    MP = GaussianPyramid(mask, leveln)
    e2 = cv2.getTickCount()
    print((e2 - e1)/cv2.getTickFrequency()*1000)
    s_LPA = time.time()
    LPA = LaplacianPyramid(img1.astype(np.float64), leveln)
    e_LPA = time.time()
    print(" Time for LPA is %.4f" %(e_LPA-s_LPA))
    s_LPB = time.time()
    LPB = LaplacianPyramid(img2.astype(np.float64), leveln)
    e_LPB = time.time()
    print(" Time for LPB is %.4f" %(e_LPB-s_LPB))
    # Blend two Laplacian pyramidspass
    s_B = time.time()
    blended = blend_pyramid(LPA, LPB, MP)
    e_B = time.time()
    print(" Time for blend_pyramid is %.4f" %(e_B-s_B))
    # Reconstruction process
    s_R = time.time()
    result = reconstruct(blended)
    e_R = time.time()
    print(" Time for reconstruct is %.4f" %(e_R-s_R))
    result[result > 255] = 255
    result[result < 0] = 0

    return result
'''
def multi_band_blending(img1, img2, mask, leveln=6):
    max_leveln = int(np.floor(np.log2(min(img1.shape[0], img1.shape[1],
                                          img2.shape[0], img2.shape[1]))))
    if leveln is None:
        leveln = max_leveln
    if leveln < 1 or leveln > max_leveln:
        print ("warning: inappropriate number of leveln")
        leveln = max_leveln

    # Get Gaussian pyramid and Laplacian pyramid
    MP = GaussianPyramid(mask, leveln)
    LPA = LaplacianPyramid(img1.astype(np.float64), leveln)
    LPB = LaplacianPyramid(img2.astype(np.float64), leveln)
    # Blend two Laplacian pyramidspass
    blended = blend_pyramid(LPA, LPB, MP)

    # Reconstruction process
    result = reconstruct(blended)
    result[result > 255] = 255
    result[result < 0] = 0

    return result

def imgLabeling(img1, img2, img3, img4, maskSize, xoffsetL, xoffsetR,
                minloc_old=None):
    if len(img1.shape) == 3:
        errL = np.sum(np.square(img1.astype(np.float64) -
                                img2.astype(np.float64)), axis=2)
        errR = np.sum(np.square(img3.astype(np.float64) -
                                img4.astype(np.float64)), axis=2)
    else:
        errL = np.square(img1.astype(np.float64) - img2.astype(np.float64))
        errR = np.square(img3.astype(np.float64) - img4.astype(np.float64))
    EL = np.zeros(errL.shape, np.float64)
    ER = np.zeros(errR.shape, np.float64)
    EL[0] = errL[0]
    ER[0] = errR[0]
    for i in range(1, maskSize[1]):
        EL[i, 0] = errL[i, 0] + min(EL[i - 1, 0], EL[i - 1, 1])
        ER[i, 0] = errR[i, 0] + min(ER[i - 1, 0], ER[i - 1, 1])
        for j in range(1, EL.shape[1] - 1):
            EL[i, j] = errL[i, j] + \
                min(EL[i - 1, j - 1], EL[i - 1, j], EL[i - 1, j + 1])
            ER[i, j] = errR[i, j] + \
                min(ER[i - 1, j - 1], ER[i - 1, j], ER[i - 1, j + 1])
        EL[i, -1] = errL[i, -1] + min(EL[i - 1, -1], EL[i - 1, -2])
        ER[i, -1] = errR[i, -1] + min(ER[i - 1, -1], ER[i - 1, -2])
    minlocL = np.argmin(EL, axis=1) + xoffsetL
    minlocR = np.argmin(ER, axis=1) + xoffsetR
    if minloc_old is None:
        minloc_old = [minlocL, minlocR, minlocL, minlocR]
    minlocL_fin = np.int32(0.4 * minlocL + 0.3 *
                           minloc_old[0] + 0.3 * minloc_old[2])
    minlocR_fin = np.int32(0.4 * minlocR + 0.3 *
                           minloc_old[1] + 0.3 * minloc_old[3])
    mask = np.ones((maskSize[1], maskSize[0], 3), np.float64)
    for i in range(maskSize[1]):
        mask[i, minlocL_fin[i]:minlocR_fin[i]] = 0
        mask[i, minlocL_fin[i]] = 0.5
        mask[i, minlocR_fin[i]] = 0.5
    #cv2.imshow('mask', mask.astype(np.float32))
    return mask, [minlocL, minlocR, minlocL_fin, minlocR_fin]

def verticalBoundary(M, W_remap, W, H):
    """Return vertical boundary of input image."""
    row = np.zeros((W_remap, 3, 1))
    row[:, 2] = 1
    row[:, 0] = np.arange(
        (W - W_remap) / 2, (W + W_remap) / 2).reshape((W_remap, 1))
    product = np.matmul(M, row).reshape((W_remap, 3))
    normed = np.array(list(zip(product[:, 0] / product[:, 2], product[:, 1] / product[:, 2])))
    # list(normed)
    top = np.max(
        normed[
            np.logical_and(
                normed[:, 0] >= W_remap / 2,
                normed[:, 0] < W - W_remap / 2)
                ][:, 1])

    row[:, 1] = H - 1
    product = np.matmul(M, row).reshape((W_remap, 3))
    normed = np.array(
        list(zip(product[:, 0] / product[:, 2], product[:, 1] / product[:, 2])))
    bottom = np.min(normed[np.logical_and(
        normed[:, 0] >= W_remap / 2, normed[:, 0] < W - W_remap / 2)][:, 1])

    return int(top) if top > 0 else 0, int(bottom) if bottom < H else H

def getMatches_templmatch(img1, img2, templ_shape, max):
    """Return pairs of corresponding points
    using brute force template matching."""
    if not np.array_equal(img1.shape, img2.shape):
        # print "error: inconsistent array dimention", img1.shape, img2.shape
        print(("error: inconsistent array dimention", img1.shape, img2.shape))
        sys.exit()
    if not (np.all(templ_shape <= img1.shape[:2]) and
            np.all(templ_shape <= img2.shape[:2])):
        print ("error: template shape shall fit img1 and img2")
        sys.exit()

    Hs, Ws = img1.shape[:2]
    Ht, Wt = templ_shape
    matches = []
    for yt in range(0, Hs - Ht + 1, 64):
        for xt in range(0, Ws - Wt + 1, 2):
            result = cv2.matchTemplate(
                img1, img2[yt:yt + Ht, xt:xt + Wt], cv2.TM_CCORR_NORMED)
            minVal, maxVal, minLoc, maxLoc = cv2.minMaxLoc(result)
            if maxVal > 0.9:
                matches.append((maxVal, maxLoc, (xt, yt)))
    matches.sort(key=lambda e: e[0], reverse=True)
    if len(matches) >= max:
        return np.int32([matches[i][1:] for i in range(max)])
    else:
        return np.int32([c[1:] for c in matches])


def getMatches_goodtemplmatch(img1, img2, templ_shape, max):
    """Return pairs of corresponding points
    using combining Shi-Tomasi corner detector and template matching."""
    if not np.array_equal(img1.shape, img2.shape):
        print(("error: inconsistent array dimention", img1.shape, img2.shape))
        sys.exit()
    if not (np.all(templ_shape <= img1.shape[:2]) and
            np.all(templ_shape <= img2.shape[:2])):
        print ("error: template shape shall fit img1 and img2")
        sys.exit()

    feature_params = dict(maxCorners=max, qualityLevel=0.01,
                          minDistance=5, blockSize=5)
    kps1 = cv2.goodFeaturesToTrack(img1, mask=None, **feature_params)
    kps2 = cv2.goodFeaturesToTrack(img2, mask=None, **feature_params)

    Hs, Ws = img1.shape[:2]
    Ht, Wt = templ_shape
    matches = []
    for [[xt, yt]] in kps1:
        if int(yt) + Ht > Hs or int(xt) + Wt > Ws:
            continue
        result = cv2.matchTemplate(
            img2, img1[int(yt):int(yt) + Ht, int(xt):int(xt) + Wt],
            cv2.TM_CCORR_NORMED)
        minVal, maxVal, minLoc, maxLoc = cv2.minMaxLoc(result)
        if maxVal > 0.9:
            matches.append((maxVal, (int(xt), int(yt)), maxLoc))
    for [[xt, yt]] in kps2:
        if int(yt) + Ht > Hs or int(xt) + Wt > Ws:
            continue
        result = cv2.matchTemplate(
            img1, img2[int(yt):int(yt) + Ht, int(xt):int(xt) + Wt],
            cv2.TM_CCORR_NORMED)
        minVal, maxVal, minLoc, maxLoc = cv2.minMaxLoc(result)
        if maxVal > 0.9:
            matches.append((maxVal, maxLoc, (int(xt), int(yt))))
    matches.sort(key=lambda e: e[0], reverse=True)
    if len(matches) >= max:
        return np.int32([matches[i][1:] for i in range(max)])
    else:
        return np.int32([c[1:] for c in matches])
def equirect_proj(x_proj, y_proj, W, H, fov):
    """Return the equirectangular projection on a unit sphere,
    given cartesian coordinates of the de-warped image."""
    theta_alt = x_proj * fov / W
    phi_alt = y_proj * np.pi / H

    x = np.sin(theta_alt) * np.cos(phi_alt)
    y = np.sin(phi_alt)
    z = np.cos(theta_alt) * np.cos(phi_alt)

    return np.arctan2(y, x), np.arctan2(np.sqrt(x**2 + y**2), z)


def buildmap(Ws, Hs, Wd, Hd, fov):
    """Return a mapping from de-warped images to fisheye images."""
    fov = fov * np.pi / 180.0

    # cartesian coordinates of the de-warped rectangular image
    ys, xs = np.indices((Hs, Ws), np.float32)
    y_proj = Hs / 2.0 - ys
    x_proj = xs - Ws / 2.0

    # spherical coordinates
    theta, phi = equirect_proj(x_proj, y_proj, Ws, Hs, fov)

    # polar coordinates (of the fisheye image)
    p = Hd * phi / fov

    # cartesian coordinates of the fisheye image
    y_fish = p * np.sin(theta)
    x_fish = p * np.cos(theta)

    ymap = Hd / 2.0 - y_fish
    xmap = Wd / 2.0 + x_fish
    return xmap, ymap, p
def Hcalc(cap, xmap, ymap):
    """Calculate and return homography for stitching process."""
    Mlist = []
    frame_count = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    for frame_no in np.arange(0, frame_count, int(frame_count / 10)):
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_no)
        ret, frame = cap.read()
        if ret:
            # defish / unwarp
            cam1 = cv2.remap(frame[:, :1280], xmap, ymap, cv2.INTER_LINEAR)
            cam2 = cv2.remap(frame[:, 1280:], xmap, ymap, cv2.INTER_LINEAR)
            cam1_gray = cv2.cvtColor(cam1, cv2.COLOR_BGR2GRAY)
            cam2_gray = cv2.cvtColor(cam2, cv2.COLOR_BGR2GRAY)

            # shift the remapped images along x-axis
            shifted_cams = np.zeros((H * 2, W, 3), np.uint8)
            shifted_cams[H:, int((W - W_remap) / 2):int((W + W_remap) / 2)] = cam2
            shifted_cams[:H, :int(W_remap / 2)] = cam1[:, int(W_remap / 2):]
            shifted_cams[:H, W - int(W_remap / 2):] = cam1[:, :int(W_remap / 2)]

            # find matches and extract pairs of correspondent matching points
            matchesL = getMatches_goodtemplmatch(
                cam1_gray[offsetYL:H - offsetYL, int(W / 2):],
                cam2_gray[offsetYL:H - offsetYL, :W_remap - int(W / 2)],
                templ_shape, maxL)
            matchesR = getMatches_goodtemplmatch(
                cam2_gray[offsetYR:H - offsetYR, int(W / 2):],
                cam1_gray[offsetYR:H - offsetYR, :W_remap - int(W / 2)],
                templ_shape, maxR)
            matchesR = matchesR[:, -1::-1]

            matchesL = matchesL + (int((W - W_remap) / 2), offsetYL)
            matchesR = matchesR + (int((W - W_remap) / 2) + int(W / 2), offsetYR)
            zipped_matches = list(zip(matchesL, matchesR))
            matches = np.int32([e for i in zipped_matches for e in i])
            pts1 = matches[:, 0]
            pts2 = matches[:, 1]

            # find homography from pairs of correspondent matchings
            M, status = cv2.findHomography(pts2, pts1, cv2.RANSAC, 5.0)
            Mlist.append(M)
    M = np.average(np.array(Mlist), axis=0)
    print (M)
    #cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
    return M
def deduplication(inliers):
    pts_1, indexes_1 = np.unique(inliers[:,1], return_index = True, axis=0)
    label,indexes_2 = np.unique(inliers[:,0][indexes_1], return_index = True, axis=0)
    train = pts_1[indexes_2]
    return train, label

# %%
import torch
import torch.optim as optim
from torch import nn
import torch.utils.data as Data

cap1=cv2.VideoCapture('C:/Users/Jackie/Downloads/0129_1.MP4')
cap2=cv2.VideoCapture('C:/Users/Jackie/Downloads/0129_2.MP4')
count=cap1.get(cv2.CAP_PROP_FRAME_COUNT)
fps=cap1.get(cv2.CAP_PROP_FPS)
size=(int(cap1.get(cv2.CAP_PROP_FRAME_WIDTH)*2),int(cap1.get(cv2.CAP_PROP_FRAME_HEIGHT)))
video=cv2.VideoWriter('C:/Users/Jackie/Downloads/129_improved_blending.MP4',cv2.VideoWriter_fourcc('I','4','2','0'),fps,size)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")



maxL = 200
maxR = 200

if cap1.isOpened() and cap2.isOpened():
    i=1
    print('successful')
    print("The count is %d" %(count))
    #image size paremeters
    
        
    ret1,frame1=cap1.read()
    ret2,frame2=cap2.read()
    H=frame1.shape[0]
    W_remap=int(194/180*H)
    W=frame1.shape[1]+frame2.shape[1]
    templ_shape = (60, 16)
    offsetYL = int(160/1280*H)
    offsetYR = int(160/1280*H)
    #print(W_remap)
    #remap
    xmap, ymap, p = buildmap(Ws=W_remap, Hs=H, Wd=H, Hd=H, fov=194)
    #cam2 = cv2.remap(frame[:, :H], xmap, ymap, cv2.INTER_LINEAR)
    #cam1 = cv2.remap(frame[:, H:], xmap, ymap, cv2.INTER_LINEAR)
    cam1 = cv2.remap(frame1, xmap, ymap, cv2.INTER_LINEAR)
    cam2 = cv2.remap(frame2, xmap, ymap, cv2.INTER_LINEAR)
    
    #shift
    cam1_gray = cv2.cvtColor(cam1, cv2.COLOR_BGR2GRAY)
    cam2_gray = cv2.cvtColor(cam2, cv2.COLOR_BGR2GRAY)
    shifted_cams = np.zeros((H * 2, W, 3), np.uint8)
    shifted_cams[H:, int((W - W_remap) / 2):int((W + W_remap) / 2)] = cam1
    shifted_cams[:H, :int(W_remap / 2)] = cam2[:, int(W_remap / 2):]
    shifted_cams[:H, W - int(W_remap / 2):] = cam2[:, :int(W_remap / 2)]
    
    #cv2.imwrite('video_shift.jpg', shifted_cams)
    #matching
    
    maxL = 200
    maxR = 200
    b_matching=time.time()
    matchesL = getMatches_goodtemplmatch(
                    cam1_gray[offsetYL:H - offsetYL, int(W / 2):],
                    cam2_gray[offsetYL:H - offsetYL, :W_remap - int(W / 2)],
                    templ_shape, maxL)
    matchesR = getMatches_goodtemplmatch(
                    cam2_gray[offsetYR:H - offsetYR, int(W / 2):],
                    cam1_gray[offsetYR:H - offsetYR, :W_remap - int(W / 2)],
                    templ_shape, maxR)
    matchesR = matchesR[:, -1::-1]
    matchesL = matchesL + (int((W - W_remap) / 2), offsetYL)
    matchesR = matchesR + (int((W - W_remap) / 2) + int(W / 2), offsetYR)
    zipped_matches = list(zip(matchesL, matchesR))
    matches = np.int32([e for i in zipped_matches for e in i])
    pts1 = matches[:, 0]
    pts2 = matches[:, 1]
    
    #homography
    M_current, status = cv2.findHomography(pts2, pts1, cv2.RANSAC, 4.0)
    
    top, bottom = verticalBoundary(M_current, W_remap, W, H)
    warped2 = cv2.warpPerspective(shifted_cams[H:], M_current, (W, H))
    warped1 = shifted_cams[0:H,:]
    warped1 = cv2.resize(warped1[top:bottom], (W, H))
    warped2 = cv2.resize(warped2[top:bottom], (W, H))
    EAof2 = np.zeros((H, W, 3), np.uint8)
    EAof2[:, int((W - W_remap) / 2) + 1:int((W + W_remap) / 2) - 1] = 255
    EAof2 = cv2.warpPerspective(EAof2, M_current, (W, H))
    
    #blend
    b_blend=time.time()
    W_lbl = 120
    blend_level = 4
    
    mask, minloc_old = imgLabeling(
                warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                (W, H), int(W_remap / 2) - W_lbl, W - int(W_remap / 2))
    
    warped1[:, int(W_remap / 2):W - int(W_remap /
                2)] = warped2[:, int(W_remap / 2):W - int(W_remap / 2)]
    warped2[EAof2 == 0] = warped1[EAof2 == 0]
    '''
    blended = multi_band_blending(
                    warped1, warped2, mask, blend_level)
    '''
    blended_l = multi_band_blending(
                    warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    mask[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    blend_level)
    blended_r = multi_band_blending(
                    warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    mask[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    blend_level)
    blended = np.ones((H,W,3))
    blended[:, 0:int(W_remap / 2) - W_lbl] = warped1[:, 0:int(W_remap / 2) - W_lbl]
    blended[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)] = blended_l
    blended[:,int(W_remap / 2):W - int(W_remap / 2)] = warped2[:,int(W_remap / 2):W - int(W_remap / 2)]
    blended[:,W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl] = blended_r
    blended[:,W - int(W_remap / 2) + W_lbl:] = warped1[:,W - int(W_remap / 2) + W_lbl:]
    e_blend=time.time()
    #print("Time for blending is %.4f" %(e_blend-b_blend))
    video.write(blended.astype(np.uint8))
    #cv2.imwrite('video_blending.jpg', blended.astype(np.uint8))
    #FCN
    epochs=40
    index=np.where(status.ravel()==1)
    inliers=matches[index[0]]
    train,label = deduplication(inliers)
    zipped_train = list(zip(train, label))
    dataset = np.int32([e for e in zipped_train])
    np.random.shuffle(dataset)
    train = dataset[:, 0]
    label = dataset[:, 1]
    b_test = np.ones(int(train[int(train.shape[0]*0.8):].shape[0]))
    test = np.insert(train[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
    label_test = np.insert(label[int(train.shape[0]*0.8):], 2, values=b_test, axis=1)
    M = torch.tensor(M_current,requires_grad=True)
    #M_best = torch.tensor(M_best,requires_grad=True)
    model = nn.Linear(3,3,bias=False)
    model.weight =nn.Parameter(M)
    criterion = nn.MSELoss()
    test = torch.tensor(test,requires_grad=False,dtype=torch.float64)
    label_test = torch.tensor(label_test,requires_grad=False,dtype=torch.float64)
    
    test_output = model(test)
    test_output = test_output/test_output[:,2].reshape(-1,1)
    best_loss = criterion(test_output,label_test)/label_test.shape[0]
    
    print("The loss for frame1 is %.4f" %(best_loss))
    #print("The loss of M_best for frame1 is %.4f" %(loss_test_b))
    shape_list = []
    shape_list.append(inliers.shape[0])
    #M_best = M_best.to(device)
    while i<count:
        i+=1
        ret1,frame1=cap1.read()
        ret2,frame2=cap2.read()
        
        if ret1 and ret2:
            
            cam1 = cv2.remap(frame1, xmap, ymap, cv2.INTER_LINEAR)
            cam2 = cv2.remap(frame2, xmap, ymap, cv2.INTER_LINEAR)
            
            #shift
                
            shifted_cams = np.zeros((H * 2, W, 3), np.uint8)
            shifted_cams[H:, int((W - W_remap) / 2):int((W + W_remap) / 2)] = cam1
            shifted_cams[:H, :int(W_remap / 2)] = cam2[:, int(W_remap / 2):]
            shifted_cams[:H, W - int(W_remap / 2):] = cam2[:, :int(W_remap / 2)]
            if len(shape_list)%4==0:
                inliers = np.delete(inliers, range(0,shape_list[0]),axis = 0)
                del(shape_list[0])
             
            if i%60==0:
                cam1_gray = cv2.cvtColor(cam1, cv2.COLOR_BGR2GRAY)
                cam2_gray = cv2.cvtColor(cam2, cv2.COLOR_BGR2GRAY)
                b_matching=time.time()
                matchesL = getMatches_goodtemplmatch(
                    cam1_gray[offsetYL:H - offsetYL, int(W / 2):],
                    cam2_gray[offsetYL:H - offsetYL, :W_remap - int(W / 2)],
                    templ_shape, maxL)
                matchesR = getMatches_goodtemplmatch(
                    cam2_gray[offsetYR:H - offsetYR, int(W / 2):],
                    cam1_gray[offsetYR:H - offsetYR, :W_remap - int(W / 2)],
                    templ_shape, maxR)
                matchesR = matchesR[:, -1::-1]
                matchesL = matchesL + (int((W - W_remap) / 2), offsetYL)
                matchesR = matchesR + (int((W - W_remap) / 2) + int(W / 2), offsetYR)
                zipped_matches = list(zip(matchesL, matchesR))
                matches_append = np.int32([e for i in zipped_matches for e in i])
                pts1 = matches_append[:, 0]
                pts2 = matches_append[:, 1]
                
                
                e_matching=time.time()
                print("Time for matching is %.4f, round is %d" %((e_matching-b_matching),i) )
                M_, status = cv2.findHomography(pts2, pts1, cv2.RANSAC, 4.0)
                index=np.where(status.ravel()==1)
      
                inliers = np.concatenate((inliers,matches_append[index[0]]),axis=0)
                shape_list.append(matches_append[index[0]].shape[0])
                
        
                train,label = deduplication(inliers)
                zipped_train = list(zip(train, label))
                dataset = np.int32([e for e in zipped_train])
                np.random.shuffle(dataset)
                train = dataset[:, 0]
                label = dataset[:, 1]
                
                b_test = np.ones(int(train[int(train.shape[0]*0.8):].shape[0]))
                test = np.insert(train[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
                label_test = np.insert(label[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
                b=np.ones(int(train.shape[0]*0.8))
                train = np.insert(train[:int(train.shape[0]*0.8)], 2, values=b, axis=1) 
                label = np.insert(label[:int(label.shape[0]*0.8)], 2, values=b, axis=1) 
                
                M = torch.tensor(M_current,requires_grad=True)
                model = nn.Linear(3,3,bias=False)
                model.weight =nn.Parameter(M)
                model.to(device)
                criterion = nn.MSELoss()
                optimizer = torch.optim.Adam(model.parameters(), lr=0.000001)
                #optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
    
                #M = torch.tensor(M,requires_grad=True)
                inputs = torch.tensor(train,requires_grad=False,dtype=torch.float64)
                inputs = inputs.to(device)
                label_t = torch.tensor(label,requires_grad=False,dtype=torch.float64)
                label_t = label_t.to(device)
                test = torch.tensor(test,requires_grad=False,dtype=torch.float64)
                test = test.to(device)
                label_test = torch.tensor(label_test,requires_grad=False,dtype=torch.float64)
                label_test = label_test.to(device)
                torch_dataset = Data.TensorDataset(inputs, label_t)

                loader = Data.DataLoader(
                                dataset=torch_dataset,      
                                batch_size=64,      
                                shuffle=True,               
                                num_workers=0,)
                total_step = len(loader)
                t_s = time.time()
                for epoch in range(epochs):
                    for step, (batch_x, l) in enumerate(loader):
                        #batch_x, l = batch_x.to(device),l.to(device)
                        outputs = model(batch_x)
                        outputs = outputs/outputs[:,2].reshape(-1,1)
                        loss = criterion(outputs,l)
                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()
                        print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch+1, epochs, step+1, total_step, loss.item()/len(batch_x)))
                t_e = time.time()
                print(" Time for training is %.4f ms" %((t_e-t_s)*1000))
                test_output = model(test)
                test_output = test_output/test_output[:,2].reshape(-1,1)
                loss_test = criterion(test_output,label_test)/label_test.shape[0]
                
                M_c = torch.tensor(M_current,requires_grad=True)
                model_c = nn.Linear(3,3,bias=False)
                model_c.weight =nn.Parameter(M_c)
                model_c.to(device)
                current_test = model_c(test)
                current_test = current_test/current_test[:,2].reshape(-1,1)
                current_loss = criterion(current_test,label_test)/label_test.shape[0]
                
                print("The loss of M_trained is %.4f, round %d" %(loss_test,i))
                print("The loss of M_current is %.4f, round %d" %(current_loss,i))
                print(model.weight)
                
                if loss_test<current_loss:
                    model = model.cpu()
                    M_current = model.weight.detach().numpy()
                    M_current = M_current/M_current[2][2]
                    best_loss = loss_test
                    print("The best loss is %.4f" %(best_loss))
            
            top, bottom = verticalBoundary(M_current, W_remap, W, H)
            warped2 = cv2.warpPerspective(shifted_cams[H:], M_current, (W, H))
            warped1 = shifted_cams[0:H,:]
            warped1 = cv2.resize(warped1[top:bottom], (W, H))
            warped2 = cv2.resize(warped2[top:bottom], (W, H))
            EAof2 = np.zeros((H, W, 3), np.uint8)
            EAof2[:, int((W - W_remap) / 2) + 1:int((W + W_remap) / 2) - 1] = 255
            EAof2 = cv2.warpPerspective(EAof2, M_current, (W, H))
            b_blend=time.time()
            
            if i%120==0:
                mask, minloc_old = imgLabeling(
                warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                (W, H), int(W_remap / 2) - W_lbl, W - int(W_remap / 2))
            
            
            
            warped1[:, int(W_remap / 2):W - int(W_remap /
                        2)] = warped2[:, int(W_remap / 2):W - int(W_remap / 2)]
            warped2[EAof2 == 0] = warped1[EAof2 == 0]
            '''
            blended = multi_band_blending(
                                warped1, warped2, mask, blend_level)
            '''
            #blended = warped1 * mask + warped2 * (1 - mask)
            blended_l = multi_band_blending(
                    warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    mask[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    blend_level)
            blended_r = multi_band_blending(
                    warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    mask[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    blend_level)
            blended = np.ones((H,W,3))
            blended[:, 0:int(W_remap / 2) - W_lbl] = warped1[:, 0:int(W_remap / 2) - W_lbl]
            blended[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)] = blended_l
            blended[:,int(W_remap / 2):W - int(W_remap / 2)] = warped2[:,int(W_remap / 2):W - int(W_remap / 2)]
            blended[:,W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl] = blended_r
            blended[:,W - int(W_remap / 2) + W_lbl:] = warped1[:,W - int(W_remap / 2) + W_lbl:]
            video.write(blended.astype(np.uint8))
            e_blend=time.time()
            print(" Time for blending is %.4f, round is %d" %((e_blend-b_blend),i) )
      
        else:   
            break
    
else:
    print('fail')
cap1.release()
cap2.release()
video.release()
# Out:
# successful
# The count is 985
# The loss for frame1 is 0.0463
#  Time for blending is 0.1985, round is 2
#  Time for blending is 0.2043, round is 3
#  Time for blending is 0.1820, round is 4
#  Time for blending is 0.1827, round is 5
#  Time for blending is 0.1805, round is 6
#  Time for blending is 0.1823, round is 7
#  Time for blending is 0.2073, round is 8
#  Time for blending is 0.2007, round is 9
#  Time for blending is 0.2314, round is 10
#  Time for blending is 0.2347, round is 11
#  Time for blending is 0.2268, round is 12
#  Time for blending is 0.2177, round is 13
#  Time for blending is 0.2349, round is 14
#  Time for blending is 0.2073, round is 15
#  Time for blending is 0.2229, round is 16
#  Time for blending is 0.2055, round is 17
#  Time for blending is 0.2408, round is 18
#  Time for blending is 0.2587, round is 19
#  Time for blending is 0.2827, round is 20
#  Time for blending is 0.1785, round is 21
#  Time for blending is 0.2197, round is 22
#  Time for blending is 0.2241, round is 23
#  Time for blending is 0.1777, round is 24
#  Time for blending is 0.1896, round is 25
#  Time for blending is 0.2209, round is 26
#  Time for blending is 0.1918, round is 27
#  Time for blending is 0.2075, round is 28
#  Time for blending is 0.2026, round is 29
#  Time for blending is 0.2075, round is 30
#  Time for blending is 0.1925, round is 31
#  Time for blending is 0.1870, round is 32
#  Time for blending is 0.1912, round is 33
#  Time for blending is 0.1876, round is 34
#  Time for blending is 0.1897, round is 35
#  Time for blending is 0.1888, round is 36
#  Time for blending is 0.1927, round is 37
#  Time for blending is 0.1905, round is 38
#  Time for blending is 0.1884, round is 39
#  Time for blending is 0.1900, round is 40
#  Time for blending is 0.1907, round is 41
#  Time for blending is 0.1895, round is 42
#  Time for blending is 0.1898, round is 43
#  Time for blending is 0.1915, round is 44
#  Time for blending is 0.2041, round is 45
#  Time for blending is 0.1891, round is 46
#  Time for blending is 0.2095, round is 47
#  Time for blending is 0.2019, round is 48
#  Time for blending is 0.1923, round is 49
#  Time for blending is 0.2057, round is 50
#  Time for blending is 0.2041, round is 51
#  Time for blending is 0.1771, round is 52
#  Time for blending is 0.2043, round is 53
#  Time for blending is 0.1902, round is 54
#  Time for blending is 0.2056, round is 55
#  Time for blending is 0.1909, round is 56
#  Time for blending is 0.2044, round is 57
#  Time for blending is 0.1903, round is 58
#  Time for blending is 0.2056, round is 59
# Time for matching is 1.5053, round is 60
# Epoch [1/40], Step [1/4], Loss: 0.0255
# Epoch [1/40], Step [2/4], Loss: 0.4448
# Epoch [1/40], Step [3/4], Loss: 0.0629
# Epoch [1/40], Step [4/4], Loss: 0.1408
# Epoch [2/40], Step [1/4], Loss: 0.2990
# Epoch [2/40], Step [2/4], Loss: 0.2287
# Epoch [2/40], Step [3/4], Loss: 0.0599
# Epoch [2/40], Step [4/4], Loss: 0.0392
# Epoch [3/40], Step [1/4], Loss: 0.0761
# Epoch [3/40], Step [2/4], Loss: 0.1306
# Epoch [3/40], Step [3/4], Loss: 0.1444
# Epoch [3/40], Step [4/4], Loss: 0.1073
# Epoch [4/40], Step [1/4], Loss: 0.0411
# Epoch [4/40], Step [2/4], Loss: 0.0288
# Epoch [4/40], Step [3/4], Loss: 0.0445
# Epoch [4/40], Step [4/4], Loss: 0.0937
# Epoch [5/40], Step [1/4], Loss: 0.0722
# Epoch [5/40], Step [2/4], Loss: 0.0664
# Epoch [5/40], Step [3/4], Loss: 0.0341
# Epoch [5/40], Step [4/4], Loss: 0.0315
# Epoch [34/40], Step [3/4], Loss: 0.0225
# Epoch [34/40], Step [4/4], Loss: 0.0421
# Epoch [35/40], Step [1/4], Loss: 0.0222
# Epoch [35/40], Step [2/4], Loss: 0.0284
# Epoch [35/40], Step [3/4], Loss: 0.0293
# Epoch [35/40], Step [4/4], Loss: 0.0282
# Epoch [36/40], Step [1/4], Loss: 0.0294
# Epoch [36/40], Step [2/4], Loss: 0.0245
# Epoch [36/40], Step [3/4], Loss: 0.0236
# Epoch [36/40], Step [4/4], Loss: 0.0319
# Epoch [37/40], Step [1/4], Loss: 0.0218
# Epoch [37/40], Step [2/4], Loss: 0.0347
# Epoch [37/40], Step [3/4], Loss: 0.0233
# Epoch [37/40], Step [4/4], Loss: 0.0275
# Epoch [38/40], Step [1/4], Loss: 0.0218
# Epoch [38/40], Step [2/4], Loss: 0.0277
# Epoch [38/40], Step [3/4], Loss: 0.0267
# Epoch [38/40], Step [4/4], Loss: 0.0331
# Epoch [39/40], Step [1/4], Loss: 0.0304
# Epoch [39/40], Step [2/4], Loss: 0.0285
# Epoch [39/40], Step [3/4], Loss: 0.0216
# Epoch [39/40], Step [4/4], Loss: 0.0281
# Epoch [40/40], Step [1/4], Loss: 0.0274
# Epoch [40/40], Step [2/4], Loss: 0.0243
# Epoch [40/40], Step [3/4], Loss: 0.0232
# Epoch [40/40], Step [4/4], Loss: 0.0376
#  Time for training is 1642.3762 ms
# The loss of M_trained is 0.0280, round 60
# The loss of M_current is 0.0281, round 60
# Parameter containing:
# tensor([[ 1.0745e+00,  5.0273e-02, -1.4992e+02],
#         [-6.3069e-03,  1.0539e+00, -1.3710e+01],
#         [-1.2457e-06,  2.7467e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.0280
#  Time for blending is 0.2193, round is 60
#  Time for blending is 0.2002, round is 61
#  Time for blending is 0.2227, round is 62
#  Time for blending is 0.2031, round is 63
#  Time for blending is 0.2079, round is 64
#  Time for blending is 0.2277, round is 65
#  Time for blending is 0.1919, round is 66
#  Time for blending is 0.1749, round is 67
#  Time for blending is 0.1875, round is 68
#  Time for blending is 0.1897, round is 69
#  Time for blending is 0.1738, round is 70
#  Time for blending is 0.1896, round is 71
#  Time for blending is 0.1879, round is 72
#  Time for blending is 0.1899, round is 73
#  Time for blending is 0.1861, round is 74
#  Time for blending is 0.1733, round is 75
#  Time for blending is 0.1761, round is 76
#  Time for blending is 0.1869, round is 77
#  Time for blending is 0.1844, round is 78
#  Time for blending is 0.1727, round is 79
#  Time for blending is 0.1885, round is 80
#  Time for blending is 0.1898, round is 81
#  Time for blending is 0.1748, round is 82
#  Time for blending is 0.1875, round is 83
#  Time for blending is 0.1729, round is 84
#  Time for blending is 0.2056, round is 85
#  Time for blending is 0.1911, round is 86
#  Time for blending is 0.1748, round is 87
#  Time for blending is 0.1890, round is 88
#  Time for blending is 0.1745, round is 89
#  Time for blending is 0.1728, round is 90
#  Time for blending is 0.1735, round is 91
#  Time for blending is 0.2065, round is 92
#  Time for blending is 0.2039, round is 93
#  Time for blending is 0.1929, round is 94
#  Time for blending is 0.1887, round is 95
#  Time for blending is 0.1888, round is 96
#  Time for blending is 0.1870, round is 97
#  Time for blending is 0.2083, round is 98
#  Time for blending is 0.1907, round is 99
#  Time for blending is 0.1875, round is 100
#  Time for blending is 0.1906, round is 101
#  Time for blending is 0.1921, round is 102
#  Time for blending is 0.1866, round is 103
#  Time for blending is 0.2074, round is 104
#  Time for blending is 0.1903, round is 105
#  Time for blending is 0.1901, round is 106
#  Time for blending is 0.1881, round is 107
#  Time for blending is 0.2072, round is 108
#  Time for blending is 0.2051, round is 109
#  Time for blending is 0.1911, round is 110
#  Time for blending is 0.1904, round is 111
#  Time for blending is 0.2035, round is 112
#  Time for blending is 0.1918, round is 113
#  Time for blending is 0.2130, round is 114
#  Time for blending is 0.1907, round is 115
#  Time for blending is 0.2057, round is 116
#  Time for blending is 0.2218, round is 117
#  Time for blending is 0.2287, round is 118
#  Time for blending is 0.2364, round is 119
# Time for matching is 1.4592, round is 120
# Epoch [1/40], Step [1/5], Loss: 0.0274
# Epoch [1/40], Step [2/5], Loss: 0.3528
# Epoch [1/40], Step [3/5], Loss: 0.0676
# Epoch [1/40], Step [4/5], Loss: 0.1130
# Epoch [1/40], Step [5/5], Loss: 0.1753
# Epoch [2/40], Step [1/5], Loss: 0.2230
# Epoch [2/40], Step [2/5], Loss: 0.0814
# Epoch [2/40], Step [3/5], Loss: 0.0349
# Epoch [2/40], Step [4/5], Loss: 0.0780
# Epoch [2/40], Step [5/5], Loss: 0.1577
# Epoch [3/40], Step [1/5], Loss: 0.1281
# Epoch [3/40], Step [2/5], Loss: 0.0366
# Epoch [3/40], Step [3/5], Loss: 0.0390
# Epoch [3/40], Step [4/5], Loss: 0.0506
# Epoch [3/40], Step [5/5], Loss: 0.0642
# Epoch [4/40], Step [1/5], Loss: 0.0722
# Epoch [4/40], Step [2/5], Loss: 0.0502
# Epoch [4/40], Step [3/5], Loss: 0.0469
# Epoch [4/40], Step [4/5], Loss: 0.0420
# Epoch [4/40], Step [5/5], Loss: 0.0387
# Epoch [5/40], Step [1/5], Loss: 0.0498
# Epoch [5/40], Step [2/5], Loss: 0.0443
# Epoch [5/40], Step [3/5], Loss: 0.0437
# Epoch [5/40], Step [4/5], Loss: 0.0266
# Epoch [5/40], Step [5/5], Loss: 0.0490
# Epoch [6/40], Step [1/5], Loss: 0.0431
# Epoch [6/40], Step [2/5], Loss: 0.0376
# Epoch [6/40], Step [3/5], Loss: 0.0419
# Epoch [6/40], Step [4/5], Loss: 0.0375
# Epoch [6/40], Step [5/5], Loss: 0.0437
# Epoch [7/40], Step [1/5], Loss: 0.0308
# Epoch [7/40], Step [2/5], Loss: 0.0312
# Epoch [7/40], Step [3/5], Loss: 0.0295
# Epoch [7/40], Step [4/5], Loss: 0.0503
# Epoch [7/40], Step [5/5], Loss: 0.0354
# Epoch [8/40], Step [1/5], Loss: 0.0309
# Epoch [8/40], Step [2/5], Loss: 0.0254
# Epoch [8/40], Step [3/5], Loss: 0.0371
# Epoch [8/40], Step [4/5], Loss: 0.0472
-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.0286
#  Time for blending is 0.5360, round is 120
#  Time for blending is 0.1761, round is 121
#  Time for blending is 0.1873, round is 122
#  Time for blending is 0.1896, round is 123
#  Time for blending is 0.1740, round is 124
#  Time for blending is 0.1739, round is 125
#  Time for blending is 0.1745, round is 126
#  Time for blending is 0.1875, round is 127
#  Time for blending is 0.1919, round is 128
#  Time for blending is 0.1908, round is 129
#  Time for blending is 0.1879, round is 130
#  Time for blending is 0.1755, round is 131
#  Time for blending is 0.1868, round is 132
#  Time for blending is 0.1896, round is 133
#  Time for blending is 0.1953, round is 134
#  Time for blending is 0.1879, round is 135
#  Time for blending is 0.2007, round is 136
#  Time for blending is 0.1920, round is 137
#  Time for blending is 0.1893, round is 138
#  Time for blending is 0.1982, round is 139
#  Time for blending is 0.1802, round is 140
#  Time for blending is 0.1841, round is 141
#  Time for blending is 0.1978, round is 142
#  Time for blending is 0.1754, round is 143
#  Time for blending is 0.1894, round is 144
#  Time for blending is 0.1881, round is 145
#  Time for blending is 0.1913, round is 146
#  Time for blending is 0.1878, round is 147
#  Time for blending is 0.2245, round is 148
#  Time for blending is 0.2081, round is 149
#  Time for blending is 0.1891, round is 150
#  Time for blending is 0.2055, round is 151
#  Time for blending is 0.2058, round is 152
#  Time for blending is 0.1911, round is 153
#  Time for blending is 0.2047, round is 154
#  Time for blending is 0.1898, round is 155
#  Time for blending is 0.2075, round is 156
#  Time for blending is 0.1891, round is 157
#  Time for blending is 0.2053, round is 158
#  Time for blending is 0.1909, round is 159
#  Time for blending is 0.1894, round is 160
#  Time for blending is 0.1742, round is 161
#  Time for blending is 0.2045, round is 162
#  Time for blending is 0.1909, round is 163
#  Time for blending is 0.1889, round is 164
#  Time for blending is 0.1942, round is 165
#  Time for blending is 0.1884, round is 166
#  Time for blending is 0.2078, round is 167
#  Time for blending is 0.2066, round is 168
#  Time for blending is 0.1719, round is 169
#  Time for blending is 0.2054, round is 170
#  Time for blending is 0.1736, round is 171
#  Time for blending is 0.2052, round is 172
#  Time for blending is 0.1898, round is 173
#  Time for blending is 0.1889, round is 174
#  Time for blending is 0.2083, round is 175
#  Time for blending is 0.1751, round is 176
#  Time for blending is 0.2035, round is 177
#  Time for blending is 0.1933, round is 178
#  Time for blending is 0.1881, round is 179
# Time for matching is 1.4703, round is 180
# Epoch [1/40], Step [1/6], Loss: 0.0324
# Epoch [1/40], Step [2/6], Loss: 0.4543
# Epoch [1/40], Step [3/6], Loss: 0.0585
# Epoch [1/40], Step [4/6], Loss: 0.1013
# Epoch [1/40], Step [5/6], Loss: 0.2907
# Epoch [1/40], Step [6/6], Loss: 0.3873
# Epoch [2/40], Step [1/6], Loss: 0.1863
# Epoch [2/40], Step [2/6], Loss: 0.0523
# Epoch [2/40], Step [3/6], Loss: 0.0449
# Epoch [2/40], Step [4/6], Loss: 0.1389
# Epoch [2/40], Step [5/6], Loss: 0.1995
# Epoch [2/40], Step [6/6], Loss: 0.2040
# Epoch [3/40], Step [1/6], Loss: 0.1064
# Epoch [3/40], Step [2/6], Loss: 0.0509
# Epoch [3/40], Step [3/6], Loss: 0.0339
# Epoch [3/40], Step [4/6], Loss: 0.0759
# Epoch [3/40], Step [5/6], Loss: 0.0977
# Epoch [3/40], Step [6/6], Loss: 0.1484
# Epoch [4/40], Step [1/6], Loss: 0.1023
# Epoch [34/40], Step [6/6], Loss: 0.7778
# Epoch [35/40], Step [1/6], Loss: 0.2785
# Epoch [35/40], Step [2/6], Loss: 0.2452
# Epoch [35/40], Step [3/6], Loss: 0.2052
# Epoch [35/40], Step [4/6], Loss: 0.2238
# Epoch [35/40], Step [5/6], Loss: 0.2356
# Epoch [35/40], Step [6/6], Loss: 1.1229
# Epoch [36/40], Step [1/6], Loss: 0.3351
# Epoch [36/40], Step [2/6], Loss: 0.2386
# Epoch [36/40], Step [3/6], Loss: 0.1350
# Epoch [36/40], Step [4/6], Loss: 0.2533
# Epoch [36/40], Step [5/6], Loss: 0.2395
# Epoch [36/40], Step [6/6], Loss: 0.8621
# Epoch [37/40], Step [1/6], Loss: 0.2596
# Epoch [37/40], Step [2/6], Loss: 0.1831
# Epoch [37/40], Step [3/6], Loss: 0.2464
# Epoch [37/40], Step [4/6], Loss: 0.2272
# Epoch [37/40], Step [5/6], Loss: 0.2441
# Epoch [37/40], Step [6/6], Loss: 1.4165
# Epoch [38/40], Step [1/6], Loss: 0.2784
# Epoch [38/40], Step [2/6], Loss: 0.2265
# Epoch [38/40], Step [3/6], Loss: 0.2476
# Epoch [38/40], Step [4/6], Loss: 0.2540
# Epoch [38/40], Step [5/6], Loss: 0.2360
# Epoch [38/40], Step [6/6], Loss: 0.5018
# Epoch [39/40], Step [1/6], Loss: 0.2457
# Epoch [39/40], Step [2/6], Loss: 0.2218
# Epoch [39/40], Step [3/6], Loss: 0.2248
# Epoch [39/40], Step [4/6], Loss: 0.2748
# Epoch [39/40], Step [5/6], Loss: 0.2343
# Epoch [39/40], Step [6/6], Loss: 0.9276
# Epoch [40/40], Step [1/6], Loss: 0.1791
# Epoch [40/40], Step [2/6], Loss: 0.2247
# Epoch [40/40], Step [3/6], Loss: 0.2420
# Epoch [40/40], Step [4/6], Loss: 0.2792
# Epoch [40/40], Step [5/6], Loss: 0.2778
# Epoch [40/40], Step [6/6], Loss: 0.8177
#  Time for training is 580.3423 ms
# The loss of M_trained is 0.1943, round 900
# The loss of M_current is 0.2041, round 900
# Parameter containing:
# tensor([[ 1.0751e+00,  5.1208e-02, -1.4993e+02],
#         [-6.3288e-03,  1.0528e+00, -1.3713e+01],
#         [-1.5359e-07,  2.2972e-05,  9.9998e-01]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.1943
#  Time for blending is 0.2039, round is 900
#  Time for blending is 0.1859, round is 901
#  Time for blending is 0.1741, round is 902
#  Time for blending is 0.1889, round is 903
#  Time for blending is 0.1886, round is 904
#  Time for blending is 0.1902, round is 905
#  Time for blending is 0.1901, round is 906
#  Time for blending is 0.1907, round is 907
#  Time for blending is 0.2050, round is 908
#  Time for blending is 0.2060, round is 909
#  Time for blending is 0.2061, round is 910
#  Time for blending is 0.2056, round is 911
#  Time for blending is 0.2069, round is 912
#  Time for blending is 0.1902, round is 913
#  Time for blending is 0.1905, round is 914
#  Time for blending is 0.1872, round is 915
#  Time for blending is 0.1912, round is 916
#  Time for blending is 0.1972, round is 917
#  Time for blending is 0.1855, round is 918
#  Time for blending is 0.1888, round is 919
#  Time for blending is 0.1898, round is 920
#  Time for blending is 0.1876, round is 921
#  Time for blending is 0.1881, round is 922
#  Time for blending is 0.1918, round is 923
#  Time for blending is 0.1911, round is 924
#  Time for blending is 0.2035, round is 925
#  Time for blending is 0.1913, round is 926
#  Time for blending is 0.1912, round is 927
#  Time for blending is 0.1823, round is 928
#  Time for blending is 0.1905, round is 929
#  Time for blending is 0.1754, round is 930
#  Time for blending is 0.2045, round is 931
#  Time for blending is 0.1891, round is 932
#  Time for blending is 0.2067, round is 933
#  Time for blending is 0.1907, round is 934
#  Time for blending is 0.1891, round is 935
#  Time for blending is 0.1885, round is 936
#  Time for blending is 0.1746, round is 937
#  Time for blending is 0.2048, round is 938
#  Time for blending is 0.2055, round is 939
#  Time for blending is 0.1739, round is 940
#  Time for blending is 0.2049, round is 941
#  Time for blending is 0.1905, round is 942
#  Time for blending is 0.1758, round is 943
#  Time for blending is 0.2021, round is 944
#  Time for blending is 0.1826, round is 945
#  Time for blending is 0.2056, round is 946
#  Time for blending is 0.1906, round is 947
#  Time for blending is 0.2053, round is 948
#  Time for blending is 0.1905, round is 949
#  Time for blending is 0.2074, round is 950
#  Time for blending is 0.2056, round is 951
#  Time for blending is 0.1878, round is 952
#  Time for blending is 0.2093, round is 953
#  Time for blending is 0.1922, round is 954
#  Time for blending is 0.2061, round is 955
#  Time for blending is 0.1882, round is 956
#  Time for blending is 0.2053, round is 957
#  Time for blending is 0.1910, round is 958
#  Time for blending is 0.1897, round is 959
# Time for matching is 1.4246, round is 960
# Epoch [1/40], Step [1/6], Loss: 0.2366
# Epoch [1/40], Step [2/6], Loss: 0.6586
# Epoch [1/40], Step [3/6], Loss: 0.2620
# Epoch [1/40], Step [4/6], Loss: 0.3046
# Epoch [1/40], Step [5/6], Loss: 0.3997
# Epoch [1/40], Step [6/6], Loss: 1.0644
# Epoch [2/40], Step [1/6], Loss: 0.2975
# Epoch [2/40], Step [2/6], Loss: 0.2359
# Epoch [2/40], Step [3/6], Loss: 0.2941
# Epoch [2/40], Step [4/6], Loss: 0.3194
# Epoch [2/40], Step [5/6], Loss: 0.3224
# Epoch [2/40], Step [6/6], Loss: 0.6475
# Epoch [3/40], Step [1/6], Loss: 0.1880
# Epoch [3/40], Step [2/6], Loss: 0.2452
# Epoch [3/40], Step [3/6], Loss: 0.2547
# Epoch [3/40], Step [4/6], Loss: 0.3454
# Epoch [3/40], Step [5/6], Loss: 0.3062
# Epoch [3/40], Step [6/6], Loss: 0.6127
# Epoch [4/40], Step [1/6], Loss: 0.2105
# Epoch [4/40], Step [2/6], Loss: 0.2900
# Epoch [4/40], Step [3/6], Loss: 0.2439
# Epoch [4/40], Step [4/6], Loss: 0.2941
# Epoch [4/40], Step [5/6], Loss: 0.2318
# Epoch [4/40], Step [6/6], Loss: 0.8661
# Epoch [5/40], Step [1/6], Loss: 0.2301
# Epoch [5/40], Step [2/6], Loss: 0.2599
# Epoch [5/40], Step [3/6], Loss: 0.2255
# Epoch [5/40], Step [4/6], Loss: 0.2165
# Epoch [34/40], Step [2/6], Loss: 0.2848
# Epoch [34/40], Step [3/6], Loss: 0.2766
# Epoch [34/40], Step [4/6], Loss: 0.1921
# Epoch [34/40], Step [5/6], Loss: 0.1845
# Epoch [34/40], Step [6/6], Loss: 0.5488
# Epoch [35/40], Step [1/6], Loss: 0.2289
# Epoch [35/40], Step [2/6], Loss: 0.2580
# Epoch [35/40], Step [3/6], Loss: 0.2121
# Epoch [35/40], Step [4/6], Loss: 0.2572
# Epoch [35/40], Step [5/6], Loss: 0.2092
# Epoch [35/40], Step [6/6], Loss: 0.2791
# Epoch [36/40], Step [1/6], Loss: 0.2496
# Epoch [36/40], Step [2/6], Loss: 0.2179
# Epoch [36/40], Step [3/6], Loss: 0.2255
# Epoch [36/40], Step [4/6], Loss: 0.1866
# Epoch [36/40], Step [5/6], Loss: 0.2130
# Epoch [36/40], Step [6/6], Loss: 0.7850
# Epoch [37/40], Step [1/6], Loss: 0.1998
# Epoch [37/40], Step [2/6], Loss: 0.1833
# Epoch [37/40], Step [3/6], Loss: 0.2597
# Epoch [37/40], Step [4/6], Loss: 0.2170
# Epoch [37/40], Step [5/6], Loss: 0.2717
# Epoch [37/40], Step [6/6], Loss: 0.4829
# Epoch [38/40], Step [1/6], Loss: 0.3147
# Epoch [38/40], Step [2/6], Loss: 0.2267
# Epoch [38/40], Step [3/6], Loss: 0.1722
# Epoch [38/40], Step [4/6], Loss: 0.2047
# Epoch [38/40], Step [5/6], Loss: 0.2336
# Epoch [38/40], Step [6/6], Loss: 0.3326
# Epoch [39/40], Step [1/6], Loss: 0.2594
# Epoch [39/40], Step [2/6], Loss: 0.2527
# Epoch [39/40], Step [3/6], Loss: 0.1952
# Epoch [39/40], Step [4/6], Loss: 0.2406
# Epoch [39/40], Step [5/6], Loss: 0.1852
# Epoch [39/40], Step [6/6], Loss: 0.5844
# Epoch [40/40], Step [1/6], Loss: 0.2155
# Epoch [40/40], Step [2/6], Loss: 0.2740
# Epoch [40/40], Step [3/6], Loss: 0.2187
# Epoch [40/40], Step [4/6], Loss: 0.2015
# Epoch [40/40], Step [5/6], Loss: 0.1984
# Epoch [40/40], Step [6/6], Loss: 0.6487
#  Time for training is 590.7028 ms
# The loss of M_trained is 0.1788, round 960
# The loss of M_current is 0.1848, round 960
# Parameter containing:
# tensor([[ 1.0752e+00,  5.1383e-02, -1.4993e+02],
#         [-6.2432e-03,  1.0526e+00, -1.3713e+01],
#         [-5.9347e-08,  2.2901e-05,  9.9998e-01]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.1788
#  Time for blending is 0.5646, round is 960
#  Time for blending is 0.1746, round is 961
#  Time for blending is 0.1882, round is 962
#  Time for blending is 0.1895, round is 963
#  Time for blending is 0.1898, round is 964
#  Time for blending is 0.1910, round is 965
#  Time for blending is 0.2049, round is 966
#  Time for blending is 0.1904, round is 967
#  Time for blending is 0.1741, round is 968
#  Time for blending is 0.1888, round is 969
#  Time for blending is 0.2042, round is 970
#  Time for blending is 0.1922, round is 971
#  Time for blending is 0.1891, round is 972
#  Time for blending is 0.1885, round is 973
#  Time for blending is 0.1905, round is 974
#  Time for blending is 0.2046, round is 975
#  Time for blending is 0.1919, round is 976
#  Time for blending is 0.1892, round is 977
#  Time for blending is 0.2033, round is 978
#  Time for blending is 0.1903, round is 979
#  Time for blending is 0.1920, round is 980
#  Time for blending is 0.1890, round is 981
#  Time for blending is 0.1898, round is 982
#  Time for blending is 0.1878, round is 983
#  Time for blending is 0.1891, round is 984
#  Time for blending is 0.1918, round is 985

# %%
import torch
import torch.optim as optim
from torch import nn
import torch.utils.data as Data

cap1=cv2.VideoCapture('C:/Users/Jackie/Downloads/0121_1.MP4')
cap2=cv2.VideoCapture('C:/Users/Jackie/Downloads/0121_2.MP4')
count=cap1.get(cv2.CAP_PROP_FRAME_COUNT)
fps=cap1.get(cv2.CAP_PROP_FPS)
size=(int(cap1.get(cv2.CAP_PROP_FRAME_WIDTH)*2),int(cap1.get(cv2.CAP_PROP_FRAME_HEIGHT)))
video=cv2.VideoWriter('C:/Users/Jackie/Downloads/121_improved_blending_maskrate240.MP4',cv2.VideoWriter_fourcc('I','4','2','0'),fps,size)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")



maxL = 200
maxR = 200

if cap1.isOpened() and cap2.isOpened():
    i=1
    print('successful')
    print("The count is %d" %(count))
    #image size paremeters
    
        
    ret1,frame1=cap1.read()
    ret2,frame2=cap2.read()
    H=frame1.shape[0]
    W_remap=int(194/180*H)
    W=frame1.shape[1]+frame2.shape[1]
    templ_shape = (60, 16)
    offsetYL = int(160/1280*H)
    offsetYR = int(160/1280*H)
    #print(W_remap)
    #remap
    xmap, ymap, p = buildmap(Ws=W_remap, Hs=H, Wd=H, Hd=H, fov=194)
    #cam2 = cv2.remap(frame[:, :H], xmap, ymap, cv2.INTER_LINEAR)
    #cam1 = cv2.remap(frame[:, H:], xmap, ymap, cv2.INTER_LINEAR)
    cam1 = cv2.remap(frame1, xmap, ymap, cv2.INTER_LINEAR)
    cam2 = cv2.remap(frame2, xmap, ymap, cv2.INTER_LINEAR)
    
    #shift
    cam1_gray = cv2.cvtColor(cam1, cv2.COLOR_BGR2GRAY)
    cam2_gray = cv2.cvtColor(cam2, cv2.COLOR_BGR2GRAY)
    shifted_cams = np.zeros((H * 2, W, 3), np.uint8)
    shifted_cams[H:, int((W - W_remap) / 2):int((W + W_remap) / 2)] = cam1
    shifted_cams[:H, :int(W_remap / 2)] = cam2[:, int(W_remap / 2):]
    shifted_cams[:H, W - int(W_remap / 2):] = cam2[:, :int(W_remap / 2)]
    
    #cv2.imwrite('video_shift.jpg', shifted_cams)
    #matching
    
    maxL = 200
    maxR = 200
    b_matching=time.time()
    matchesL = getMatches_goodtemplmatch(
                    cam1_gray[offsetYL:H - offsetYL, int(W / 2):],
                    cam2_gray[offsetYL:H - offsetYL, :W_remap - int(W / 2)],
                    templ_shape, maxL)
    matchesR = getMatches_goodtemplmatch(
                    cam2_gray[offsetYR:H - offsetYR, int(W / 2):],
                    cam1_gray[offsetYR:H - offsetYR, :W_remap - int(W / 2)],
                    templ_shape, maxR)
    matchesR = matchesR[:, -1::-1]
    matchesL = matchesL + (int((W - W_remap) / 2), offsetYL)
    matchesR = matchesR + (int((W - W_remap) / 2) + int(W / 2), offsetYR)
    zipped_matches = list(zip(matchesL, matchesR))
    matches = np.int32([e for i in zipped_matches for e in i])
    pts1 = matches[:, 0]
    pts2 = matches[:, 1]
    
    #homography
    M_current, status = cv2.findHomography(pts2, pts1, cv2.RANSAC, 4.0)
    
    top, bottom = verticalBoundary(M_current, W_remap, W, H)
    warped2 = cv2.warpPerspective(shifted_cams[H:], M_current, (W, H))
    warped1 = shifted_cams[0:H,:]
    warped1 = cv2.resize(warped1[top:bottom], (W, H))
    warped2 = cv2.resize(warped2[top:bottom], (W, H))
    EAof2 = np.zeros((H, W, 3), np.uint8)
    EAof2[:, int((W - W_remap) / 2) + 1:int((W + W_remap) / 2) - 1] = 255
    EAof2 = cv2.warpPerspective(EAof2, M_current, (W, H))
    
    #blend
    b_blend=time.time()
    W_lbl = 120
    blend_level = 4
    
    mask, minloc_old = imgLabeling(
                warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                (W, H), int(W_remap / 2) - W_lbl, W - int(W_remap / 2))
    
    warped1[:, int(W_remap / 2):W - int(W_remap /
                2)] = warped2[:, int(W_remap / 2):W - int(W_remap / 2)]
    warped2[EAof2 == 0] = warped1[EAof2 == 0]
    '''
    blended = multi_band_blending(
                    warped1, warped2, mask, blend_level)
    '''
    blended_l = multi_band_blending(
                    warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    mask[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    blend_level)
    blended_r = multi_band_blending(
                    warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    mask[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    blend_level)
    blended = np.ones((H,W,3))
    blended[:, 0:int(W_remap / 2) - W_lbl] = warped1[:, 0:int(W_remap / 2) - W_lbl]
    blended[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)] = blended_l
    blended[:,int(W_remap / 2):W - int(W_remap / 2)] = warped2[:,int(W_remap / 2):W - int(W_remap / 2)]
    blended[:,W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl] = blended_r
    blended[:,W - int(W_remap / 2) + W_lbl:] = warped1[:,W - int(W_remap / 2) + W_lbl:]
    e_blend=time.time()
    #print("Time for blending is %.4f" %(e_blend-b_blend))
    video.write(blended.astype(np.uint8))
    #cv2.imwrite('video_blending.jpg', blended.astype(np.uint8))
    #FCN
    epochs=40
    index=np.where(status.ravel()==1)
    inliers=matches[index[0]]
    train,label = deduplication(inliers)
    zipped_train = list(zip(train, label))
    dataset = np.int32([e for e in zipped_train])
    np.random.shuffle(dataset)
    train = dataset[:, 0]
    label = dataset[:, 1]
    b_test = np.ones(int(train[int(train.shape[0]*0.8):].shape[0]))
    test = np.insert(train[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
    label_test = np.insert(label[int(train.shape[0]*0.8):], 2, values=b_test, axis=1)
    M = torch.tensor(M_current,requires_grad=True)
    #M_best = torch.tensor(M_best,requires_grad=True)
    model = nn.Linear(3,3,bias=False)
    model.weight =nn.Parameter(M)
    criterion = nn.MSELoss()
    test = torch.tensor(test,requires_grad=False,dtype=torch.float64)
    label_test = torch.tensor(label_test,requires_grad=False,dtype=torch.float64)
    
    test_output = model(test)
    test_output = test_output/test_output[:,2].reshape(-1,1)
    best_loss = criterion(test_output,label_test)/label_test.shape[0]
    
    print("The loss for frame1 is %.4f" %(best_loss))
    #print("The loss of M_best for frame1 is %.4f" %(loss_test_b))
    shape_list = []
    shape_list.append(inliers.shape[0])
    #M_best = M_best.to(device)
    while i<count:
        i+=1
        ret1,frame1=cap1.read()
        ret2,frame2=cap2.read()
        
        if ret1 and ret2:
            
            cam1 = cv2.remap(frame1, xmap, ymap, cv2.INTER_LINEAR)
            cam2 = cv2.remap(frame2, xmap, ymap, cv2.INTER_LINEAR)
            
            #shift
                
            shifted_cams = np.zeros((H * 2, W, 3), np.uint8)
            shifted_cams[H:, int((W - W_remap) / 2):int((W + W_remap) / 2)] = cam1
            shifted_cams[:H, :int(W_remap / 2)] = cam2[:, int(W_remap / 2):]
            shifted_cams[:H, W - int(W_remap / 2):] = cam2[:, :int(W_remap / 2)]
            if len(shape_list)%4==0:
                inliers = np.delete(inliers, range(0,shape_list[0]),axis = 0)
                del(shape_list[0])
             
            if i%60==0:
                cam1_gray = cv2.cvtColor(cam1, cv2.COLOR_BGR2GRAY)
                cam2_gray = cv2.cvtColor(cam2, cv2.COLOR_BGR2GRAY)
                b_matching=time.time()
                matchesL = getMatches_goodtemplmatch(
                    cam1_gray[offsetYL:H - offsetYL, int(W / 2):],
                    cam2_gray[offsetYL:H - offsetYL, :W_remap - int(W / 2)],
                    templ_shape, maxL)
                matchesR = getMatches_goodtemplmatch(
                    cam2_gray[offsetYR:H - offsetYR, int(W / 2):],
                    cam1_gray[offsetYR:H - offsetYR, :W_remap - int(W / 2)],
                    templ_shape, maxR)
                matchesR = matchesR[:, -1::-1]
                matchesL = matchesL + (int((W - W_remap) / 2), offsetYL)
                matchesR = matchesR + (int((W - W_remap) / 2) + int(W / 2), offsetYR)
                zipped_matches = list(zip(matchesL, matchesR))
                matches_append = np.int32([e for i in zipped_matches for e in i])
                pts1 = matches_append[:, 0]
                pts2 = matches_append[:, 1]
                
                
                e_matching=time.time()
                print("Time for matching is %.4f, round is %d" %((e_matching-b_matching),i) )
                M_, status = cv2.findHomography(pts2, pts1, cv2.RANSAC, 4.0)
                index=np.where(status.ravel()==1)
      
                inliers = np.concatenate((inliers,matches_append[index[0]]),axis=0)
                shape_list.append(matches_append[index[0]].shape[0])
                
        
                train,label = deduplication(inliers)
                zipped_train = list(zip(train, label))
                dataset = np.int32([e for e in zipped_train])
                np.random.shuffle(dataset)
                train = dataset[:, 0]
                label = dataset[:, 1]
                
                b_test = np.ones(int(train[int(train.shape[0]*0.8):].shape[0]))
                test = np.insert(train[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
                label_test = np.insert(label[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
                b=np.ones(int(train.shape[0]*0.8))
                train = np.insert(train[:int(train.shape[0]*0.8)], 2, values=b, axis=1) 
                label = np.insert(label[:int(label.shape[0]*0.8)], 2, values=b, axis=1) 
                
                M = torch.tensor(M_current,requires_grad=True)
                model = nn.Linear(3,3,bias=False)
                model.weight =nn.Parameter(M)
                model.to(device)
                criterion = nn.MSELoss()
                optimizer = torch.optim.Adam(model.parameters(), lr=0.000001)
                #optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
    
                #M = torch.tensor(M,requires_grad=True)
                inputs = torch.tensor(train,requires_grad=False,dtype=torch.float64)
                inputs = inputs.to(device)
                label_t = torch.tensor(label,requires_grad=False,dtype=torch.float64)
                label_t = label_t.to(device)
                test = torch.tensor(test,requires_grad=False,dtype=torch.float64)
                test = test.to(device)
                label_test = torch.tensor(label_test,requires_grad=False,dtype=torch.float64)
                label_test = label_test.to(device)
                torch_dataset = Data.TensorDataset(inputs, label_t)

                loader = Data.DataLoader(
                                dataset=torch_dataset,      
                                batch_size=64,      
                                shuffle=True,               
                                num_workers=0,)
                total_step = len(loader)
                t_s = time.time()
                for epoch in range(epochs):
                    for step, (batch_x, l) in enumerate(loader):
                        #batch_x, l = batch_x.to(device),l.to(device)
                        outputs = model(batch_x)
                        outputs = outputs/outputs[:,2].reshape(-1,1)
                        loss = criterion(outputs,l)
                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()
                        print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch+1, epochs, step+1, total_step, loss.item()/len(batch_x)))
                t_e = time.time()
                print(" Time for training is %.4f ms" %((t_e-t_s)*1000))
                test_output = model(test)
                test_output = test_output/test_output[:,2].reshape(-1,1)
                loss_test = criterion(test_output,label_test)/label_test.shape[0]
                
                M_c = torch.tensor(M_current,requires_grad=True)
                model_c = nn.Linear(3,3,bias=False)
                model_c.weight =nn.Parameter(M_c)
                model_c.to(device)
                current_test = model_c(test)
                current_test = current_test/current_test[:,2].reshape(-1,1)
                current_loss = criterion(current_test,label_test)/label_test.shape[0]
                
                print("The loss of M_trained is %.4f, round %d" %(loss_test,i))
                print("The loss of M_current is %.4f, round %d" %(current_loss,i))
                print(model.weight)
                
                if loss_test<current_loss:
                    model = model.cpu()
                    M_current = model.weight.detach().numpy()
                    M_current = M_current/M_current[2][2]
                    best_loss = loss_test
                    print("The best loss is %.4f" %(best_loss))
            
            top, bottom = verticalBoundary(M_current, W_remap, W, H)
            warped2 = cv2.warpPerspective(shifted_cams[H:], M_current, (W, H))
            warped1 = shifted_cams[0:H,:]
            warped1 = cv2.resize(warped1[top:bottom], (W, H))
            warped2 = cv2.resize(warped2[top:bottom], (W, H))
            EAof2 = np.zeros((H, W, 3), np.uint8)
            EAof2[:, int((W - W_remap) / 2) + 1:int((W + W_remap) / 2) - 1] = 255
            EAof2 = cv2.warpPerspective(EAof2, M_current, (W, H))
            b_blend=time.time()
            
            if i%240==0:
                mask, minloc_old = imgLabeling(
                warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                (W, H), int(W_remap / 2) - W_lbl, W - int(W_remap / 2))
            
            
            
            warped1[:, int(W_remap / 2):W - int(W_remap /
                        2)] = warped2[:, int(W_remap / 2):W - int(W_remap / 2)]
            warped2[EAof2 == 0] = warped1[EAof2 == 0]
            '''
            blended = multi_band_blending(
                                warped1, warped2, mask, blend_level)
            '''
            #blended = warped1 * mask + warped2 * (1 - mask)
            blended_l = multi_band_blending(
                    warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    mask[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    blend_level)
            blended_r = multi_band_blending(
                    warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    mask[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    blend_level)
            blended = np.ones((H,W,3))
            blended[:, 0:int(W_remap / 2) - W_lbl] = warped1[:, 0:int(W_remap / 2) - W_lbl]
            blended[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)] = blended_l
            blended[:,int(W_remap / 2):W - int(W_remap / 2)] = warped2[:,int(W_remap / 2):W - int(W_remap / 2)]
            blended[:,W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl] = blended_r
            blended[:,W - int(W_remap / 2) + W_lbl:] = warped1[:,W - int(W_remap / 2) + W_lbl:]
            video.write(blended.astype(np.uint8))
            e_blend=time.time()
            print(" Time for blending is %.4f, round is %d" %((e_blend-b_blend),i) )
      
        else:   
            break
    
else:
    print('fail')
cap1.release()
cap2.release()
video.release()
# Out:
# successful
# The count is 943
# The loss for frame1 is 0.0699
#  Time for blending is 0.3210, round is 2
#  Time for blending is 0.3109, round is 3
#  Time for blending is 0.3098, round is 4
#  Time for blending is 0.3116, round is 5
#  Time for blending is 0.3410, round is 6
#  Time for blending is 0.3126, round is 7
#  Time for blending is 0.3108, round is 8
#  Time for blending is 0.2952, round is 9
#  Time for blending is 0.2966, round is 10
#  Time for blending is 0.2929, round is 11
#  Time for blending is 0.2952, round is 12
#  Time for blending is 0.3109, round is 13
#  Time for blending is 0.3110, round is 14
#  Time for blending is 0.3176, round is 15
#  Time for blending is 0.3158, round is 16
#  Time for blending is 0.3066, round is 17
#  Time for blending is 0.3253, round is 18
#  Time for blending is 0.3426, round is 19
#  Time for blending is 0.3159, round is 20
#  Time for blending is 0.3096, round is 21
#  Time for blending is 0.3113, round is 22
#  Time for blending is 0.3117, round is 23
#  Time for blending is 0.3108, round is 24
#  Time for blending is 0.3098, round is 25
#  Time for blending is 0.3120, round is 26
#  Time for blending is 0.3101, round is 27
#  Time for blending is 0.2935, round is 28
#  Time for blending is 0.2967, round is 29
#  Time for blending is 0.2944, round is 30
#  Time for blending is 0.3090, round is 31
#  Time for blending is 0.3245, round is 32
#  Time for blending is 0.3256, round is 33
#  Time for blending is 0.3117, round is 34
#  Time for blending is 0.3098, round is 35
#  Time for blending is 0.3092, round is 36
#  Time for blending is 0.3138, round is 37
#  Time for blending is 0.3265, round is 38
#  Time for blending is 0.3094, round is 39
#  Time for blending is 0.3137, round is 40
#  Time for blending is 0.3076, round is 41
#  Time for blending is 0.3123, round is 42
#  Time for blending is 0.3128, round is 43
#  Time for blending is 0.3084, round is 44
#  Time for blending is 0.3121, round is 45
#  Time for blending is 0.3278, round is 46
#  Time for blending is 0.3434, round is 47
#  Time for blending is 0.3112, round is 48
#  Time for blending is 0.3094, round is 49
#  Time for blending is 0.3117, round is 50
#  Time for blending is 0.3110, round is 51
#  Time for blending is 0.3688, round is 52
#  Time for blending is 0.3217, round is 53
#  Time for blending is 0.3252, round is 54
#  Time for blending is 0.3291, round is 55
#  Time for blending is 0.3365, round is 56
#  Time for blending is 0.3497, round is 57
#  Time for blending is 0.3315, round is 58
#  Time for blending is 0.3335, round is 59
# Time for matching is 3.0152, round is 60
# Epoch [1/40], Step [1/3], Loss: 0.3185
# Epoch [1/40], Step [2/3], Loss: 3.5528
# Epoch [1/40], Step [3/3], Loss: 1.4380
# Epoch [2/40], Step [1/3], Loss: 0.9883
# Epoch [2/40], Step [2/3], Loss: 2.2683
# Epoch [2/40], Step [3/3], Loss: 3.6726
# Epoch [3/40], Step [1/3], Loss: 0.8152
# Epoch [3/40], Step [2/3], Loss: 0.3841
# Epoch [3/40], Step [3/3], Loss: 1.3067
# Epoch [4/40], Step [1/3], Loss: 1.0614
# Epoch [4/40], Step [2/3], Loss: 1.2590
# Epoch [4/40], Step [3/3], Loss: 1.8632
# Epoch [5/40], Step [1/3], Loss: 0.4912
# Epoch [5/40], Step [2/3], Loss: 0.2658
# Epoch [5/40], Step [3/3], Loss: 1.2499
# Epoch [6/40], Step [1/3], Loss: 0.8950
# Epoch [6/40], Step [2/3], Loss: 0.6623
# Epoch [6/40], Step [3/3], Loss: 1.4928
# Epoch [7/40], Step [1/3], Loss: 0.2962
# Epoch [7/40], Step [2/3], Loss: 0.2682
# Epoch [7/40], Step [3/3], Loss: 1.9032
# Epoch [8/40], Step [1/3], Loss: 0.6763
# Epoch [8/40], Step [2/3], Loss: 0.4406
# Epoch [8/40], Step [3/3], Loss: 1.3012
# Epoch [9/40], Step [1/3], Loss: 0.1812
# Epoch [9/40], Step [2/3], Loss: 0.3382
# Epoch [9/40], Step [3/3], Loss: 2.0879
# Epoch [10/40], Step [1/3], Loss: 0.5783
# Epoch [10/40], Step [2/3], Loss: 0.4349
# Epoch [10/40], Step [3/3], Loss: 0.5421
# Epoch [11/40], Step [1/3], Loss: 0.2899
# Epoch [11/40], Step [2/3], Loss: 0.2523
# Epoch [11/40], Step [3/3], Loss: 1.4036
# Epoch [12/40], Step [1/3], Loss: 0.3542
# Epoch [12/40], Step [2/3], Loss: 0.4293
# Epoch [12/40], Step [3/3], Loss: 0.9155
# Epoch [13/40], Step [1/3], Loss: 0.2906
# Epoch [13/40], Step [2/3], Loss: 0.1890
# Epoch [13/40], Step [3/3], Loss: 1.8571
# Epoch [33/40], Step [1/3], Loss: 0.2220
# Epoch [33/40], Step [2/3], Loss: 0.0867
# Epoch [33/40], Step [3/3], Loss: 1.9921
# Epoch [34/40], Step [1/3], Loss: 0.2789
# Epoch [34/40], Step [2/3], Loss: 0.3012
# Epoch [34/40], Step [3/3], Loss: 0.2329
# Epoch [35/40], Step [1/3], Loss: 0.2839
# Epoch [35/40], Step [2/3], Loss: 0.2556
# Epoch [35/40], Step [3/3], Loss: 0.4342
# Epoch [36/40], Step [1/3], Loss: 0.2570
# Epoch [36/40], Step [2/3], Loss: 0.1837
# Epoch [36/40], Step [3/3], Loss: 1.0587
# Epoch [37/40], Step [1/3], Loss: 0.3277
# Epoch [37/40], Step [2/3], Loss: 0.1676
# Epoch [37/40], Step [3/3], Loss: 0.6979
# Epoch [38/40], Step [1/3], Loss: 0.2459
# Epoch [38/40], Step [2/3], Loss: 0.2563
# Epoch [38/40], Step [3/3], Loss: 0.5947
# Epoch [39/40], Step [1/3], Loss: 0.2057
# Epoch [39/40], Step [2/3], Loss: 0.2582
# Epoch [39/40], Step [3/3], Loss: 0.8895
# Epoch [40/40], Step [1/3], Loss: 0.2639
# Epoch [40/40], Step [2/3], Loss: 0.1883
# Epoch [40/40], Step [3/3], Loss: 0.9833
#  Time for training is 403.9521 ms
# The loss of M_trained is 0.5215, round 60
# The loss of M_current is 0.6815, round 60
# Parameter containing:
# tensor([[ 9.3624e-01, -9.4970e-03,  1.0092e+02],
#         [-3.3549e-02,  1.0073e+00,  4.4114e+01],
#         [-1.8560e-05,  1.9411e-05,  9.9999e-01]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.5215
#  Time for blending is 0.3376, round is 60
#  Time for blending is 0.3014, round is 61
#  Time for blending is 0.3252, round is 62
#  Time for blending is 0.3097, round is 63
#  Time for blending is 0.2964, round is 64
#  Time for blending is 0.3262, round is 65
#  Time for blending is 0.3116, round is 66
#  Time for blending is 0.3123, round is 67
#  Time for blending is 0.2950, round is 68
#  Time for blending is 0.2944, round is 69
#  Time for blending is 0.3105, round is 70
#  Time for blending is 0.3106, round is 71
#  Time for blending is 0.3120, round is 72
#  Time for blending is 0.3092, round is 73
#  Time for blending is 0.3115, round is 74
#  Time for blending is 0.3112, round is 75
#  Time for blending is 0.3108, round is 76
#  Time for blending is 0.3267, round is 77
#  Time for blending is 0.3117, round is 78
#  Time for blending is 0.3099, round is 79
#  Time for blending is 0.3112, round is 80
#  Time for blending is 0.3126, round is 81
#  Time for blending is 0.3261, round is 82
#  Time for blending is 0.3275, round is 83
#  Time for blending is 0.3118, round is 84
#  Time for blending is 0.3099, round is 85
#  Time for blending is 0.3275, round is 86
#  Time for blending is 0.3276, round is 87
#  Time for blending is 0.3255, round is 88
#  Time for blending is 0.3286, round is 89
#  Time for blending is 0.3275, round is 90
#  Time for blending is 0.2961, round is 91
#  Time for blending is 0.3101, round is 92
#  Time for blending is 0.3115, round is 93
#  Time for blending is 0.2942, round is 94
#  Time for blending is 0.3108, round is 95
#  Time for blending is 0.3095, round is 96
#  Time for blending is 0.3129, round is 97
#  Time for blending is 0.3103, round is 98
#  Time for blending is 0.3112, round is 99
#  Time for blending is 0.2926, round is 100
#  Time for blending is 0.3131, round is 101
#  Time for blending is 0.3111, round is 102
#  Time for blending is 0.2928, round is 103
#  Time for blending is 0.3109, round is 104
#  Time for blending is 0.2961, round is 105
#  Time for blending is 0.3080, round is 106
#  Time for blending is 0.3290, round is 107
#  Time for blending is 0.3119, round is 108
#  Time for blending is 0.3236, round is 109
#  Time for blending is 0.3132, round is 110
#  Time for blending is 0.3108, round is 111
#  Time for blending is 0.3115, round is 112
#  Time for blending is 0.3096, round is 113
#  Time for blending is 0.3111, round is 114
#  Time for blending is 0.3122, round is 115
#  Time for blending is 0.3198, round is 116
#  Time for blending is 0.3126, round is 117
#  Time for blending is 0.3244, round is 118
#  Time for blending is 0.3114, round is 119
# Time for matching is 2.9691, round is 120
# Epoch [1/40], Step [1/4], Loss: 0.2625
# Epoch [1/40], Step [2/4], Loss: 3.1715
# Epoch [1/40], Step [3/4], Loss: 0.5618
# Epoch [1/40], Step [4/4], Loss: 2.8891
# Epoch [2/40], Step [1/4], Loss: 2.0608
# Epoch [2/40], Step [2/4], Loss: 1.3326
# Epoch [2/40], Step [3/4], Loss: 0.4564
# Epoch [2/40], Step [4/4], Loss: 1.2863
# Epoch [3/40], Step [1/4], Loss: 0.5488
# Epoch [3/40], Step [2/4], Loss: 0.8849
# Epoch [3/40], Step [3/4], Loss: 1.0066
# Epoch [3/40], Step [4/4], Loss: 1.9030
# Epoch [4/40], Step [1/4], Loss: 0.2466
# Epoch [4/40], Step [2/4], Loss: 0.3342
# Epoch [4/40], Step [3/4], Loss: 0.4990
# Epoch [4/40], Step [4/4], Loss: 3.9256
# Epoch [5/40], Step [1/4], Loss: 0.4731
# Epoch [5/40], Step [2/4], Loss: 0.2715
# Epoch [5/40], Step [3/4], Loss: 0.3261
# Epoch [5/40], Step [4/4], Loss: 2.9121
# Epoch [6/40], Step [1/4], Loss: 0.4869
# Epoch [6/40], Step [2/4], Loss: 0.4883
# Epoch [6/40], Step [3/4], Loss: 0.4464
# Epoch [6/40], Step [4/4], Loss: 2.5936
# Epoch [7/40], Step [1/4], Loss: 0.1996
# Epoch [7/40], Step [2/4], Loss: 0.3995
# Epoch [7/40], Step [3/4], Loss: 0.3768
# Epoch [7/40], Step [4/4], Loss: 2.1809
# Epoch [8/40], Step [1/4], Loss: 0.3602
# Epoch [8/40], Step [2/4], Loss: 0.1851
# Epoch [8/40], Step [3/4], Loss: 0.3148
# Epoch [8/40], Step [4/4], Loss: 1.8978
# Epoch [9/40], Step [1/4], Loss: 0.4224
# Epoch [9/40], Step [2/4], Loss: 0.2871
# Epoch [9/40], Step [3/4], Loss: 0.3104
# Epoch [9/40], Step [4/4], Loss: 1.1994
# Epoch [10/40], Step [1/4], Loss: 0.2774
# Epoch [10/40], Step [2/4], Loss: 0.3146
# Epoch [10/40], Step [3/4], Loss: 0.3673
# Epoch [10/40], Step [4/4], Loss: 0.8651
# Epoch [11/40], Step [1/4], Loss: 0.2531
# Epoch [39/40], Step [4/4], Loss: 2.3603
# Epoch [40/40], Step [1/4], Loss: 0.1588
# Epoch [40/40], Step [2/4], Loss: 0.3158
# Epoch [40/40], Step [3/4], Loss: 0.2961
# Epoch [40/40], Step [4/4], Loss: 1.2838
#  Time for training is 512.8131 ms
# The loss of M_trained is 0.2629, round 120
# The loss of M_current is 0.2705, round 120
# Parameter containing:
# tensor([[ 9.3625e-01, -9.4805e-03,  1.0092e+02],
#         [-3.3548e-02,  1.0073e+00,  4.4115e+01],
#         [-1.8104e-05,  1.8557e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.2629
#  Time for blending is 0.2988, round is 120
#  Time for blending is 0.3105, round is 121
#  Time for blending is 0.3117, round is 122
#  Time for blending is 0.3100, round is 123
#  Time for blending is 0.3102, round is 124
#  Time for blending is 0.2978, round is 125
#  Time for blending is 0.3076, round is 126
#  Time for blending is 0.3134, round is 127
#  Time for blending is 0.3103, round is 128
#  Time for blending is 0.3107, round is 129
#  Time for blending is 0.3107, round is 130
#  Time for blending is 0.3120, round is 131
#  Time for blending is 0.3275, round is 132
#  Time for blending is 0.3096, round is 133
#  Time for blending is 0.3104, round is 134
#  Time for blending is 0.2949, round is 135
#  Time for blending is 0.3108, round is 136
#  Time for blending is 0.2958, round is 137
#  Time for blending is 0.3114, round is 138
#  Time for blending is 0.3101, round is 139
#  Time for blending is 0.3105, round is 140
#  Time for blending is 0.2927, round is 141
#  Time for blending is 0.3102, round is 142
#  Time for blending is 0.3120, round is 143
#  Time for blending is 0.2937, round is 144
#  Time for blending is 0.3060, round is 145
#  Time for blending is 0.3098, round is 146
#  Time for blending is 0.3281, round is 147
#  Time for blending is 0.3112, round is 148
#  Time for blending is 0.3243, round is 149
#  Time for blending is 0.3139, round is 150
#  Time for blending is 0.3246, round is 151
#  Time for blending is 0.3123, round is 152
#  Time for blending is 0.3118, round is 153
#  Time for blending is 0.3095, round is 154
#  Time for blending is 0.3117, round is 155
#  Time for blending is 0.3260, round is 156
#  Time for blending is 0.3295, round is 157
#  Time for blending is 0.3420, round is 158
#  Time for blending is 0.3122, round is 159
#  Time for blending is 0.3292, round is 160
#  Time for blending is 0.3264, round is 161
#  Time for blending is 0.3111, round is 162
#  Time for blending is 0.3098, round is 163
#  Time for blending is 0.3139, round is 164
#  Time for blending is 0.3267, round is 165
#  Time for blending is 0.3265, round is 166
#  Time for blending is 0.3275, round is 167
#  Time for blending is 0.3118, round is 168
#  Time for blending is 0.3093, round is 169
#  Time for blending is 0.3115, round is 170
#  Time for blending is 0.3106, round is 171
#  Time for blending is 0.2958, round is 172
#  Time for blending is 0.3095, round is 173
#  Time for blending is 0.3119, round is 174
#  Time for blending is 0.2947, round is 175
#  Time for blending is 0.3114, round is 176
#  Time for blending is 0.3103, round is 177
#  Time for blending is 0.3114, round is 178
#  Time for blending is 0.2953, round is 179
# Time for matching is 3.0295, round is 180
# Epoch [1/40], Step [1/4], Loss: 0.1830
# Epoch [1/40], Step [2/4], Loss: 3.4767
# Epoch [1/40], Step [3/4], Loss: 0.3552
# Epoch [1/40], Step [4/4], Loss: 1.0629
# Epoch [30/40], Step [3/4], Loss: 0.2558
# Epoch [30/40], Step [4/4], Loss: 0.2704
# Epoch [31/40], Step [1/4], Loss: 0.1817
# Epoch [31/40], Step [2/4], Loss: 0.1846
# Epoch [31/40], Step [3/4], Loss: 0.1657
# Epoch [31/40], Step [4/4], Loss: 0.4315
# Epoch [32/40], Step [1/4], Loss: 0.2566
# Epoch [32/40], Step [2/4], Loss: 0.2359
# Epoch [32/40], Step [3/4], Loss: 0.1793
# Epoch [32/40], Step [4/4], Loss: 0.2238
# Epoch [33/40], Step [1/4], Loss: 0.2888
# Epoch [33/40], Step [2/4], Loss: 0.1635
# Epoch [33/40], Step [3/4], Loss: 0.2559
# Epoch [33/40], Step [4/4], Loss: 0.1883
# Epoch [34/40], Step [1/4], Loss: 0.1434
# Epoch [34/40], Step [2/4], Loss: 0.2474
# Epoch [34/40], Step [3/4], Loss: 0.2110
# Epoch [34/40], Step [4/4], Loss: 0.3166
# Epoch [35/40], Step [1/4], Loss: 0.2741
# Epoch [35/40], Step [2/4], Loss: 0.2003
# Epoch [35/40], Step [3/4], Loss: 0.1503
# Epoch [35/40], Step [4/4], Loss: 0.2880
# Epoch [36/40], Step [1/4], Loss: 0.2905
# Epoch [36/40], Step [2/4], Loss: 0.1780
# Epoch [36/40], Step [3/4], Loss: 0.1138
# Epoch [36/40], Step [4/4], Loss: 0.3375
# Epoch [37/40], Step [1/4], Loss: 0.1199
# Epoch [37/40], Step [2/4], Loss: 0.1835
# Epoch [37/40], Step [3/4], Loss: 0.2718
# Epoch [37/40], Step [4/4], Loss: 0.3532
# Epoch [38/40], Step [1/4], Loss: 0.2464
# Epoch [38/40], Step [2/4], Loss: 0.1597
# Epoch [38/40], Step [3/4], Loss: 0.2170
# Epoch [38/40], Step [4/4], Loss: 0.2921
# Epoch [39/40], Step [1/4], Loss: 0.1652
# Epoch [39/40], Step [2/4], Loss: 0.2528
# Epoch [39/40], Step [3/4], Loss: 0.2776
# Epoch [39/40], Step [4/4], Loss: 0.1810
# Epoch [40/40], Step [1/4], Loss: 0.1611
# Epoch [40/40], Step [2/4], Loss: 0.3064
# Epoch [40/40], Step [3/4], Loss: 0.1933
# Epoch [40/40], Step [4/4], Loss: 0.2508
#  Time for training is 550.2942 ms
# The loss of M_trained is 0.2898, round 180
# The loss of M_current is 0.2893, round 180
# Parameter containing:
# tensor([[ 9.3626e-01, -9.4740e-03,  1.0092e+02],
#         [-3.3555e-02,  1.0073e+00,  4.4115e+01],
#         [-1.8306e-05,  1.8963e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
#  Time for blending is 0.3053, round is 180
#  Time for blending is 0.3150, round is 181
#  Time for blending is 0.3098, round is 182
#  Time for blending is 0.3110, round is 183
#  Time for blending is 0.3282, round is 184
#  Time for blending is 0.3108, round is 185
#  Time for blending is 0.3131, round is 186
#  Time for blending is 0.3255, round is 187
#  Time for blending is 0.3097, round is 188
#  Time for blending is 0.3151, round is 189
#  Time for blending is 0.3240, round is 190
#  Time for blending is 0.2962, round is 191
#  Time for blending is 0.3113, round is 192
#  Time for blending is 0.3118, round is 193
#  Time for blending is 0.3244, round is 194
#  Time for blending is 0.3126, round is 195
#  Time for blending is 0.3148, round is 196
#  Time for blending is 0.3256, round is 197
#  Time for blending is 0.3125, round is 198
#  Time for blending is 0.3115, round is 199
#  Time for blending is 0.3087, round is 200
#  Time for blending is 0.3123, round is 201
#  Time for blending is 0.3103, round is 202
#  Time for blending is 0.3114, round is 203
#  Time for blending is 0.2961, round is 204
#  Time for blending is 0.3075, round is 205
#  Time for blending is 0.2985, round is 206
#  Time for blending is 0.3086, round is 207
#  Time for blending is 0.3122, round is 208
#  Time for blending is 0.3106, round is 209
#  Time for blending is 0.3104, round is 210
#  Time for blending is 0.2945, round is 211
#  Time for blending is 0.3102, round is 212
#  Time for blending is 0.2949, round is 213
#  Time for blending is 0.2950, round is 214
#  Time for blending is 0.3243, round is 215
#  Time for blending is 0.3139, round is 216
#  Time for blending is 0.3273, round is 217
#  Time for blending is 0.3264, round is 218
#  Time for blending is 0.3284, round is 219
#  Time for blending is 0.3108, round is 220
#  Time for blending is 0.3102, round is 221
#  Time for blending is 0.3264, round is 222
#  Time for blending is 0.3272, round is 223
#  Time for blending is 0.2962, round is 224
#  Time for blending is 0.3232, round is 225
#  Time for blending is 0.3141, round is 226
#  Time for blending is 0.3256, round is 227
#  Time for blending is 0.3119, round is 228
#  Time for blending is 0.3115, round is 229
#  Time for blending is 0.3275, round is 230
#  Time for blending is 0.3113, round is 231
#  Time for blending is 0.3127, round is 232
#  Time for blending is 0.3257, round is 233
#  Time for blending is 0.3271, round is 234
#  Time for blending is 0.3440, round is 235
#  Time for blending is 0.3118, round is 236
#  Time for blending is 0.3294, round is 237
#  Time for blending is 0.3962, round is 238
#  Time for blending is 0.3276, round is 239
# Time for matching is 3.1409, round is 240
# Epoch [1/40], Step [1/4], Loss: 0.3757
# Epoch [1/40], Step [2/4], Loss: 3.4672
# Epoch [1/40], Step [3/4], Loss: 0.4752
# Epoch [1/40], Step [4/4], Loss: 1.6409
# Epoch [2/40], Step [1/4], Loss: 1.7564
# Epoch [2/40], Step [2/4], Loss: 1.8539
# Epoch [2/40], Step [3/4], Loss: 0.9559
# Epoch [2/40], Step [4/4], Loss: 0.5733
# Epoch [3/40], Step [1/4], Loss: 0.5590
# Epoch [3/40], Step [2/4], Loss: 0.9398
# Epoch [3/40], Step [3/4], Loss: 1.2332
# Epoch [3/40], Step [4/4], Loss: 1.7121
# Epoch [4/40], Step [1/4], Loss: 0.3896
# Epoch [4/40], Step [2/4], Loss: 0.4099
# Epoch [4/40], Step [3/4], Loss: 0.5630
# Epoch [4/40], Step [4/4], Loss: 0.9934
# Epoch [5/40], Step [1/4], Loss: 1.0408
# Epoch [5/40], Step [2/4], Loss: 0.5522
# Epoch [5/40], Step [3/4], Loss: 0.4977
# Epoch [5/40], Step [4/4], Loss: 0.5492
# Epoch [6/40], Step [1/4], Loss: 0.3971
# Epoch [6/40], Step [2/4], Loss: 0.4428
# Epoch [6/40], Step [3/4], Loss: 0.7824
# Epoch [6/40], Step [4/4], Loss: 0.8821
# Epoch [35/40], Step [3/4], Loss: 0.3684
# Epoch [35/40], Step [4/4], Loss: 0.5068
# Epoch [36/40], Step [1/4], Loss: 0.3468
# Epoch [36/40], Step [2/4], Loss: 0.2857
# Epoch [36/40], Step [3/4], Loss: 0.3381
# Epoch [36/40], Step [4/4], Loss: 0.4798
# Epoch [37/40], Step [1/4], Loss: 0.2896
# Epoch [37/40], Step [2/4], Loss: 0.2597
# Epoch [37/40], Step [3/4], Loss: 0.3811
# Epoch [37/40], Step [4/4], Loss: 0.5953
# Epoch [38/40], Step [1/4], Loss: 0.2492
# Epoch [38/40], Step [2/4], Loss: 0.3303
# Epoch [38/40], Step [3/4], Loss: 0.2603
# Epoch [38/40], Step [4/4], Loss: 0.8619
# Epoch [39/40], Step [1/4], Loss: 0.3478
# Epoch [39/40], Step [2/4], Loss: 0.2716
# Epoch [39/40], Step [3/4], Loss: 0.3448
# Epoch [39/40], Step [4/4], Loss: 0.4593
# Epoch [40/40], Step [1/4], Loss: 0.2817
# Epoch [40/40], Step [2/4], Loss: 0.2064
# Epoch [40/40], Step [3/4], Loss: 0.3991
# Epoch [40/40], Step [4/4], Loss: 0.7044
#  Time for training is 446.3086 ms
# The loss of M_trained is 0.2333, round 240
# The loss of M_current is 0.2220, round 240
# Parameter containing:
# tensor([[ 9.3626e-01, -9.4665e-03,  1.0092e+02],
#         [-3.3551e-02,  1.0073e+00,  4.4115e+01],
#         [-1.7829e-05,  1.7896e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
#  Time for blending is 0.8145, round is 240
#  Time for blending is 0.3060, round is 241
#  Time for blending is 0.3717, round is 242
#  Time for blending is 0.3176, round is 243
#  Time for blending is 0.3088, round is 244
#  Time for blending is 0.2961, round is 245
#  Time for blending is 0.3102, round is 246
#  Time for blending is 0.2959, round is 247
#  Time for blending is 0.3106, round is 248
#  Time for blending is 0.2960, round is 249
#  Time for blending is 0.3082, round is 250
#  Time for blending is 0.3137, round is 251
#  Time for blending is 0.2941, round is 252
#  Time for blending is 0.2946, round is 253
#  Time for blending is 0.3116, round is 254
#  Time for blending is 0.3101, round is 255
#  Time for blending is 0.3127, round is 256
#  Time for blending is 0.3097, round is 257
#  Time for blending is 0.3127, round is 258
#  Time for blending is 0.3267, round is 259
#  Time for blending is 0.3127, round is 260
#  Time for blending is 0.3109, round is 261
#  Time for blending is 0.3097, round is 262
#  Time for blending is 0.3110, round is 263
#  Time for blending is 0.3096, round is 264
#  Time for blending is 0.3125, round is 265
#  Time for blending is 0.3266, round is 266
#  Time for blending is 0.3098, round is 267
#  Time for blending is 0.3442, round is 268
#  Time for blending is 0.3296, round is 269
#  Time for blending is 0.3107, round is 270
#  Time for blending is 0.3229, round is 271
#  Time for blending is 0.3260, round is 272
#  Time for blending is 0.3304, round is 273
#  Time for blending is 0.3267, round is 274
#  Time for blending is 0.3109, round is 275
#  Time for blending is 0.3148, round is 276
#  Time for blending is 0.3074, round is 277
#  Time for blending is 0.3110, round is 278
#  Time for blending is 0.3270, round is 279
#  Time for blending is 0.2979, round is 280
#  Time for blending is 0.3028, round is 281
#  Time for blending is 0.3123, round is 282
#  Time for blending is 0.3103, round is 283
#  Time for blending is 0.2961, round is 284
#  Time for blending is 0.3105, round is 285
#  Time for blending is 0.3232, round is 286
#  Time for blending is 0.3277, round is 287
#  Time for blending is 0.3106, round is 288
#  Time for blending is 0.3129, round is 289
#  Time for blending is 0.3100, round is 290
#  Time for blending is 0.2995, round is 291
#  Time for blending is 0.3389, round is 292
#  Time for blending is 0.3145, round is 293
#  Time for blending is 0.3094, round is 294
#  Time for blending is 0.3124, round is 295
#  Time for blending is 0.3121, round is 296
#  Time for blending is 0.3072, round is 297
#  Time for blending is 0.3120, round is 298
#  Time for blending is 0.2970, round is 299
# Time for matching is 3.0142, round is 300
# Epoch [1/40], Step [1/4], Loss: 0.2079
# Epoch [1/40], Step [2/4], Loss: 3.4285
# Epoch [1/40], Step [3/4], Loss: 0.5003
# Epoch [1/40], Step [4/4], Loss: 1.1845
# Epoch [2/40], Step [1/4], Loss: 1.7302
# Epoch [2/40], Step [2/4], Loss: 1.5672
# Epoch [2/40], Step [3/4], Loss: 0.5593
# Epoch [2/40], Step [4/4], Loss: 0.4023
# Epoch [3/40], Step [1/4], Loss: 0.6899
# Epoch [3/40], Step [2/4], Loss: 1.0174
# Epoch [3/40], Step [3/4], Loss: 0.9765
# Epoch [3/40], Step [4/4], Loss: 1.0153
# Epoch [4/40], Step [1/4], Loss: 0.2680
# Epoch [4/40], Step [2/4], Loss: 0.3465
# Epoch [4/40], Step [3/4], Loss: 0.6174
# Epoch [4/40], Step [4/4], Loss: 0.9982
# Epoch [5/40], Step [1/4], Loss: 0.6455
# Epoch [5/40], Step [2/4], Loss: 0.4286
# Epoch [5/40], Step [3/4], Loss: 0.2062
# Epoch [5/40], Step [4/4], Loss: 0.5069
# Epoch [6/40], Step [1/4], Loss: 0.4990
# Epoch [6/40], Step [2/4], Loss: 0.6990
# Epoch [6/40], Step [3/4], Loss: 0.4014
# Epoch [6/40], Step [4/4], Loss: 0.5096
# Epoch [7/40], Step [1/4], Loss: 0.1740
# Epoch [7/40], Step [2/4], Loss: 0.3909
# Epoch [7/40], Step [3/4], Loss: 0.4775
# Epoch [7/40], Step [4/4], Loss: 0.5304
# Epoch [8/40], Step [1/4], Loss: 0.4712
# Epoch [8/40], Step [2/4], Loss: 0.2911
# Epoch [8/40], Step [3/4], Loss: 0.2706
# Epoch [8/40], Step [4/4], Loss: 0.2544
# Epoch [9/40], Step [1/4], Loss: 0.3394
# Epoch [9/40], Step [2/4], Loss: 0.4264
# Epoch [9/40], Step [3/4], Loss: 0.3342
# Epoch [9/40], Step [4/4], Loss: 0.2659
# Epoch [10/40], Step [1/4], Loss: 0.2824
# Epoch [10/40], Step [2/4], Loss: 0.3658
# Epoch [10/40], Step [3/4], Loss: 0.2561
# Epoch [10/40], Step [4/4], Loss: 0.4361
# Epoch [11/40], Step [1/4], Loss: 0.3690
# Epoch [11/40], Step [2/4], Loss: 0.2487
# Epoch [11/40], Step [3/4], Loss: 0.2833
# Epoch [11/40], Step [4/4], Loss: 0.3859
# Epoch [40/40], Step [3/4], Loss: 0.1975
# Epoch [40/40], Step [4/4], Loss: 0.2387
#  Time for training is 468.8623 ms
# The loss of M_trained is 0.2675, round 300
# The loss of M_current is 0.3237, round 300
# Parameter containing:
# tensor([[ 9.3625e-01, -9.4944e-03,  1.0092e+02],
#         [-3.3535e-02,  1.0073e+00,  4.4115e+01],
#         [-1.9048e-05,  2.0613e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.2675
#  Time for blending is 0.3075, round is 300
#  Time for blending is 0.3130, round is 301
#  Time for blending is 0.3264, round is 302
#  Time for blending is 0.3123, round is 303
#  Time for blending is 0.3261, round is 304
#  Time for blending is 0.3286, round is 305
#  Time for blending is 0.3279, round is 306
#  Time for blending is 0.3262, round is 307
#  Time for blending is 0.3118, round is 308
#  Time for blending is 0.3276, round is 309
#  Time for blending is 0.3095, round is 310
#  Time for blending is 0.3106, round is 311
#  Time for blending is 0.3137, round is 312
#  Time for blending is 0.3078, round is 313
#  Time for blending is 0.3126, round is 314
#  Time for blending is 0.3101, round is 315
#  Time for blending is 0.3095, round is 316
#  Time for blending is 0.3136, round is 317
#  Time for blending is 0.3111, round is 318
#  Time for blending is 0.3119, round is 319
#  Time for blending is 0.3077, round is 320
#  Time for blending is 0.2977, round is 321
#  Time for blending is 0.3107, round is 322
#  Time for blending is 0.3020, round is 323
#  Time for blending is 0.3053, round is 324
#  Time for blending is 0.3075, round is 325
#  Time for blending is 0.3135, round is 326
#  Time for blending is 0.3230, round is 327
#  Time for blending is 0.3148, round is 328
#  Time for blending is 0.3108, round is 329
#  Time for blending is 0.3084, round is 330
#  Time for blending is 0.3127, round is 331
#  Time for blending is 0.3113, round is 332
#  Time for blending is 0.3127, round is 333
#  Time for blending is 0.3093, round is 334
#  Time for blending is 0.3129, round is 335
#  Time for blending is 0.3105, round is 336
#  Time for blending is 0.3107, round is 337
#  Time for blending is 0.3130, round is 338
#  Time for blending is 0.3110, round is 339
#  Time for blending is 0.3105, round is 340
#  Time for blending is 0.3133, round is 341
#  Time for blending is 0.3264, round is 342
#  Time for blending is 0.3289, round is 343
#  Time for blending is 0.3111, round is 344
#  Time for blending is 0.3113, round is 345
#  Time for blending is 0.3279, round is 346
#  Time for blending is 0.3273, round is 347
#  Time for blending is 0.3107, round is 348
#  Time for blending is 0.3108, round is 349
#  Time for blending is 0.3095, round is 350
#  Time for blending is 0.2983, round is 351
#  Time for blending is 0.3099, round is 352
#  Time for blending is 0.3085, round is 353
#  Time for blending is 0.2964, round is 354
#  Time for blending is 0.3126, round is 355
#  Time for blending is 0.3104, round is 356
#  Time for blending is 0.3174, round is 357
#  Time for blending is 0.3006, round is 358
#  Time for blending is 0.3197, round is 359
# Time for matching is 3.0465, round is 360
# Epoch [1/40], Step [1/4], Loss: 0.2265
# Epoch [1/40], Step [2/4], Loss: 3.2839
# Epoch [1/40], Step [3/4], Loss: 0.4823
# Epoch [1/40], Step [4/4], Loss: 1.0471
# Epoch [2/40], Step [1/4], Loss: 2.1565
# Epoch [2/40], Step [2/4], Loss: 1.4174
# Epoch [2/40], Step [3/4], Loss: 0.5022
# Epoch [32/40], Step [3/4], Loss: 0.3480
# Epoch [32/40], Step [4/4], Loss: 0.1344
# Epoch [33/40], Step [1/4], Loss: 0.1407
# Epoch [33/40], Step [2/4], Loss: 0.3027
# Epoch [33/40], Step [3/4], Loss: 0.3361
# Epoch [33/40], Step [4/4], Loss: 0.2375
# Epoch [34/40], Step [1/4], Loss: 0.3132
# Epoch [34/40], Step [2/4], Loss: 0.2962
# Epoch [34/40], Step [3/4], Loss: 0.1970
# Epoch [34/40], Step [4/4], Loss: 0.2276
# Epoch [35/40], Step [1/4], Loss: 0.3336
# Epoch [35/40], Step [2/4], Loss: 0.2802
# Epoch [35/40], Step [3/4], Loss: 0.2287
# Epoch [35/40], Step [4/4], Loss: 0.1985
# Epoch [36/40], Step [1/4], Loss: 0.2491
# Epoch [36/40], Step [2/4], Loss: 0.2394
# Epoch [36/40], Step [3/4], Loss: 0.2511
# Epoch [36/40], Step [4/4], Loss: 0.2692
# Epoch [37/40], Step [1/4], Loss: 0.1961
# Epoch [37/40], Step [2/4], Loss: 0.3638
# Epoch [37/40], Step [3/4], Loss: 0.2294
# Epoch [37/40], Step [4/4], Loss: 0.2291
# Epoch [38/40], Step [1/4], Loss: 0.1956
# Epoch [38/40], Step [2/4], Loss: 0.3274
# Epoch [38/40], Step [3/4], Loss: 0.1902
# Epoch [38/40], Step [4/4], Loss: 0.2910
# Epoch [39/40], Step [1/4], Loss: 0.2075
# Epoch [39/40], Step [2/4], Loss: 0.2204
# Epoch [39/40], Step [3/4], Loss: 0.2246
# Epoch [39/40], Step [4/4], Loss: 0.3306
# Epoch [40/40], Step [1/4], Loss: 0.1749
# Epoch [40/40], Step [2/4], Loss: 0.2338
# Epoch [40/40], Step [3/4], Loss: 0.3652
# Epoch [40/40], Step [4/4], Loss: 0.2098
#  Time for training is 516.8915 ms
# The loss of M_trained is 0.3477, round 900
# The loss of M_current is 0.3426, round 900
# Parameter containing:
# tensor([[ 9.3625e-01, -9.4539e-03,  1.0092e+02],
#         [-3.3504e-02,  1.0074e+00,  4.4115e+01],
#         [-1.8471e-05,  1.9549e-05,  9.9999e-01]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
#  Time for blending is 0.3127, round is 900
#  Time for blending is 0.3134, round is 901
#  Time for blending is 0.3171, round is 902
#  Time for blending is 0.2849, round is 903
#  Time for blending is 0.3011, round is 904
#  Time for blending is 0.3171, round is 905
#  Time for blending is 0.3172, round is 906
#  Time for blending is 0.3166, round is 907
#  Time for blending is 0.3338, round is 908
#  Time for blending is 0.3050, round is 909
#  Time for blending is 0.2904, round is 910
#  Time for blending is 0.3021, round is 911
#  Time for blending is 0.3007, round is 912
#  Time for blending is 0.3016, round is 913
#  Time for blending is 0.3014, round is 914
#  Time for blending is 0.3015, round is 915
#  Time for blending is 0.3058, round is 916
#  Time for blending is 0.3044, round is 917
#  Time for blending is 0.3010, round is 918
#  Time for blending is 0.3219, round is 919
#  Time for blending is 0.3168, round is 920
#  Time for blending is 0.3125, round is 921
#  Time for blending is 0.3180, round is 922
#  Time for blending is 0.3014, round is 923
#  Time for blending is 0.3511, round is 924
#  Time for blending is 0.3044, round is 925
#  Time for blending is 0.3012, round is 926
#  Time for blending is 0.3011, round is 927
#  Time for blending is 0.3013, round is 928
#  Time for blending is 0.3245, round is 929
#  Time for blending is 0.3166, round is 930
#  Time for blending is 0.3336, round is 931
#  Time for blending is 0.3389, round is 932
#  Time for blending is 0.3323, round is 933
#  Time for blending is 0.3172, round is 934
#  Time for blending is 0.3168, round is 935
#  Time for blending is 0.3167, round is 936
#  Time for blending is 0.3168, round is 937
#  Time for blending is 0.2982, round is 938
#  Time for blending is 0.3157, round is 939
#  Time for blending is 0.3032, round is 940
#  Time for blending is 0.3011, round is 941
#  Time for blending is 0.3012, round is 942
#  Time for blending is 0.3171, round is 943

# %%
import torch
import torch.optim as optim
from torch import nn
import torch.utils.data as Data

cap1=cv2.VideoCapture('C:/Users/Jackie/Downloads/0122_1.MP4')
cap2=cv2.VideoCapture('C:/Users/Jackie/Downloads/0122_2.MP4')
count=cap1.get(cv2.CAP_PROP_FRAME_COUNT)
fps=cap1.get(cv2.CAP_PROP_FPS)
size=(int(cap1.get(cv2.CAP_PROP_FRAME_WIDTH)*2),int(cap1.get(cv2.CAP_PROP_FRAME_HEIGHT)))
video=cv2.VideoWriter('C:/Users/Jackie/Downloads/122_improved_blending_maskrate240.MP4',cv2.VideoWriter_fourcc('I','4','2','0'),fps,size)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")



maxL = 200
maxR = 200

if cap1.isOpened() and cap2.isOpened():
    i=1
    print('successful')
    print("The count is %d" %(count))
    #image size paremeters
    
        
    ret1,frame1=cap1.read()
    ret2,frame2=cap2.read()
    H=frame1.shape[0]
    W_remap=int(194/180*H)
    W=frame1.shape[1]+frame2.shape[1]
    templ_shape = (60, 16)
    offsetYL = int(160/1280*H)
    offsetYR = int(160/1280*H)
    #print(W_remap)
    #remap
    xmap, ymap, p = buildmap(Ws=W_remap, Hs=H, Wd=H, Hd=H, fov=194)
    #cam2 = cv2.remap(frame[:, :H], xmap, ymap, cv2.INTER_LINEAR)
    #cam1 = cv2.remap(frame[:, H:], xmap, ymap, cv2.INTER_LINEAR)
    cam1 = cv2.remap(frame1, xmap, ymap, cv2.INTER_LINEAR)
    cam2 = cv2.remap(frame2, xmap, ymap, cv2.INTER_LINEAR)
    
    #shift
    cam1_gray = cv2.cvtColor(cam1, cv2.COLOR_BGR2GRAY)
    cam2_gray = cv2.cvtColor(cam2, cv2.COLOR_BGR2GRAY)
    shifted_cams = np.zeros((H * 2, W, 3), np.uint8)
    shifted_cams[H:, int((W - W_remap) / 2):int((W + W_remap) / 2)] = cam1
    shifted_cams[:H, :int(W_remap / 2)] = cam2[:, int(W_remap / 2):]
    shifted_cams[:H, W - int(W_remap / 2):] = cam2[:, :int(W_remap / 2)]
    
    #cv2.imwrite('video_shift.jpg', shifted_cams)
    #matching
    
    maxL = 200
    maxR = 200
    b_matching=time.time()
    matchesL = getMatches_goodtemplmatch(
                    cam1_gray[offsetYL:H - offsetYL, int(W / 2):],
                    cam2_gray[offsetYL:H - offsetYL, :W_remap - int(W / 2)],
                    templ_shape, maxL)
    matchesR = getMatches_goodtemplmatch(
                    cam2_gray[offsetYR:H - offsetYR, int(W / 2):],
                    cam1_gray[offsetYR:H - offsetYR, :W_remap - int(W / 2)],
                    templ_shape, maxR)
    matchesR = matchesR[:, -1::-1]
    matchesL = matchesL + (int((W - W_remap) / 2), offsetYL)
    matchesR = matchesR + (int((W - W_remap) / 2) + int(W / 2), offsetYR)
    zipped_matches = list(zip(matchesL, matchesR))
    matches = np.int32([e for i in zipped_matches for e in i])
    pts1 = matches[:, 0]
    pts2 = matches[:, 1]
    
    #homography
    M_current, status = cv2.findHomography(pts2, pts1, cv2.RANSAC, 4.0)
    
    top, bottom = verticalBoundary(M_current, W_remap, W, H)
    warped2 = cv2.warpPerspective(shifted_cams[H:], M_current, (W, H))
    warped1 = shifted_cams[0:H,:]
    warped1 = cv2.resize(warped1[top:bottom], (W, H))
    warped2 = cv2.resize(warped2[top:bottom], (W, H))
    EAof2 = np.zeros((H, W, 3), np.uint8)
    EAof2[:, int((W - W_remap) / 2) + 1:int((W + W_remap) / 2) - 1] = 255
    EAof2 = cv2.warpPerspective(EAof2, M_current, (W, H))
    
    #blend
    b_blend=time.time()
    W_lbl = 120
    blend_level = 4
    
    mask, minloc_old = imgLabeling(
                warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                (W, H), int(W_remap / 2) - W_lbl, W - int(W_remap / 2))
    
    warped1[:, int(W_remap / 2):W - int(W_remap /
                2)] = warped2[:, int(W_remap / 2):W - int(W_remap / 2)]
    warped2[EAof2 == 0] = warped1[EAof2 == 0]
    '''
    blended = multi_band_blending(
                    warped1, warped2, mask, blend_level)
    '''
    blended_l = multi_band_blending(
                    warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    mask[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    blend_level)
    blended_r = multi_band_blending(
                    warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    mask[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    blend_level)
    blended = np.ones((H,W,3))
    blended[:, 0:int(W_remap / 2) - W_lbl] = warped1[:, 0:int(W_remap / 2) - W_lbl]
    blended[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)] = blended_l
    blended[:,int(W_remap / 2):W - int(W_remap / 2)] = warped2[:,int(W_remap / 2):W - int(W_remap / 2)]
    blended[:,W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl] = blended_r
    blended[:,W - int(W_remap / 2) + W_lbl:] = warped1[:,W - int(W_remap / 2) + W_lbl:]
    e_blend=time.time()
    #print("Time for blending is %.4f" %(e_blend-b_blend))
    video.write(blended.astype(np.uint8))
    #cv2.imwrite('video_blending.jpg', blended.astype(np.uint8))
    #FCN
    epochs=40
    index=np.where(status.ravel()==1)
    inliers=matches[index[0]]
    train,label = deduplication(inliers)
    zipped_train = list(zip(train, label))
    dataset = np.int32([e for e in zipped_train])
    np.random.shuffle(dataset)
    train = dataset[:, 0]
    label = dataset[:, 1]
    b_test = np.ones(int(train[int(train.shape[0]*0.8):].shape[0]))
    test = np.insert(train[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
    label_test = np.insert(label[int(train.shape[0]*0.8):], 2, values=b_test, axis=1)
    M = torch.tensor(M_current,requires_grad=True)
    #M_best = torch.tensor(M_best,requires_grad=True)
    model = nn.Linear(3,3,bias=False)
    model.weight =nn.Parameter(M)
    criterion = nn.MSELoss()
    test = torch.tensor(test,requires_grad=False,dtype=torch.float64)
    label_test = torch.tensor(label_test,requires_grad=False,dtype=torch.float64)
    
    test_output = model(test)
    test_output = test_output/test_output[:,2].reshape(-1,1)
    best_loss = criterion(test_output,label_test)/label_test.shape[0]
    
    print("The loss for frame1 is %.4f" %(best_loss))
    #print("The loss of M_best for frame1 is %.4f" %(loss_test_b))
    shape_list = []
    shape_list.append(inliers.shape[0])
    #M_best = M_best.to(device)
    while i<count:
        i+=1
        ret1,frame1=cap1.read()
        ret2,frame2=cap2.read()
        
        if ret1 and ret2:
            
            cam1 = cv2.remap(frame1, xmap, ymap, cv2.INTER_LINEAR)
            cam2 = cv2.remap(frame2, xmap, ymap, cv2.INTER_LINEAR)
            
            #shift
                
            shifted_cams = np.zeros((H * 2, W, 3), np.uint8)
            shifted_cams[H:, int((W - W_remap) / 2):int((W + W_remap) / 2)] = cam1
            shifted_cams[:H, :int(W_remap / 2)] = cam2[:, int(W_remap / 2):]
            shifted_cams[:H, W - int(W_remap / 2):] = cam2[:, :int(W_remap / 2)]
            if len(shape_list)%4==0:
                inliers = np.delete(inliers, range(0,shape_list[0]),axis = 0)
                del(shape_list[0])
             
            if i%60==0:
                cam1_gray = cv2.cvtColor(cam1, cv2.COLOR_BGR2GRAY)
                cam2_gray = cv2.cvtColor(cam2, cv2.COLOR_BGR2GRAY)
                b_matching=time.time()
                matchesL = getMatches_goodtemplmatch(
                    cam1_gray[offsetYL:H - offsetYL, int(W / 2):],
                    cam2_gray[offsetYL:H - offsetYL, :W_remap - int(W / 2)],
                    templ_shape, maxL)
                matchesR = getMatches_goodtemplmatch(
                    cam2_gray[offsetYR:H - offsetYR, int(W / 2):],
                    cam1_gray[offsetYR:H - offsetYR, :W_remap - int(W / 2)],
                    templ_shape, maxR)
                matchesR = matchesR[:, -1::-1]
                matchesL = matchesL + (int((W - W_remap) / 2), offsetYL)
                matchesR = matchesR + (int((W - W_remap) / 2) + int(W / 2), offsetYR)
                zipped_matches = list(zip(matchesL, matchesR))
                matches_append = np.int32([e for i in zipped_matches for e in i])
                pts1 = matches_append[:, 0]
                pts2 = matches_append[:, 1]
                
                
                e_matching=time.time()
                print("Time for matching is %.4f, round is %d" %((e_matching-b_matching),i) )
                M_, status = cv2.findHomography(pts2, pts1, cv2.RANSAC, 4.0)
                index=np.where(status.ravel()==1)
      
                inliers = np.concatenate((inliers,matches_append[index[0]]),axis=0)
                shape_list.append(matches_append[index[0]].shape[0])
                
        
                train,label = deduplication(inliers)
                zipped_train = list(zip(train, label))
                dataset = np.int32([e for e in zipped_train])
                np.random.shuffle(dataset)
                train = dataset[:, 0]
                label = dataset[:, 1]
                
                b_test = np.ones(int(train[int(train.shape[0]*0.8):].shape[0]))
                test = np.insert(train[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
                label_test = np.insert(label[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
                b=np.ones(int(train.shape[0]*0.8))
                train = np.insert(train[:int(train.shape[0]*0.8)], 2, values=b, axis=1) 
                label = np.insert(label[:int(label.shape[0]*0.8)], 2, values=b, axis=1) 
                
                M = torch.tensor(M_current,requires_grad=True)
                model = nn.Linear(3,3,bias=False)
                model.weight =nn.Parameter(M)
                model.to(device)
                criterion = nn.MSELoss()
                optimizer = torch.optim.Adam(model.parameters(), lr=0.000001)
                #optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
    
                #M = torch.tensor(M,requires_grad=True)
                inputs = torch.tensor(train,requires_grad=False,dtype=torch.float64)
                inputs = inputs.to(device)
                label_t = torch.tensor(label,requires_grad=False,dtype=torch.float64)
                label_t = label_t.to(device)
                test = torch.tensor(test,requires_grad=False,dtype=torch.float64)
                test = test.to(device)
                label_test = torch.tensor(label_test,requires_grad=False,dtype=torch.float64)
                label_test = label_test.to(device)
                torch_dataset = Data.TensorDataset(inputs, label_t)

                loader = Data.DataLoader(
                                dataset=torch_dataset,      
                                batch_size=64,      
                                shuffle=True,               
                                num_workers=0,)
                total_step = len(loader)
                t_s = time.time()
                for epoch in range(epochs):
                    for step, (batch_x, l) in enumerate(loader):
                        #batch_x, l = batch_x.to(device),l.to(device)
                        outputs = model(batch_x)
                        outputs = outputs/outputs[:,2].reshape(-1,1)
                        loss = criterion(outputs,l)
                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()
                        print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch+1, epochs, step+1, total_step, loss.item()/len(batch_x)))
                t_e = time.time()
                print(" Time for training is %.4f ms" %((t_e-t_s)*1000))
                test_output = model(test)
                test_output = test_output/test_output[:,2].reshape(-1,1)
                loss_test = criterion(test_output,label_test)/label_test.shape[0]
                
                M_c = torch.tensor(M_current,requires_grad=True)
                model_c = nn.Linear(3,3,bias=False)
                model_c.weight =nn.Parameter(M_c)
                model_c.to(device)
                current_test = model_c(test)
                current_test = current_test/current_test[:,2].reshape(-1,1)
                current_loss = criterion(current_test,label_test)/label_test.shape[0]
                
                print("The loss of M_trained is %.4f, round %d" %(loss_test,i))
                print("The loss of M_current is %.4f, round %d" %(current_loss,i))
                print(model.weight)
                
                if loss_test<current_loss:
                    model = model.cpu()
                    M_current = model.weight.detach().numpy()
                    M_current = M_current/M_current[2][2]
                    best_loss = loss_test
                    print("The best loss is %.4f" %(best_loss))
            
            top, bottom = verticalBoundary(M_current, W_remap, W, H)
            warped2 = cv2.warpPerspective(shifted_cams[H:], M_current, (W, H))
            warped1 = shifted_cams[0:H,:]
            warped1 = cv2.resize(warped1[top:bottom], (W, H))
            warped2 = cv2.resize(warped2[top:bottom], (W, H))
            EAof2 = np.zeros((H, W, 3), np.uint8)
            EAof2[:, int((W - W_remap) / 2) + 1:int((W + W_remap) / 2) - 1] = 255
            EAof2 = cv2.warpPerspective(EAof2, M_current, (W, H))
            b_blend=time.time()
            
            if i%240==0:
                mask, minloc_old = imgLabeling(
                warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                (W, H), int(W_remap / 2) - W_lbl, W - int(W_remap / 2))
            
            
            
            warped1[:, int(W_remap / 2):W - int(W_remap /
                        2)] = warped2[:, int(W_remap / 2):W - int(W_remap / 2)]
            warped2[EAof2 == 0] = warped1[EAof2 == 0]
            '''
            blended = multi_band_blending(
                                warped1, warped2, mask, blend_level)
            '''
            #blended = warped1 * mask + warped2 * (1 - mask)
            blended_l = multi_band_blending(
                    warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    mask[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    blend_level)
            blended_r = multi_band_blending(
                    warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    mask[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    blend_level)
            blended = np.ones((H,W,3))
            blended[:, 0:int(W_remap / 2) - W_lbl] = warped1[:, 0:int(W_remap / 2) - W_lbl]
            blended[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)] = blended_l
            blended[:,int(W_remap / 2):W - int(W_remap / 2)] = warped2[:,int(W_remap / 2):W - int(W_remap / 2)]
            blended[:,W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl] = blended_r
            blended[:,W - int(W_remap / 2) + W_lbl:] = warped1[:,W - int(W_remap / 2) + W_lbl:]
            video.write(blended.astype(np.uint8))
            e_blend=time.time()
            print(" Time for blending is %.4f, round is %d" %((e_blend-b_blend),i) )
      
        else:   
            break
    
else:
    print('fail')
cap1.release()
cap2.release()
video.release()
# Out:
# successful
# The count is 943
# The loss for frame1 is 0.0421
#  Time for blending is 0.3495, round is 2
#  Time for blending is 0.3383, round is 3
#  Time for blending is 0.3079, round is 4
#  Time for blending is 0.3351, round is 5
#  Time for blending is 0.3189, round is 6
#  Time for blending is 0.3244, round is 7
#  Time for blending is 0.3228, round is 8
#  Time for blending is 0.3151, round is 9
#  Time for blending is 0.3117, round is 10
#  Time for blending is 0.3151, round is 11
#  Time for blending is 0.3153, round is 12
#  Time for blending is 0.3135, round is 13
#  Time for blending is 0.3096, round is 14
#  Time for blending is 0.3158, round is 15
#  Time for blending is 0.3204, round is 16
#  Time for blending is 0.3310, round is 17
#  Time for blending is 0.3208, round is 18
#  Time for blending is 0.3269, round is 19
#  Time for blending is 0.3279, round is 20
#  Time for blending is 0.3154, round is 21
#  Time for blending is 0.3285, round is 22
#  Time for blending is 0.3319, round is 23
#  Time for blending is 0.3283, round is 24
#  Time for blending is 0.3302, round is 25
#  Time for blending is 0.3133, round is 26
#  Time for blending is 0.3075, round is 27
#  Time for blending is 0.3053, round is 28
#  Time for blending is 0.3185, round is 29
#  Time for blending is 0.3239, round is 30
#  Time for blending is 0.3150, round is 31
#  Time for blending is 0.3286, round is 32
#  Time for blending is 0.3137, round is 33
#  Time for blending is 0.3131, round is 34
#  Time for blending is 0.3054, round is 35
#  Time for blending is 0.3236, round is 36
#  Time for blending is 0.3079, round is 37
#  Time for blending is 0.3332, round is 38
#  Time for blending is 0.3204, round is 39
#  Time for blending is 0.3419, round is 40
#  Time for blending is 0.3124, round is 41
#  Time for blending is 0.3276, round is 42
#  Time for blending is 0.3311, round is 43
#  Time for blending is 0.2982, round is 44
#  Time for blending is 0.2979, round is 45
#  Time for blending is 0.3304, round is 46
#  Time for blending is 0.3108, round is 47
#  Time for blending is 0.3227, round is 48
#  Time for blending is 0.3219, round is 49
#  Time for blending is 0.3197, round is 50
#  Time for blending is 0.3045, round is 51
#  Time for blending is 0.3098, round is 52
#  Time for blending is 0.3279, round is 53
#  Time for blending is 0.3326, round is 54
#  Time for blending is 0.3134, round is 55
#  Time for blending is 0.3279, round is 56
#  Time for blending is 0.3164, round is 57
#  Time for blending is 0.3280, round is 58
#  Time for blending is 0.3336, round is 59
# Time for matching is 3.1989, round is 60
# Epoch [1/40], Step [1/4], Loss: 0.0685
# Epoch [1/40], Step [2/4], Loss: 1.4946
# Epoch [1/40], Step [3/4], Loss: 0.1624
# Epoch [1/40], Step [4/4], Loss: 0.2882
# Epoch [2/40], Step [1/4], Loss: 0.8503
# Epoch [2/40], Step [2/4], Loss: 1.0833
# Epoch [2/40], Step [3/4], Loss: 0.5324
# Epoch [2/40], Step [4/4], Loss: 0.0504
# Epoch [3/40], Step [1/4], Loss: 0.2071
# Epoch [3/40], Step [2/4], Loss: 0.4890
# Epoch [3/40], Step [3/4], Loss: 0.5366
# Epoch [3/40], Step [4/4], Loss: 0.5369
# Epoch [4/40], Step [1/4], Loss: 0.1827
# Epoch [4/40], Step [2/4], Loss: 0.0579
# Epoch [4/40], Step [3/4], Loss: 0.1034
# Epoch [4/40], Step [4/4], Loss: 0.4356
# Epoch [5/40], Step [1/4], Loss: 0.4143
# Epoch [5/40], Step [2/4], Loss: 0.1527
# Epoch [5/40], Step [3/4], Loss: 0.0654
# Epoch [5/40], Step [4/4], Loss: 0.0817
# Epoch [6/40], Step [1/4], Loss: 0.0748
# Epoch [6/40], Step [2/4], Loss: 0.1908
# Epoch [6/40], Step [3/4], Loss: 0.2165
# Epoch [6/40], Step [4/4], Loss: 0.2006
# Epoch [7/40], Step [1/4], Loss: 0.0732
# Epoch [7/40], Step [2/4], Loss: 0.0602
# Epoch [7/40], Step [3/4], Loss: 0.0544
# Epoch [7/40], Step [4/4], Loss: 0.1476
# Epoch [8/40], Step [1/4], Loss: 0.1093
# Epoch [8/40], Step [2/4], Loss: 0.1367
# Epoch [8/40], Step [3/4], Loss: 0.0493
# Epoch [8/40], Step [4/4], Loss: 0.0678
# Epoch [9/40], Step [1/4], Loss: 0.0496
# Epoch [9/40], Step [2/4], Loss: 0.0814
# Epoch [38/40], Step [1/4], Loss: 0.0426
# Epoch [38/40], Step [2/4], Loss: 0.0515
# Epoch [38/40], Step [3/4], Loss: 0.0469
# Epoch [38/40], Step [4/4], Loss: 0.0889
# Epoch [39/40], Step [1/4], Loss: 0.0520
# Epoch [39/40], Step [2/4], Loss: 0.0354
# Epoch [39/40], Step [3/4], Loss: 0.0630
# Epoch [39/40], Step [4/4], Loss: 0.0606
# Epoch [40/40], Step [1/4], Loss: 0.0728
# Epoch [40/40], Step [2/4], Loss: 0.0366
# Epoch [40/40], Step [3/4], Loss: 0.0380
# Epoch [40/40], Step [4/4], Loss: 0.0656
#  Time for training is 466.6152 ms
# The loss of M_trained is 0.0626, round 60
# The loss of M_current is 0.0769, round 60
# Parameter containing:
# tensor([[ 9.9014e-01, -1.2301e-02,  3.5325e+01],
#         [-8.9596e-03,  9.9562e-01,  2.4160e+01],
#         [-2.1193e-06, -1.7589e-07,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.0626
#  Time for blending is 0.3077, round is 60
#  Time for blending is 0.3053, round is 61
#  Time for blending is 0.3059, round is 62
#  Time for blending is 0.3125, round is 63
#  Time for blending is 0.3149, round is 64
#  Time for blending is 0.3128, round is 65
#  Time for blending is 0.3001, round is 66
#  Time for blending is 0.3136, round is 67
#  Time for blending is 0.3119, round is 68
#  Time for blending is 0.3058, round is 69
#  Time for blending is 0.3069, round is 70
#  Time for blending is 0.3332, round is 71
#  Time for blending is 0.2889, round is 72
#  Time for blending is 0.3256, round is 73
#  Time for blending is 0.3154, round is 74
#  Time for blending is 0.2981, round is 75
#  Time for blending is 0.3134, round is 76
#  Time for blending is 0.2984, round is 77
#  Time for blending is 0.3250, round is 78
#  Time for blending is 0.3253, round is 79
#  Time for blending is 0.3223, round is 80
#  Time for blending is 0.3062, round is 81
#  Time for blending is 0.3631, round is 82
#  Time for blending is 0.3189, round is 83
#  Time for blending is 0.3063, round is 84
#  Time for blending is 0.3161, round is 85
#  Time for blending is 0.3368, round is 86
#  Time for blending is 0.3018, round is 87
#  Time for blending is 0.3112, round is 88
#  Time for blending is 0.3304, round is 89
#  Time for blending is 0.3064, round is 90
#  Time for blending is 0.3266, round is 91
#  Time for blending is 0.3057, round is 92
#  Time for blending is 0.3523, round is 93
#  Time for blending is 0.3832, round is 94
#  Time for blending is 0.3255, round is 95
#  Time for blending is 0.3138, round is 96
#  Time for blending is 0.3179, round is 97
#  Time for blending is 0.3128, round is 98
#  Time for blending is 0.2898, round is 99
#  Time for blending is 0.3736, round is 100
#  Time for blending is 0.3349, round is 101
#  Time for blending is 0.3080, round is 102
#  Time for blending is 0.3109, round is 103
#  Time for blending is 0.3019, round is 104
#  Time for blending is 0.3140, round is 105
#  Time for blending is 0.3146, round is 106
#  Time for blending is 0.3180, round is 107
#  Time for blending is 0.3099, round is 108
#  Time for blending is 0.3070, round is 109
#  Time for blending is 0.3174, round is 110
#  Time for blending is 0.2986, round is 111
#  Time for blending is 0.2967, round is 112
#  Time for blending is 0.3284, round is 113
#  Time for blending is 0.3308, round is 114
#  Time for blending is 0.3283, round is 115
# Epoch [38/40], Step [4/6], Loss: 0.0463
# Epoch [38/40], Step [5/6], Loss: 0.0578
# Epoch [38/40], Step [6/6], Loss: 0.3297
# Epoch [39/40], Step [1/6], Loss: 0.0494
# Epoch [39/40], Step [2/6], Loss: 0.0593
# Epoch [39/40], Step [3/6], Loss: 0.0610
# Epoch [39/40], Step [4/6], Loss: 0.0694
# Epoch [39/40], Step [5/6], Loss: 0.0457
# Epoch [39/40], Step [6/6], Loss: 0.1518
# Epoch [40/40], Step [1/6], Loss: 0.0908
# Epoch [40/40], Step [2/6], Loss: 0.0486
# Epoch [40/40], Step [3/6], Loss: 0.0638
# Epoch [40/40], Step [4/6], Loss: 0.0511
# Epoch [40/40], Step [5/6], Loss: 0.0557
# Epoch [40/40], Step [6/6], Loss: 0.1662
#  Time for training is 603.6584 ms
# The loss of M_trained is 0.0437, round 120
# The loss of M_current is 0.0421, round 120
# Parameter containing:
# tensor([[ 9.9013e-01, -1.2310e-02,  3.5325e+01],
#         [-8.9939e-03,  9.9550e-01,  2.4159e+01],
#         [-1.9732e-06, -3.8946e-07,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
#  Time for blending is 0.3050, round is 120
#  Time for blending is 0.3181, round is 121
#  Time for blending is 0.3108, round is 122
#  Time for blending is 0.3062, round is 123
#  Time for blending is 0.3101, round is 124
#  Time for blending is 0.3219, round is 125
#  Time for blending is 0.3230, round is 126
#  Time for blending is 0.3446, round is 127
#  Time for blending is 0.3293, round is 128
#  Time for blending is 0.3296, round is 129
#  Time for blending is 0.3299, round is 130
#  Time for blending is 0.3464, round is 131
#  Time for blending is 0.3298, round is 132
#  Time for blending is 0.3310, round is 133
#  Time for blending is 0.3442, round is 134
#  Time for blending is 0.2980, round is 135
#  Time for blending is 0.3073, round is 136
#  Time for blending is 0.3298, round is 137
#  Time for blending is 0.3091, round is 138
#  Time for blending is 0.3109, round is 139
#  Time for blending is 0.3104, round is 140
#  Time for blending is 0.3008, round is 141
#  Time for blending is 0.3283, round is 142
#  Time for blending is 0.3295, round is 143
#  Time for blending is 0.3462, round is 144
#  Time for blending is 0.3327, round is 145
#  Time for blending is 0.3277, round is 146
#  Time for blending is 0.3082, round is 147
#  Time for blending is 0.3211, round is 148
#  Time for blending is 0.3220, round is 149
#  Time for blending is 0.3081, round is 150
#  Time for blending is 0.3122, round is 151
#  Time for blending is 0.3456, round is 152
#  Time for blending is 0.3277, round is 153
#  Time for blending is 0.3282, round is 154
#  Time for blending is 0.3149, round is 155
#  Time for blending is 0.3294, round is 156
#  Time for blending is 0.3300, round is 157
#  Time for blending is 0.3240, round is 158
#  Time for blending is 0.3241, round is 159
#  Time for blending is 0.3080, round is 160
#  Time for blending is 0.3039, round is 161
#  Time for blending is 0.3146, round is 162
#  Time for blending is 0.3248, round is 163
#  Time for blending is 0.3280, round is 164
#  Time for blending is 0.3304, round is 165
#  Time for blending is 0.3444, round is 166
#  Time for blending is 0.3391, round is 167
#  Time for blending is 0.3291, round is 168
#  Time for blending is 0.3472, round is 169
#  Time for blending is 0.3456, round is 170
#  Time for blending is 0.3310, round is 171
# Epoch [34/40], Step [6/7], Loss: 0.0759
# Epoch [34/40], Step [7/7], Loss: 0.1268
# Epoch [35/40], Step [1/7], Loss: 0.0715
# ...
# Epoch [36/40], Step [1/6], Loss: 0.1639
# Epoch [36/40], Step [2/6], Loss: 0.2161
# Epoch [36/40], Step [3/6], Loss: 0.1145
# Epoch [36/40], Step [4/6], Loss: 0.2958
# Epoch [36/40], Step [5/6], Loss: 0.1081
# Epoch [36/40], Step [6/6], Loss: 0.1891
# Epoch [37/40], Step [1/6], Loss: 0.2217
# Epoch [37/40], Step [2/6], Loss: 0.2435
# Epoch [37/40], Step [3/6], Loss: 0.1800
# Epoch [37/40], Step [4/6], Loss: 0.1768
# Epoch [37/40], Step [5/6], Loss: 0.0831
# Epoch [37/40], Step [6/6], Loss: 0.2446
# Epoch [38/40], Step [1/6], Loss: 0.1983
# Epoch [38/40], Step [2/6], Loss: 0.1220
# Epoch [38/40], Step [3/6], Loss: 0.1611
# Epoch [38/40], Step [4/6], Loss: 0.1591
# Epoch [38/40], Step [5/6], Loss: 0.2074
# Epoch [38/40], Step [6/6], Loss: 0.1424
# Epoch [39/40], Step [1/6], Loss: 0.1865
# Epoch [39/40], Step [2/6], Loss: 0.1606
# Epoch [39/40], Step [3/6], Loss: 0.1386
# Epoch [39/40], Step [4/6], Loss: 0.1418
# Epoch [39/40], Step [5/6], Loss: 0.1908
# Epoch [39/40], Step [6/6], Loss: 0.2597
# Epoch [40/40], Step [1/6], Loss: 0.2178
# Epoch [40/40], Step [2/6], Loss: 0.1223
# Epoch [40/40], Step [3/6], Loss: 0.1233
# Epoch [40/40], Step [4/6], Loss: 0.1559
# Epoch [40/40], Step [5/6], Loss: 0.2213
# Epoch [40/40], Step [6/6], Loss: 0.1956
#  Time for training is 481.8137 ms
# The loss of M_trained is 0.1640, round 840
# The loss of M_current is 0.1669, round 840
# Parameter containing:
# tensor([[ 9.9005e-01, -1.2376e-02,  3.5323e+01],
#         [-8.7995e-03,  9.9544e-01,  2.4158e+01],
#         [-1.8673e-06, -2.0253e-07,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.1640
#  Time for blending is 0.3087, round is 840
#  Time for blending is 0.3090, round is 841
#  Time for blending is 0.2961, round is 842
#  Time for blending is 0.3105, round is 843
#  Time for blending is 0.3100, round is 844
#  Time for blending is 0.3092, round is 845
#  Time for blending is 0.2869, round is 846
#  Time for blending is 0.3093, round is 847
#  Time for blending is 0.3287, round is 848
#  Time for blending is 0.3204, round is 849
#  Time for blending is 0.3021, round is 850
#  Time for blending is 0.3288, round is 851
#  Time for blending is 0.3466, round is 852
#  Time for blending is 0.3225, round is 853
#  Time for blending is 0.3262, round is 854
#  Time for blending is 0.3099, round is 855
#  Time for blending is 0.3077, round is 856
#  Time for blending is 0.3133, round is 857
#  Time for blending is 0.3028, round is 858
#  Time for blending is 0.3104, round is 859
#  Time for blending is 0.3872, round is 860
#  Time for blending is 0.3261, round is 861
#  Time for blending is 0.3592, round is 862
#  Time for blending is 0.3304, round is 863
#  Time for blending is 0.3268, round is 864
#  Time for blending is 0.3272, round is 865
#  Time for blending is 0.3293, round is 866
#  Time for blending is 0.3286, round is 867
#  Time for blending is 0.3086, round is 868
#  Time for blending is 0.3266, round is 869
#  Time for blending is 0.3261, round is 870
#  Time for blending is 0.3097, round is 871
#  Time for blending is 0.2958, round is 872
#  Time for blending is 0.3244, round is 873
#  Time for blending is 0.3285, round is 874
#  Time for blending is 0.3441, round is 875
#  Time for blending is 0.3077, round is 876
#  Time for blending is 0.3085, round is 877
#  Time for blending is 0.3093, round is 878
#  Time for blending is 0.3130, round is 879
#  Time for blending is 0.3228, round is 880
#  Time for blending is 0.3129, round is 881
#  Time for blending is 0.3315, round is 882
#  Time for blending is 0.3022, round is 883
#  Time for blending is 0.3205, round is 884
#  Time for blending is 0.3097, round is 885
#  Time for blending is 0.3097, round is 886
#  Time for blending is 0.3115, round is 887
#  Time for blending is 0.3277, round is 888
#  Time for blending is 0.3265, round is 889
#  Time for blending is 0.3286, round is 890
#  Time for blending is 0.3205, round is 891
#  Time for blending is 0.3077, round is 892
#  Time for blending is 0.3135, round is 893
#  Time for blending is 0.3257, round is 894
#  Time for blending is 0.3109, round is 895
#  Time for blending is 0.3116, round is 896
#  Time for blending is 0.3707, round is 897
#  Time for blending is 0.3319, round is 898
#  Time for blending is 0.3209, round is 899
# Time for matching is 3.1583, round is 900
# Epoch [1/40], Step [1/6], Loss: 0.2041
# Epoch [1/40], Step [2/6], Loss: 1.5604
# Epoch [1/40], Step [3/6], Loss: 0.3048
# Epoch [1/40], Step [4/6], Loss: 0.6058
# Epoch [1/40], Step [5/6], Loss: 0.9103
# Epoch [1/40], Step [6/6], Loss: 1.0935
# Epoch [2/40], Step [1/6], Loss: 0.2892
# Epoch [2/40], Step [2/6], Loss: 0.2767
# Epoch [2/40], Step [3/6], Loss: 0.4214
# Epoch [2/40], Step [4/6], Loss: 0.6390
# Epoch [2/40], Step [5/6], Loss: 0.4892
# Epoch [2/40], Step [6/6], Loss: 0.3204
# Epoch [3/40], Step [1/6], Loss: 0.0928
# Epoch [3/40], Step [2/6], Loss: 0.2962
# Epoch [3/40], Step [3/6], Loss: 0.2873
# Epoch [3/40], Step [4/6], Loss: 0.6021
# Epoch [3/40], Step [5/6], Loss: 0.3590
# Epoch [3/40], Step [6/6], Loss: 0.2033
# Epoch [4/40], Step [1/6], Loss: 0.1318
# Epoch [4/40], Step [2/6], Loss: 0.3480
# Epoch [4/40], Step [3/6], Loss: 0.3371
# Epoch [4/40], Step [4/6], Loss: 0.2758
# Epoch [4/40], Step [5/6], Loss: 0.1814
# Epoch [4/40], Step [6/6], Loss: 0.3162
# Epoch [5/40], Step [1/6], Loss: 0.1801
# Epoch [5/40], Step [2/6], Loss: 0.1760
# Epoch [5/40], Step [3/6], Loss: 0.3815
# Epoch [5/40], Step [4/6], Loss: 0.3830
# Epoch [5/40], Step [5/6], Loss: 0.1612
# Epoch [5/40], Step [6/6], Loss: 0.1921
# Epoch [6/40], Step [1/6], Loss: 0.1701
# Epoch [6/40], Step [2/6], Loss: 0.3592
# Epoch [6/40], Step [3/6], Loss: 0.5110
# Epoch [35/40], Step [1/6], Loss: 0.1108
# Epoch [35/40], Step [2/6], Loss: 0.1096
# Epoch [35/40], Step [3/6], Loss: 0.2610
# Epoch [35/40], Step [4/6], Loss: 0.2365
# Epoch [35/40], Step [5/6], Loss: 0.1918
# Epoch [35/40], Step [6/6], Loss: 0.1801
# Epoch [36/40], Step [1/6], Loss: 0.0966
# Epoch [36/40], Step [2/6], Loss: 0.2861
# Epoch [36/40], Step [3/6], Loss: 0.2105
# Epoch [36/40], Step [4/6], Loss: 0.1315
# Epoch [36/40], Step [5/6], Loss: 0.1489
# Epoch [36/40], Step [6/6], Loss: 0.3065
# Epoch [37/40], Step [1/6], Loss: 0.2114
# Epoch [37/40], Step [2/6], Loss: 0.1360
# Epoch [37/40], Step [3/6], Loss: 0.2340
# Epoch [37/40], Step [4/6], Loss: 0.1669
# Epoch [37/40], Step [5/6], Loss: 0.2340
# Epoch [37/40], Step [6/6], Loss: 0.1391
# Epoch [38/40], Step [1/6], Loss: 0.2455
# Epoch [38/40], Step [2/6], Loss: 0.1324
# Epoch [38/40], Step [3/6], Loss: 0.1241
# Epoch [38/40], Step [4/6], Loss: 0.1569
# Epoch [38/40], Step [5/6], Loss: 0.2300
# Epoch [38/40], Step [6/6], Loss: 0.2835
# Epoch [39/40], Step [1/6], Loss: 0.2294
# Epoch [39/40], Step [2/6], Loss: 0.3220
# Epoch [39/40], Step [3/6], Loss: 0.1238
# Epoch [39/40], Step [4/6], Loss: 0.1397
# Epoch [39/40], Step [5/6], Loss: 0.2359
# Epoch [39/40], Step [6/6], Loss: 0.2262
# Epoch [40/40], Step [1/6], Loss: 0.1894
# Epoch [40/40], Step [2/6], Loss: 0.1798
# Epoch [40/40], Step [3/6], Loss: 0.1892
# Epoch [40/40], Step [4/6], Loss: 0.1502
# Epoch [40/40], Step [5/6], Loss: 0.1577
# Epoch [40/40], Step [6/6], Loss: 0.3119
#  Time for training is 657.1503 ms
# The loss of M_trained is 0.1945, round 900
# The loss of M_current is 0.1597, round 900
# Parameter containing:
# tensor([[ 9.9004e-01, -1.2367e-02,  3.5323e+01],
#         [-8.7742e-03,  9.9542e-01,  2.4158e+01],
#         [-2.1207e-06, -3.8719e-07,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
#  Time for blending is 0.3103, round is 900
#  Time for blending is 0.3085, round is 901
#  Time for blending is 0.3181, round is 902
#  Time for blending is 0.3267, round is 903
#  Time for blending is 0.3174, round is 904
#  Time for blending is 0.3202, round is 905
#  Time for blending is 0.3076, round is 906
#  Time for blending is 0.3063, round is 907
#  Time for blending is 0.3124, round is 908
#  Time for blending is 0.3239, round is 909
#  Time for blending is 0.3292, round is 910
#  Time for blending is 0.3114, round is 911
#  Time for blending is 0.3274, round is 912
#  Time for blending is 0.3129, round is 913
#  Time for blending is 0.2989, round is 914
#  Time for blending is 0.3065, round is 915
#  Time for blending is 0.3000, round is 916
#  Time for blending is 0.3096, round is 917
#  Time for blending is 0.2961, round is 918
#  Time for blending is 0.3102, round is 919
#  Time for blending is 0.3069, round is 920
#  Time for blending is 0.3043, round is 921
#  Time for blending is 0.3171, round is 922
#  Time for blending is 0.3181, round is 923
#  Time for blending is 0.3266, round is 924
#  Time for blending is 0.3115, round is 925
#  Time for blending is 0.3129, round is 926
#  Time for blending is 0.3254, round is 927
#  Time for blending is 0.3200, round is 928
#  Time for blending is 0.3283, round is 929
#  Time for blending is 0.3113, round is 930
#  Time for blending is 0.3267, round is 931
#  Time for blending is 0.3264, round is 932
#  Time for blending is 0.3273, round is 933
#  Time for blending is 0.3373, round is 934
#  Time for blending is 0.3479, round is 935
#  Time for blending is 0.3351, round is 936
#  Time for blending is 0.3286, round is 937
#  Time for blending is 0.3115, round is 938
#  Time for blending is 0.3137, round is 939
#  Time for blending is 0.3102, round is 940
#  Time for blending is 0.3254, round is 941
#  Time for blending is 0.3276, round is 942
#  Time for blending is 0.3088, round is 943

# %%
import torch
import torch.optim as optim
from torch import nn
import torch.utils.data as Data

cap1=cv2.VideoCapture('C:/Users/Jackie/Downloads/0119_1.MP4')
cap2=cv2.VideoCapture('C:/Users/Jackie/Downloads/0119_2.MP4')
count=cap1.get(cv2.CAP_PROP_FRAME_COUNT)
fps=cap1.get(cv2.CAP_PROP_FPS)
size=(int(cap1.get(cv2.CAP_PROP_FRAME_WIDTH)*2),int(cap1.get(cv2.CAP_PROP_FRAME_HEIGHT)))
video=cv2.VideoWriter('C:/Users/Jackie/Downloads/119_200fov.MP4',cv2.VideoWriter_fourcc('I','4','2','0'),fps,size)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")



maxL = 200
maxR = 200

if cap1.isOpened() and cap2.isOpened():
    i=1
    print('successful')
    print("The count is %d" %(count))
    #image size paremeters
    
        
    ret1,frame1=cap1.read()
    ret2,frame2=cap2.read()
    H=frame1.shape[0]
    W_remap=int(200/180*H)
    W=frame1.shape[1]+frame2.shape[1]
    templ_shape = (60, 16)
    offsetYL = int(160/1280*H)
    offsetYR = int(160/1280*H)
    #print(W_remap)
    #remap
    xmap, ymap, p = buildmap(Ws=W_remap, Hs=H, Wd=H, Hd=H, fov=200)
    #cam2 = cv2.remap(frame[:, :H], xmap, ymap, cv2.INTER_LINEAR)
    #cam1 = cv2.remap(frame[:, H:], xmap, ymap, cv2.INTER_LINEAR)
    cam1 = cv2.remap(frame1, xmap, ymap, cv2.INTER_LINEAR)
    cam2 = cv2.remap(frame2, xmap, ymap, cv2.INTER_LINEAR)
    
    #shift
    cam1_gray = cv2.cvtColor(cam1, cv2.COLOR_BGR2GRAY)
    cam2_gray = cv2.cvtColor(cam2, cv2.COLOR_BGR2GRAY)
    shifted_cams = np.zeros((H * 2, W, 3), np.uint8)
    shifted_cams[H:, int((W - W_remap) / 2):int((W + W_remap) / 2)] = cam1
    shifted_cams[:H, :int(W_remap / 2)] = cam2[:, int(W_remap / 2):]
    shifted_cams[:H, W - int(W_remap / 2):] = cam2[:, :int(W_remap / 2)]
    
    #cv2.imwrite('video_shift.jpg', shifted_cams)
    #matching
    
    maxL = 200
    maxR = 200
    b_matching=time.time()
    matchesL = getMatches_goodtemplmatch(
                    cam1_gray[offsetYL:H - offsetYL, int(W / 2):],
                    cam2_gray[offsetYL:H - offsetYL, :W_remap - int(W / 2)],
                    templ_shape, maxL)
    matchesR = getMatches_goodtemplmatch(
                    cam2_gray[offsetYR:H - offsetYR, int(W / 2):],
                    cam1_gray[offsetYR:H - offsetYR, :W_remap - int(W / 2)],
                    templ_shape, maxR)
    matchesR = matchesR[:, -1::-1]
    matchesL = matchesL + (int((W - W_remap) / 2), offsetYL)
    matchesR = matchesR + (int((W - W_remap) / 2) + int(W / 2), offsetYR)
    zipped_matches = list(zip(matchesL, matchesR))
    matches = np.int32([e for i in zipped_matches for e in i])
    pts1 = matches[:, 0]
    pts2 = matches[:, 1]
    
    #homography
    M_current, status = cv2.findHomography(pts2, pts1, cv2.RANSAC, 4.0)
    
    top, bottom = verticalBoundary(M_current, W_remap, W, H)
    warped2 = cv2.warpPerspective(shifted_cams[H:], M_current, (W, H))
    warped1 = shifted_cams[0:H,:]
    warped1 = cv2.resize(warped1[top:bottom], (W, H))
    warped2 = cv2.resize(warped2[top:bottom], (W, H))
    EAof2 = np.zeros((H, W, 3), np.uint8)
    EAof2[:, int((W - W_remap) / 2) + 1:int((W + W_remap) / 2) - 1] = 255
    EAof2 = cv2.warpPerspective(EAof2, M_current, (W, H))
    
    #blend
    b_blend=time.time()
    W_lbl = 192
    blend_level = 5
    
    mask, minloc_old = imgLabeling(
                warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                (W, H), int(W_remap / 2) - W_lbl, W - int(W_remap / 2))
    
    warped1[:, int(W_remap / 2):W - int(W_remap /
                2)] = warped2[:, int(W_remap / 2):W - int(W_remap / 2)]
    warped2[EAof2 == 0] = warped1[EAof2 == 0]
    '''
    blended = multi_band_blending(
                    warped1, warped2, mask, blend_level)
    '''
    blended_l = multi_band_blending(
                    warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    mask[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    blend_level)
    blended_r = multi_band_blending(
                    warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    mask[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    blend_level)
    blended = np.ones((H,W,3))
    blended[:, 0:int(W_remap / 2) - W_lbl] = warped1[:, 0:int(W_remap / 2) - W_lbl]
    blended[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)] = blended_l
    blended[:,int(W_remap / 2):W - int(W_remap / 2)] = warped2[:,int(W_remap / 2):W - int(W_remap / 2)]
    blended[:,W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl] = blended_r
    blended[:,W - int(W_remap / 2) + W_lbl:] = warped1[:,W - int(W_remap / 2) + W_lbl:]
    e_blend=time.time()
    #print("Time for blending is %.4f" %(e_blend-b_blend))
    video.write(blended.astype(np.uint8))
    #cv2.imwrite('video_blending.jpg', blended.astype(np.uint8))
    #FCN
    epochs=40
    index=np.where(status.ravel()==1)
    inliers=matches[index[0]]
    train,label = deduplication(inliers)
    zipped_train = list(zip(train, label))
    dataset = np.int32([e for e in zipped_train])
    np.random.shuffle(dataset)
    train = dataset[:, 0]
    label = dataset[:, 1]
    b_test = np.ones(int(train[int(train.shape[0]*0.8):].shape[0]))
    test = np.insert(train[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
    label_test = np.insert(label[int(train.shape[0]*0.8):], 2, values=b_test, axis=1)
    M = torch.tensor(M_current,requires_grad=True)
    #M_best = torch.tensor(M_best,requires_grad=True)
    model = nn.Linear(3,3,bias=False)
    model.weight =nn.Parameter(M)
    criterion = nn.MSELoss()
    test = torch.tensor(test,requires_grad=False,dtype=torch.float64)
    label_test = torch.tensor(label_test,requires_grad=False,dtype=torch.float64)
    
    test_output = model(test)
    test_output = test_output/test_output[:,2].reshape(-1,1)
    best_loss = criterion(test_output,label_test)/label_test.shape[0]
    
    print("The loss for frame1 is %.4f" %(best_loss))
    #print("The loss of M_best for frame1 is %.4f" %(loss_test_b))
    shape_list = []
    shape_list.append(inliers.shape[0])
    #M_best = M_best.to(device)
    while i<count:
        i+=1
        ret1,frame1=cap1.read()
        ret2,frame2=cap2.read()
        
        if ret1 and ret2:
            
            cam1 = cv2.remap(frame1, xmap, ymap, cv2.INTER_LINEAR)
            cam2 = cv2.remap(frame2, xmap, ymap, cv2.INTER_LINEAR)
            
            #shift
                
            shifted_cams = np.zeros((H * 2, W, 3), np.uint8)
            shifted_cams[H:, int((W - W_remap) / 2):int((W + W_remap) / 2)] = cam1
            shifted_cams[:H, :int(W_remap / 2)] = cam2[:, int(W_remap / 2):]
            shifted_cams[:H, W - int(W_remap / 2):] = cam2[:, :int(W_remap / 2)]
            if len(shape_list)%4==0:
                inliers = np.delete(inliers, range(0,shape_list[0]),axis = 0)
                del(shape_list[0])
             
            if i%60==0:
                cam1_gray = cv2.cvtColor(cam1, cv2.COLOR_BGR2GRAY)
                cam2_gray = cv2.cvtColor(cam2, cv2.COLOR_BGR2GRAY)
                b_matching=time.time()
                matchesL = getMatches_goodtemplmatch(
                    cam1_gray[offsetYL:H - offsetYL, int(W / 2):],
                    cam2_gray[offsetYL:H - offsetYL, :W_remap - int(W / 2)],
                    templ_shape, maxL)
                matchesR = getMatches_goodtemplmatch(
                    cam2_gray[offsetYR:H - offsetYR, int(W / 2):],
                    cam1_gray[offsetYR:H - offsetYR, :W_remap - int(W / 2)],
                    templ_shape, maxR)
                matchesR = matchesR[:, -1::-1]
                matchesL = matchesL + (int((W - W_remap) / 2), offsetYL)
                matchesR = matchesR + (int((W - W_remap) / 2) + int(W / 2), offsetYR)
                zipped_matches = list(zip(matchesL, matchesR))
                matches_append = np.int32([e for i in zipped_matches for e in i])
                pts1 = matches_append[:, 0]
                pts2 = matches_append[:, 1]
                
                
                e_matching=time.time()
                print("Time for matching is %.4f, round is %d" %((e_matching-b_matching),i) )
                M_, status = cv2.findHomography(pts2, pts1, cv2.RANSAC, 4.0)
                index=np.where(status.ravel()==1)
      
                inliers = np.concatenate((inliers,matches_append[index[0]]),axis=0)
                shape_list.append(matches_append[index[0]].shape[0])
                
        
                train,label = deduplication(inliers)
                zipped_train = list(zip(train, label))
                dataset = np.int32([e for e in zipped_train])
                np.random.shuffle(dataset)
                train = dataset[:, 0]
                label = dataset[:, 1]
                
                b_test = np.ones(int(train[int(train.shape[0]*0.8):].shape[0]))
                test = np.insert(train[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
                label_test = np.insert(label[int(train.shape[0]*0.8):], 2, values=b_test, axis=1) 
                b=np.ones(int(train.shape[0]*0.8))
                train = np.insert(train[:int(train.shape[0]*0.8)], 2, values=b, axis=1) 
                label = np.insert(label[:int(label.shape[0]*0.8)], 2, values=b, axis=1) 
                
                M = torch.tensor(M_current,requires_grad=True)
                model = nn.Linear(3,3,bias=False)
                model.weight =nn.Parameter(M)
                model.to(device)
                criterion = nn.MSELoss()
                optimizer = torch.optim.Adam(model.parameters(), lr=0.000001)
                #optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
    
                #M = torch.tensor(M,requires_grad=True)
                inputs = torch.tensor(train,requires_grad=False,dtype=torch.float64)
                inputs = inputs.to(device)
                label_t = torch.tensor(label,requires_grad=False,dtype=torch.float64)
                label_t = label_t.to(device)
                test = torch.tensor(test,requires_grad=False,dtype=torch.float64)
                test = test.to(device)
                label_test = torch.tensor(label_test,requires_grad=False,dtype=torch.float64)
                label_test = label_test.to(device)
                torch_dataset = Data.TensorDataset(inputs, label_t)

                loader = Data.DataLoader(
                                dataset=torch_dataset,      
                                batch_size=64,      
                                shuffle=True,               
                                num_workers=0,)
                total_step = len(loader)
                t_s = time.time()
                for epoch in range(epochs):
                    for step, (batch_x, l) in enumerate(loader):
                        #batch_x, l = batch_x.to(device),l.to(device)
                        outputs = model(batch_x)
                        outputs = outputs/outputs[:,2].reshape(-1,1)
                        loss = criterion(outputs,l)
                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()
                        print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch+1, epochs, step+1, total_step, loss.item()/len(batch_x)))
                t_e = time.time()
                print(" Time for training is %.4f ms" %((t_e-t_s)*1000))
                test_output = model(test)
                test_output = test_output/test_output[:,2].reshape(-1,1)
                loss_test = criterion(test_output,label_test)/label_test.shape[0]
                
                M_c = torch.tensor(M_current,requires_grad=True)
                model_c = nn.Linear(3,3,bias=False)
                model_c.weight =nn.Parameter(M_c)
                model_c.to(device)
                current_test = model_c(test)
                current_test = current_test/current_test[:,2].reshape(-1,1)
                current_loss = criterion(current_test,label_test)/label_test.shape[0]
                
                print("The loss of M_trained is %.4f, round %d" %(loss_test,i))
                print("The loss of M_current is %.4f, round %d" %(current_loss,i))
                print(model.weight)
                
                if loss_test<current_loss:
                    model = model.cpu()
                    M_current = model.weight.detach().numpy()
                    M_current = M_current/M_current[2][2]
                    best_loss = loss_test
                    print("The best loss is %.4f" %(best_loss))
            
            top, bottom = verticalBoundary(M_current, W_remap, W, H)
            warped2 = cv2.warpPerspective(shifted_cams[H:], M_current, (W, H))
            warped1 = shifted_cams[0:H,:]
            warped1 = cv2.resize(warped1[top:bottom], (W, H))
            warped2 = cv2.resize(warped2[top:bottom], (W, H))
            EAof2 = np.zeros((H, W, 3), np.uint8)
            EAof2[:, int((W - W_remap) / 2) + 1:int((W + W_remap) / 2) - 1] = 255
            EAof2 = cv2.warpPerspective(EAof2, M_current, (W, H))
            #b_blend=time.time()
            e1 = cv2.getTickCount()
            if i%120==0:
                mask, minloc_old = imgLabeling(
                warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)],
                warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl],
                (W, H), int(W_remap / 2) - W_lbl, W - int(W_remap / 2))
            
            
            
            warped1[:, int(W_remap / 2):W - int(W_remap /
                        2)] = warped2[:, int(W_remap / 2):W - int(W_remap / 2)]
            warped2[EAof2 == 0] = warped1[EAof2 == 0]
            '''
            blended = multi_band_blending(
                                warped1, warped2, mask, blend_level)
            '''
            #blended = warped1 * mask + warped2 * (1 - mask)
           
            blended_l = multi_band_blending(
                    warped1[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    warped2[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    mask[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)], 
                    blend_level)
                
            blended_r = multi_band_blending(
                    warped1[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    warped2[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    mask[:, W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl], 
                    blend_level)
            blended = np.ones((H,W,3))
            blended[:, 0:int(W_remap / 2) - W_lbl] = warped1[:, 0:int(W_remap / 2) - W_lbl]
            blended[:, int(W_remap / 2) - W_lbl:int(W_remap / 2)] = blended_l
            blended[:,int(W_remap / 2):W - int(W_remap / 2)] = warped2[:,int(W_remap / 2):W - int(W_remap / 2)]
            blended[:,W - int(W_remap / 2):W - int(W_remap / 2) + W_lbl] = blended_r
            blended[:,W - int(W_remap / 2) + W_lbl:] = warped1[:,W - int(W_remap / 2) + W_lbl:]
            video.write(blended.astype(np.uint8))
            e2 = cv2.getTickCount()
            #e_blend=time.time()
            #print(" Time for blending is %.4f, round is %d" %((e_blend-b_blend),i) )
            print("Time for blending is %.4f, round is %d" %(((e2 - e1)/cv2.getTickFrequency()*1000),i))
      
        else:   
            break
    
else:
    print('fail')
cap1.release()
cap2.release()
video.release()
# Out:
# successful
# The count is 636
# The loss for frame1 is 0.1454
# Time for blending is 351.6364, round is 2
# Time for blending is 355.8939, round is 3
# Time for blending is 351.8112, round is 4
# Time for blending is 354.7360, round is 5
# Time for blending is 362.4592, round is 6
# Time for blending is 359.3792, round is 7
# Time for blending is 358.0967, round is 8
# Time for blending is 361.4350, round is 9
# Time for blending is 354.1075, round is 10
# Time for blending is 363.6786, round is 11
# Time for blending is 358.0551, round is 12
# Time for blending is 355.6982, round is 13
# Time for blending is 363.6397, round is 14
# Time for blending is 370.4077, round is 15
# Time for blending is 394.6088, round is 16
# Time for blending is 436.8062, round is 17
# Time for blending is 353.8472, round is 18
# Time for blending is 362.7728, round is 19
# Time for blending is 366.5807, round is 20
# Time for blending is 372.0474, round is 21
# Time for blending is 361.2201, round is 22
# Time for blending is 375.5492, round is 23
# Time for blending is 392.3974, round is 24
# Time for blending is 361.2936, round is 25
# Time for blending is 354.7896, round is 26
# Time for blending is 363.7442, round is 27
# Time for blending is 352.7167, round is 28
# Time for blending is 359.5307, round is 29
# Time for blending is 351.1228, round is 30
# Time for blending is 356.5117, round is 31
# Time for blending is 358.2416, round is 32
# Time for blending is 362.4652, round is 33
# Time for blending is 359.7178, round is 34
# Time for blending is 370.6650, round is 35
# Time for blending is 424.3738, round is 36
# Time for blending is 350.1330, round is 37
# Time for blending is 354.9033, round is 38
# Time for blending is 353.6536, round is 39
# Time for blending is 368.7961, round is 40
# Time for blending is 358.7789, round is 41
# Time for blending is 364.7025, round is 42
# Time for blending is 354.6203, round is 43
# Time for blending is 362.6664, round is 44
# Time for blending is 358.6269, round is 45
# Time for blending is 356.4491, round is 46
# Time for blending is 361.5293, round is 47
# Time for blending is 358.5254, round is 48
# Time for blending is 357.9576, round is 49
# Time for blending is 357.6011, round is 50
# Time for blending is 360.8609, round is 51
# Time for blending is 369.8291, round is 52
# Time for blending is 370.0622, round is 53
# Time for blending is 370.7537, round is 54
# Time for blending is 362.6531, round is 55
# Time for blending is 370.7966, round is 56
# Time for blending is 375.3898, round is 57
# Time for blending is 366.7424, round is 58
# Time for blending is 362.0738, round is 59
# Time for matching is 3.1777, round is 60
# Epoch [1/40], Step [1/2], Loss: 0.0627
# Epoch [1/40], Step [2/2], Loss: 15.2493
# Epoch [2/40], Step [1/2], Loss: 0.1139
# Epoch [2/40], Step [2/2], Loss: 7.3247
# Epoch [3/40], Step [1/2], Loss: 0.6218
# Epoch [3/40], Step [2/2], Loss: 4.5821
# Epoch [4/40], Step [1/2], Loss: 0.1515
# Epoch [4/40], Step [2/2], Loss: 0.7872
# Epoch [5/40], Step [1/2], Loss: 0.1255
# Epoch [5/40], Step [2/2], Loss: 2.5877
# Epoch [6/40], Step [1/2], Loss: 0.1342
# Epoch [6/40], Step [2/2], Loss: 1.1539
# Epoch [7/40], Step [1/2], Loss: 0.0559
# Epoch [7/40], Step [2/2], Loss: 2.4735
# Epoch [8/40], Step [1/2], Loss: 0.1879
# Epoch [8/40], Step [2/2], Loss: 5.3761
# Epoch [9/40], Step [1/2], Loss: 0.0916
# Epoch [9/40], Step [2/2], Loss: 0.3871
# Epoch [10/40], Step [1/2], Loss: 0.1503
# Epoch [10/40], Step [2/2], Loss: 0.9778
# Epoch [11/40], Step [1/2], Loss: 0.2895
# Epoch [11/40], Step [2/2], Loss: 8.9182
# Epoch [12/40], Step [1/2], Loss: 0.0825
# Epoch [12/40], Step [2/2], Loss: 0.8268
# Epoch [13/40], Step [1/2], Loss: 0.2020
# Epoch [13/40], Step [2/2], Loss: 11.4093
# Epoch [14/40], Step [1/2], Loss: 0.2355
# Epoch [14/40], Step [2/2], Loss: 3.8381
# Epoch [15/40], Step [1/2], Loss: 0.0562
# Epoch [15/40], Step [2/2], Loss: 2.3116
# Epoch [16/40], Step [1/2], Loss: 0.2239
# Epoch [16/40], Step [2/2], Loss: 5.5327
# Epoch [17/40], Step [1/2], Loss: 0.1341
# Epoch [17/40], Step [2/2], Loss: 2.6790
# Epoch [18/40], Step [1/2], Loss: 0.0739
# Epoch [18/40], Step [2/2], Loss: 1.3938
# Epoch [19/40], Step [1/2], Loss: 0.1795
# Epoch [19/40], Step [2/2], Loss: 4.0462
# Epoch [20/40], Step [1/2], Loss: 0.1204
# Epoch [20/40], Step [2/2], Loss: 0.8755
# Epoch [21/40], Step [1/2], Loss: 0.0580
# Epoch [21/40], Step [2/2], Loss: 0.6706
# Epoch [22/40], Step [1/2], Loss: 0.1310
# Epoch [22/40], Step [2/2], Loss: 0.6981
# Epoch [23/40], Step [1/2], Loss: 0.1486
# Epoch [23/40], Step [2/2], Loss: 1.0521
# Epoch [24/40], Step [1/2], Loss: 0.0718
# Epoch [24/40], Step [2/2], Loss: 1.0470
# Epoch [25/40], Step [1/2], Loss: 0.0675
# Epoch [25/40], Step [2/2], Loss: 0.6492
# Epoch [26/40], Step [1/2], Loss: 0.1078
# Epoch [26/40], Step [2/2], Loss: 0.4377
# Epoch [27/40], Step [1/2], Loss: 0.0829
# Epoch [27/40], Step [2/2], Loss: 1.3568
# Epoch [28/40], Step [1/2], Loss: 0.0557
# Epoch [28/40], Step [2/2], Loss: 1.1225
# Epoch [29/40], Step [1/2], Loss: 0.0664
# Epoch [29/40], Step [2/2], Loss: 0.1617
# Epoch [30/40], Step [1/2], Loss: 0.0583
# Epoch [30/40], Step [2/2], Loss: 0.8521
# Epoch [31/40], Step [1/2], Loss: 0.0565
# Epoch [31/40], Step [2/2], Loss: 0.7359
# Epoch [32/40], Step [1/2], Loss: 0.0565
# Epoch [32/40], Step [2/2], Loss: 0.6657
# Epoch [33/40], Step [1/2], Loss: 0.0445
# Epoch [33/40], Step [2/2], Loss: 3.7319
# Epoch [34/40], Step [1/2], Loss: 0.0558
# Epoch [34/40], Step [2/2], Loss: 0.6377
# Epoch [35/40], Step [1/2], Loss: 0.0643
# Epoch [35/40], Step [2/2], Loss: 0.4463
# Epoch [36/40], Step [1/2], Loss: 0.0727
# Epoch [36/40], Step [2/2], Loss: 0.2078
# Epoch [37/40], Step [1/2], Loss: 0.0560
# Epoch [37/40], Step [2/2], Loss: 0.9676
# Epoch [38/40], Step [1/2], Loss: 0.0654
# Epoch [38/40], Step [2/2], Loss: 0.6180
# Epoch [39/40], Step [1/2], Loss: 0.0765
# Epoch [39/40], Step [2/2], Loss: 2.2261
# Epoch [40/40], Step [1/2], Loss: 0.0617
# Epoch [40/40], Step [2/2], Loss: 0.7655
#  Time for training is 300.5638 ms
# The loss of M_trained is 0.4526, round 60
# The loss of M_current is 0.4726, round 60
# Parameter containing:
# tensor([[ 1.2785e+00, -7.9493e-02, -6.8168e+01],
#         [ 1.3151e-01,  1.0445e+00, -1.3941e+02],
#         [ 6.9175e-05, -1.8939e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.4526
# Time for blending is 362.7049, round is 60
# Time for blending is 354.0908, round is 61
# Time for blending is 359.8697, round is 62
# Time for blending is 360.2921, round is 63
# Time for blending is 357.6435, round is 64
# Time for blending is 360.5543, round is 65
# Time for blending is 347.4390, round is 66
# Time for blending is 356.7719, round is 67
# Time for blending is 359.7709, round is 68
# Time for blending is 355.1366, round is 69
# Time for blending is 365.2315, round is 70
# Time for blending is 352.0166, round is 71
# Time for blending is 347.9924, round is 72
# Time for blending is 363.1609, round is 73
# Time for blending is 359.7896, round is 74
# Time for blending is 366.3693, round is 75
# Time for blending is 357.2385, round is 76
# Time for blending is 357.7367, round is 77
# Time for blending is 354.2420, round is 78
# Time for blending is 361.6841, round is 79
# Time for blending is 359.0111, round is 80
# Time for blending is 367.3733, round is 81
# Time for blending is 361.1570, round is 82
# Time for blending is 356.3540, round is 83
# Time for blending is 367.1011, round is 84
# Time for blending is 367.1590, round is 85
# Time for blending is 387.4164, round is 86
# Time for blending is 359.3069, round is 87
# Time for blending is 364.1474, round is 88
# Time for blending is 359.7676, round is 89
# Time for blending is 356.7861, round is 90
# Time for blending is 366.3367, round is 91
# Time for blending is 362.7383, round is 92
# Time for blending is 364.4835, round is 93
# Time for blending is 358.2794, round is 94
# Time for blending is 358.8777, round is 95
# Time for blending is 352.0765, round is 96
# Time for blending is 358.3027, round is 97
# Time for blending is 365.3023, round is 98
# Time for blending is 355.6963, round is 99
# Time for blending is 360.1300, round is 100
# Time for blending is 354.5204, round is 101
# Time for blending is 353.2751, round is 102
# Time for blending is 351.2864, round is 103
# Time for blending is 358.3247, round is 104
# Time for blending is 357.1308, round is 105
# Time for blending is 355.5915, round is 106
# Time for blending is 370.3345, round is 107
# Time for blending is 350.7620, round is 108
# Time for blending is 349.0496, round is 109
# Time for blending is 351.1217, round is 110
# Time for blending is 362.5821, round is 111
# Time for blending is 362.6510, round is 112
# Time for blending is 368.4492, round is 113
# Time for blending is 363.0359, round is 114
# Time for blending is 360.4545, round is 115
# Time for blending is 360.3970, round is 116
# Time for blending is 358.2074, round is 117
# Time for blending is 356.9756, round is 118
# Time for blending is 359.2382, round is 119
# Time for matching is 3.5499, round is 120
# Epoch [1/40], Step [1/2], Loss: 0.0778
# Epoch [1/40], Step [2/2], Loss: 2.4709
# Epoch [2/40], Step [1/2], Loss: 0.1309
# Epoch [2/40], Step [2/2], Loss: 0.5831
# Epoch [3/40], Step [1/2], Loss: 0.5635
# Epoch [3/40], Step [2/2], Loss: 1.1590
# Epoch [4/40], Step [1/2], Loss: 0.1540
# Epoch [4/40], Step [2/2], Loss: 0.0896
# Epoch [5/40], Step [1/2], Loss: 0.2191
# Epoch [5/40], Step [2/2], Loss: 0.9656
# Epoch [6/40], Step [1/2], Loss: 0.2840
# Epoch [6/40], Step [2/2], Loss: 0.3518
# Epoch [7/40], Step [1/2], Loss: 0.0734
# Epoch [7/40], Step [2/2], Loss: 0.2622
# Epoch [8/40], Step [1/2], Loss: 0.1861
# Epoch [8/40], Step [2/2], Loss: 0.5452
# Epoch [9/40], Step [1/2], Loss: 0.1471
# Epoch [9/40], Step [2/2], Loss: 0.1323
# Epoch [10/40], Step [1/2], Loss: 0.0472
# Epoch [10/40], Step [2/2], Loss: 0.4704
# Epoch [11/40], Step [1/2], Loss: 0.1592
# Epoch [11/40], Step [2/2], Loss: 0.2241
# Epoch [12/40], Step [1/2], Loss: 0.0931
# Epoch [12/40], Step [2/2], Loss: 0.1467
# Epoch [13/40], Step [1/2], Loss: 0.0862
# Epoch [13/40], Step [2/2], Loss: 0.2293
# Epoch [14/40], Step [1/2], Loss: 0.1059
# Epoch [14/40], Step [2/2], Loss: 0.1518
# Epoch [15/40], Step [1/2], Loss: 0.0737
-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# Time for blending is 1103.8893, round is 120
# Time for blending is 366.7562, round is 121
# Time for blending is 359.9330, round is 122
# Time for blending is 350.9757, round is 123
# Time for blending is 374.2073, round is 124
# Time for blending is 353.0940, round is 125
# Time for blending is 380.7248, round is 126
# Time for blending is 351.4694, round is 127
# Time for blending is 353.3805, round is 128
# Time for blending is 348.5625, round is 129
# Time for blending is 354.5417, round is 130
# Time for blending is 357.1299, round is 131
# Time for blending is 356.2829, round is 132
# Time for blending is 352.8095, round is 133
# Time for blending is 353.8495, round is 134
# Time for blending is 355.4684, round is 135
# Time for blending is 366.5975, round is 136
# Time for blending is 363.8055, round is 137
# Time for blending is 349.7162, round is 138
# Time for blending is 362.1815, round is 139
# Time for blending is 363.1033, round is 140
# Time for blending is 363.4804, round is 141
# Time for blending is 366.9152, round is 142
# Time for blending is 357.2188, round is 143
# Time for blending is 361.5403, round is 144
# Time for blending is 368.9770, round is 145
# Time for blending is 360.5094, round is 146
# Time for blending is 363.1141, round is 147
# Time for blending is 355.2668, round is 148
# Time for blending is 373.7809, round is 149
# Time for blending is 363.3220, round is 150
# Time for blending is 369.4382, round is 151
# Time for blending is 382.0513, round is 152
# Time for blending is 370.3407, round is 153
# Time for blending is 359.2892, round is 154
# Time for blending is 368.5985, round is 155
# Time for blending is 371.2821, round is 156
# Time for blending is 357.6285, round is 157
# Time for blending is 367.6860, round is 158
# Time for blending is 361.7459, round is 159
# Time for blending is 349.5462, round is 160
# Time for blending is 355.1983, round is 161
# Time for blending is 353.6288, round is 162
# Time for blending is 356.9167, round is 163
# Time for blending is 357.8284, round is 164
# Time for blending is 355.9004, round is 165
# Time for blending is 359.3197, round is 166
# Time for blending is 356.8363, round is 167
# Time for blending is 352.5700, round is 168
# Time for blending is 355.0829, round is 169
# Time for blending is 356.1190, round is 170
# Time for blending is 351.4106, round is 171
# Time for blending is 351.9494, round is 172
# Time for blending is 354.9830, round is 173
# Time for blending is 348.9462, round is 174
# Time for blending is 364.0843, round is 175
# Time for blending is 358.8296, round is 176
# Time for blending is 363.8804, round is 177
# Time for blending is 362.9187, round is 178
# Time for blending is 363.0189, round is 179
# Time for matching is 3.3273, round is 180
# Epoch [1/40], Step [1/2], Loss: 0.0482
# Epoch [1/40], Step [2/2], Loss: 1.0755
# Epoch [2/40], Step [1/2], Loss: 0.1144
# Epoch [2/40], Step [2/2], Loss: 0.3368
# Epoch [3/40], Step [1/2], Loss: 0.6527
# Epoch [3/40], Step [2/2], Loss: 0.4264
# Epoch [4/40], Step [1/2], Loss: 0.1015
# Epoch [4/40], Step [2/2], Loss: 0.1389
# Epoch [5/40], Step [1/2], Loss: 0.2612
# Epoch [5/40], Step [2/2], Loss: 0.3605
# Epoch [6/40], Step [1/2], Loss: 0.1909
# Epoch [6/40], Step [2/2], Loss: 0.1468
# Epoch [7/40], Step [1/2], Loss: 0.0832
# Epoch [7/40], Step [2/2], Loss: 0.1779
# Epoch [8/40], Step [1/2], Loss: 0.2341
# Epoch [8/40], Step [2/2], Loss: 0.1919
# Epoch [9/40], Step [1/2], Loss: 0.1213
# Epoch [9/40], Step [2/2], Loss: 0.0656
# Epoch [10/40], Step [1/2], Loss: 0.1265
# Parameter containing:
# tensor([[ 1.2785e+00, -7.9495e-02, -6.8168e+01],
#         [ 1.3150e-01,  1.0445e+00, -1.3941e+02],
#         [ 6.9282e-05, -1.9361e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.1506
# Time for blending is 351.1313, round is 180
# Time for blending is 358.7595, round is 181
# Time for blending is 349.3972, round is 182
# Time for blending is 359.3262, round is 183
# Time for blending is 364.4765, round is 184
# Time for blending is 371.6771, round is 185
# Time for blending is 370.5888, round is 186
# Time for blending is 357.1092, round is 187
# Time for blending is 358.5760, round is 188
# Time for blending is 356.5680, round is 189
# Time for blending is 352.5642, round is 190
# Time for blending is 358.6845, round is 191
# Time for blending is 355.0710, round is 192
# Time for blending is 351.1541, round is 193
# Time for blending is 361.8785, round is 194
# Time for blending is 353.4743, round is 195
# Time for blending is 356.0287, round is 196
# Time for blending is 358.2571, round is 197
# Time for blending is 364.6887, round is 198
# Time for blending is 349.6203, round is 199
# Time for blending is 351.1937, round is 200
# Time for blending is 352.5477, round is 201
# Time for blending is 354.4263, round is 202
# Time for blending is 356.4496, round is 203
# Time for blending is 346.2101, round is 204
# Time for blending is 361.6910, round is 205
# Time for blending is 379.4539, round is 206
# Time for blending is 358.1174, round is 207
# Time for blending is 363.2650, round is 208
# Time for blending is 357.9796, round is 209
# Time for blending is 356.0128, round is 210
# Time for blending is 360.0019, round is 211
# Time for blending is 367.2112, round is 212
# Time for blending is 360.6000, round is 213
# Time for blending is 363.6355, round is 214
# Time for blending is 352.5629, round is 215
# Time for blending is 363.8465, round is 216
# Time for blending is 372.5676, round is 217
# Time for blending is 370.1111, round is 218
# Time for blending is 363.9840, round is 219
# Time for blending is 371.0329, round is 220
# Time for blending is 369.4092, round is 221
# Time for blending is 362.3410, round is 222
# Time for blending is 363.3684, round is 223
# Time for blending is 366.0517, round is 224
# Time for blending is 370.4970, round is 225
# Time for blending is 369.4490, round is 226
# Time for blending is 362.9525, round is 227
# Time for blending is 361.7618, round is 228
# Time for blending is 361.8550, round is 229
# Time for blending is 384.8733, round is 230
# Time for blending is 356.2652, round is 231
# Time for blending is 389.7287, round is 232
# Time for blending is 354.7254, round is 233
# Time for blending is 360.8134, round is 234
# Time for blending is 355.6957, round is 235
# Time for blending is 355.0235, round is 236
# Time for blending is 364.3574, round is 237
# Time for blending is 361.3773, round is 238
# Time for blending is 365.9674, round is 239
# Time for matching is 3.5349, round is 240
# Epoch [1/40], Step [1/2], Loss: 0.0852
# Epoch [1/40], Step [2/2], Loss: 2.4329
# Epoch [2/40], Step [1/2], Loss: 0.2832
# Epoch [2/40], Step [2/2], Loss: 0.3383
# Epoch [3/40], Step [1/2], Loss: 0.6262
# Epoch [3/40], Step [2/2], Loss: 1.1592
# Epoch [4/40], Step [1/2], Loss: 0.5051
# Epoch [4/40], Step [2/2], Loss: 0.3823
# Epoch [34/40], Step [1/2], Loss: 0.1884
# Epoch [34/40], Step [2/2], Loss: 0.1534
# Epoch [35/40], Step [1/2], Loss: 0.1695
# Epoch [35/40], Step [2/2], Loss: 0.1769
# Epoch [36/40], Step [1/2], Loss: 0.1697
# Epoch [36/40], Step [2/2], Loss: 0.1742
# Epoch [37/40], Step [1/2], Loss: 0.0510
# Epoch [37/40], Step [2/2], Loss: 0.3861
# Epoch [38/40], Step [1/2], Loss: 0.2407
# Epoch [38/40], Step [2/2], Loss: 0.0613
# Epoch [39/40], Step [1/2], Loss: 0.1116
# Epoch [39/40], Step [2/2], Loss: 0.2809
# Epoch [40/40], Step [1/2], Loss: 0.1553
# Epoch [40/40], Step [2/2], Loss: 0.1962
#  Time for training is 425.6692 ms
# The loss of M_trained is 0.5861, round 240
# The loss of M_current is 0.6109, round 240
# Parameter containing:
# tensor([[ 1.2785e+00, -7.9496e-02, -6.8168e+01],
#         [ 1.3148e-01,  1.0445e+00, -1.3941e+02],
#         [ 6.9112e-05, -1.9223e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.5861
# Time for blending is 1131.5090, round is 240
# Time for blending is 371.2855, round is 241
# Time for blending is 357.6418, round is 242
# Time for blending is 358.6359, round is 243
# Time for blending is 358.1407, round is 244
# Time for blending is 369.5022, round is 245
# Time for blending is 368.9925, round is 246
# Time for blending is 367.9943, round is 247
# Time for blending is 370.1484, round is 248
# Time for blending is 363.0771, round is 249
# Time for blending is 369.3234, round is 250
# Time for blending is 367.2690, round is 251
# Time for blending is 356.4604, round is 252
# Time for blending is 369.1075, round is 253
# Time for blending is 363.6017, round is 254
# Time for blending is 349.5879, round is 255
# Time for blending is 351.6605, round is 256
# Time for blending is 353.8710, round is 257
# Time for blending is 347.5373, round is 258
# Time for blending is 355.3331, round is 259
# Time for blending is 355.4628, round is 260
# Time for blending is 360.4406, round is 261
# Time for blending is 354.2036, round is 262
# Time for blending is 366.4657, round is 263
# Time for blending is 357.0239, round is 264
# Time for blending is 353.5811, round is 265
# Time for blending is 358.1812, round is 266
# Time for blending is 368.1604, round is 267
# Time for blending is 359.4974, round is 268
# Time for blending is 355.3560, round is 269
# Time for blending is 345.2396, round is 270
# Time for blending is 356.1557, round is 271
# Time for blending is 369.1905, round is 272
# Time for blending is 372.4351, round is 273
# Time for blending is 355.6769, round is 274
# Time for blending is 362.9630, round is 275
# Time for blending is 356.8705, round is 276
# Time for blending is 351.6835, round is 277
# Time for blending is 355.4591, round is 278
# Time for blending is 366.5440, round is 279
# Time for blending is 361.2155, round is 280
# Time for blending is 356.6784, round is 281
# Time for blending is 359.8583, round is 282
# Time for blending is 370.8559, round is 283
# Time for blending is 369.6502, round is 284
# Time for blending is 366.1517, round is 285
# Time for blending is 357.1944, round is 286
# Time for blending is 370.8472, round is 287
# Time for blending is 405.8672, round is 288
# Time for blending is 364.3329, round is 289
# Time for blending is 365.1303, round is 290
# Time for blending is 360.7269, round is 291
# Time for blending is 358.6502, round is 292
# Time for blending is 356.6835, round is 293
# Time for blending is 362.4194, round is 294
# Time for blending is 357.6353, round is 295
# Time for blending is 357.6882, round is 296
# Time for blending is 353.2007, round is 297
# Epoch [28/40], Step [2/2], Loss: 0.3030
# Epoch [29/40], Step [1/2], Loss: 0.2113
# Epoch [29/40], Step [2/2], Loss: 0.1705
# Epoch [30/40], Step [1/2], Loss: 0.2535
# Epoch [30/40], Step [2/2], Loss: 0.0888
# Epoch [31/40], Step [1/2], Loss: 0.2085
# Epoch [31/40], Step [2/2], Loss: 0.1744
# Epoch [32/40], Step [1/2], Loss: 0.2015
# Epoch [32/40], Step [2/2], Loss: 0.1958
# Epoch [33/40], Step [1/2], Loss: 0.2037
# Epoch [33/40], Step [2/2], Loss: 0.1893
# Epoch [34/40], Step [1/2], Loss: 0.2155
# Epoch [34/40], Step [2/2], Loss: 0.1612
# Epoch [35/40], Step [1/2], Loss: 0.2593
# Epoch [35/40], Step [2/2], Loss: 0.0763
# Epoch [36/40], Step [1/2], Loss: 0.1543
# Epoch [36/40], Step [2/2], Loss: 0.2955
# Epoch [37/40], Step [1/2], Loss: 0.2143
# Epoch [37/40], Step [2/2], Loss: 0.1701
# Epoch [38/40], Step [1/2], Loss: 0.2065
# Epoch [38/40], Step [2/2], Loss: 0.1836
# Epoch [39/40], Step [1/2], Loss: 0.2040
# Epoch [39/40], Step [2/2], Loss: 0.1852
# Epoch [40/40], Step [1/2], Loss: 0.2103
# Epoch [40/40], Step [2/2], Loss: 0.1691
#  Time for training is 296.8483 ms
# The loss of M_trained is 0.1921, round 300
# The loss of M_current is 0.1959, round 300
# Parameter containing:
# tensor([[ 1.2785e+00, -7.9491e-02, -6.8167e+01],
#         [ 1.3144e-01,  1.0445e+00, -1.3941e+02],
#         [ 6.9208e-05, -1.9422e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.1921
# Time for blending is 349.0574, round is 300
# Time for blending is 356.8528, round is 301
# Time for blending is 348.2761, round is 302
# Time for blending is 353.8105, round is 303
# Time for blending is 354.4959, round is 304
# Time for blending is 356.4773, round is 305
# Time for blending is 355.8236, round is 306
# Time for blending is 357.1902, round is 307
# Time for blending is 358.9815, round is 308
# Time for blending is 359.4246, round is 309
# Time for blending is 359.8267, round is 310
# Time for blending is 359.0602, round is 311
# Time for blending is 366.6187, round is 312
# Time for blending is 372.2758, round is 313
# Time for blending is 366.4856, round is 314
# Time for blending is 373.7288, round is 315
# Time for blending is 370.3080, round is 316
# Time for blending is 365.9503, round is 317
# Time for blending is 358.3304, round is 318
# Time for blending is 365.7418, round is 319
# Time for blending is 369.2711, round is 320
# Time for blending is 364.7540, round is 321
# Time for blending is 367.3218, round is 322
# Time for blending is 357.9970, round is 323
# Time for blending is 369.9310, round is 324
# Time for blending is 358.0560, round is 325
# Time for blending is 367.5940, round is 326
# Time for blending is 355.7756, round is 327
# Time for blending is 360.7233, round is 328
# Time for blending is 383.0744, round is 329
# Time for blending is 385.7329, round is 330
# Time for blending is 362.4165, round is 331
# Time for blending is 374.3777, round is 332
# Time for blending is 354.6425, round is 333
# Time for blending is 352.3784, round is 334
# Time for blending is 352.8854, round is 335
# Time for blending is 365.6096, round is 336
# Time for blending is 354.3999, round is 337
# Time for blending is 359.3288, round is 338
# Time for blending is 352.1348, round is 339
# Time for blending is 365.1060, round is 340
# Time for blending is 370.0266, round is 341
# Time for blending is 359.7055, round is 342
# Time for blending is 363.6154, round is 343
# Time for blending is 360.7902, round is 344
# Time for blending is 362.1437, round is 345
# Time for blending is 357.9039, round is 346
# Time for blending is 386.4567, round is 347
# Time for blending is 379.2821, round is 348
# Time for blending is 359.8515, round is 349
# Time for blending is 355.5352, round is 350
# Time for blending is 368.6318, round is 351
# Time for blending is 353.6619, round is 352
# Time for blending is 360.7755, round is 353
# Time for blending is 356.7302, round is 354
# Time for blending is 363.5914, round is 355
# Time for blending is 369.8379, round is 356
# Time for blending is 371.0443, round is 357
# Time for blending is 362.4005, round is 358
# Time for blending is 377.1155, round is 359
# Time for matching is 3.6478, round is 360
# Epoch [1/40], Step [1/2], Loss: 0.2840
# Epoch [1/40], Step [2/2], Loss: 1.3037
# Epoch [2/40], Step [1/2], Loss: 0.3156
# Epoch [2/40], Step [2/2], Loss: 0.5564
# Epoch [3/40], Step [1/2], Loss: 0.6153
# Epoch [3/40], Step [2/2], Loss: 0.7725
# Epoch [4/40], Step [1/2], Loss: 0.2634
# Epoch [4/40], Step [2/2], Loss: 0.3302
# Epoch [5/40], Step [1/2], Loss: 0.3469
# Epoch [5/40], Step [2/2], Loss: 0.6551
# Epoch [6/40], Step [1/2], Loss: 0.5016
# Epoch [6/40], Step [2/2], Loss: 0.2006
# Epoch [7/40], Step [1/2], Loss: 0.2529
# Epoch [7/40], Step [2/2], Loss: 0.3412
# Epoch [8/40], Step [1/2], Loss: 0.2957
# Epoch [8/40], Step [2/2], Loss: 0.5686
# Epoch [9/40], Step [1/2], Loss: 0.4053
# Epoch [9/40], Step [2/2], Loss: 0.1682
# Epoch [10/40], Step [1/2], Loss: 0.2773
# Epoch [10/40], Step [2/2], Loss: 0.2812
# Epoch [11/40], Step [1/2], Loss: 0.3446
# Epoch [11/40], Step [2/2], Loss: 0.3253
# Epoch [12/40], Step [1/2], Loss: 0.3013
# Epoch [12/40], Step [2/2], Loss: 0.2131
# Epoch [13/40], Step [1/2], Loss: 0.1249
# Epoch [13/40], Step [2/2], Loss: 0.5242
# Epoch [14/40], Step [1/2], Loss: 0.3446
# Epoch [14/40], Step [2/2], Loss: 0.2311
# Epoch [15/40], Step [1/2], Loss: 0.3118
# Epoch [15/40], Step [2/2], Loss: 0.1938
# Epoch [16/40], Step [1/2], Loss: 0.2291
# Epoch [16/40], Step [2/2], Loss: 0.3475
# Epoch [17/40], Step [1/2], Loss: 0.2675
# Epoch [17/40], Step [2/2], Loss: 0.2738
# Epoch [18/40], Step [1/2], Loss: 0.2014
# Epoch [18/40], Step [2/2], Loss: 0.3503
# Epoch [19/40], Step [1/2], Loss: 0.2978
# Epoch [19/40], Step [2/2], Loss: 0.2320
# Epoch [20/40], Step [1/2], Loss: 0.2546
# Epoch [20/40], Step [2/2], Loss: 0.2644
# Epoch [21/40], Step [1/2], Loss: 0.2619
# Epoch [21/40], Step [2/2], Loss: 0.2743
# Epoch [22/40], Step [1/2], Loss: 0.3180
# Epoch [22/40], Step [2/2], Loss: 0.1785
# Epoch [23/40], Step [1/2], Loss: 0.2690
# Epoch [23/40], Step [2/2], Loss: 0.2316
# Epoch [24/40], Step [1/2], Loss: 0.2426
# Epoch [24/40], Step [2/2], Loss: 0.2979
# Epoch [25/40], Step [1/2], Loss: 0.2890
# Epoch [25/40], Step [2/2], Loss: 0.2225
# Epoch [26/40], Step [1/2], Loss: 0.1789
# Epoch [26/40], Step [2/2], Loss: 0.3780
# Epoch [27/40], Step [1/2], Loss: 0.3422
# Epoch [27/40], Step [2/2], Loss: 0.1330
# Epoch [28/40], Step [1/2], Loss: 0.2936
# Epoch [28/40], Step [2/2], Loss: 0.1978
# Epoch [29/40], Step [1/2], Loss: 0.3175
# Epoch [29/40], Step [2/2], Loss: 0.1657
# Epoch [30/40], Step [1/2], Loss: 0.1333
# Epoch [30/40], Step [2/2], Loss: 0.4440
# Epoch [31/40], Step [1/2], Loss: 0.2675
# Epoch [31/40], Step [2/2], Loss: 0.2447
# Epoch [32/40], Step [1/2], Loss: 0.2380
# Epoch [32/40], Step [2/2], Loss: 0.2891
# Epoch [33/40], Step [1/2], Loss: 0.2366
# Epoch [33/40], Step [2/2], Loss: 0.2879
# Epoch [34/40], Step [1/2], Loss: 0.1990
# Epoch [34/40], Step [2/2], Loss: 0.3443
# Epoch [35/40], Step [1/2], Loss: 0.1872
# Epoch [35/40], Step [2/2], Loss: 0.3604
# Epoch [36/40], Step [1/2], Loss: 0.2336
# Epoch [36/40], Step [2/2], Loss: 0.2916
# Epoch [37/40], Step [1/2], Loss: 0.2592
# Epoch [37/40], Step [2/2], Loss: 0.2529
# Epoch [38/40], Step [1/2], Loss: 0.3298
# Epoch [38/40], Step [2/2], Loss: 0.1481
# Epoch [39/40], Step [1/2], Loss: 0.3491
# Epoch [39/40], Step [2/2], Loss: 0.1154
# Epoch [40/40], Step [1/2], Loss: 0.2985
# Epoch [40/40], Step [2/2], Loss: 0.1928
#  Time for training is 375.8340 ms
# The loss of M_trained is 0.2097, round 360
# The loss of M_current is 0.2115, round 360
# Parameter containing:
# tensor([[ 1.2785e+00, -7.9500e-02, -6.8167e+01],
#         [ 1.3141e-01,  1.0445e+00, -1.3941e+02],
#         [ 6.9045e-05, -1.9050e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.2097
# Time for blending is 1124.5417, round is 360
# Time for blending is 380.3801, round is 361
# Time for blending is 367.3006, round is 362
# Time for blending is 349.8894, round is 363
# Time for blending is 341.1651, round is 364
# Time for blending is 352.5783, round is 365
# Time for blending is 351.2322, round is 366
# Time for blending is 346.9761, round is 367
# Time for blending is 350.8749, round is 368
# Time for blending is 355.1447, round is 369
# Time for blending is 363.8738, round is 370
# Time for blending is 350.7854, round is 371
# Time for blending is 358.9536, round is 372
# Time for blending is 360.0521, round is 373
# Time for blending is 355.8350, round is 374
# Time for blending is 357.0573, round is 375
# Time for blending is 356.2123, round is 376
# Time for blending is 363.0031, round is 377
# Time for blending is 356.8097, round is 378
# Time for blending is 364.8173, round is 379
# Time for blending is 353.3447, round is 380
# Time for blending is 369.5756, round is 381
# Time for blending is 360.2736, round is 382
# Time for blending is 368.4153, round is 383
# Time for blending is 352.2361, round is 384
# Time for blending is 358.1984, round is 385
# Time for blending is 355.6738, round is 386
# Time for blending is 359.0903, round is 387
# Time for blending is 350.5451, round is 388
# Time for blending is 350.4278, round is 389
# Time for blending is 353.0786, round is 390
# Time for blending is 350.3798, round is 391
# Time for blending is 354.3369, round is 392
# Time for blending is 366.4031, round is 393
# Time for blending is 352.6462, round is 394
# Time for blending is 355.5927, round is 395
# Time for blending is 354.0694, round is 396
# Time for blending is 354.0072, round is 397
# Time for blending is 357.8093, round is 398
# Time for blending is 355.8086, round is 399
# Time for blending is 349.6007, round is 400
# Time for blending is 360.6890, round is 401
# Time for blending is 355.6045, round is 402
# Time for blending is 349.0593, round is 403
# Time for blending is 343.7236, round is 404
# Time for blending is 360.3588, round is 405
# Time for blending is 351.6467, round is 406
# Time for blending is 357.1367, round is 407
# Time for blending is 356.0345, round is 408
# Time for blending is 357.6499, round is 409
# Time for blending is 351.7346, round is 410
# Time for blending is 358.3920, round is 411
# Time for blending is 352.5258, round is 412
# Time for blending is 350.5149, round is 413
# Time for blending is 354.7854, round is 414
# Time for blending is 353.8738, round is 415
# Time for blending is 356.0678, round is 416
# Time for blending is 367.8096, round is 417
# Time for blending is 369.3547, round is 418
# Time for blending is 367.5075, round is 419
# Time for matching is 3.6063, round is 420
# Epoch [1/40], Step [1/2], Loss: 0.2255
# Epoch [1/40], Step [2/2], Loss: 1.2688
# Epoch [2/40], Step [1/2], Loss: 0.2175
# Epoch [2/40], Step [2/2], Loss: 0.4556
# Epoch [3/40], Step [1/2], Loss: 0.6839
# Epoch [3/40], Step [2/2], Loss: 0.7014
# Epoch [4/40], Step [1/2], Loss: 0.3174
# Epoch [4/40], Step [2/2], Loss: 0.0683
# Epoch [5/40], Step [1/2], Loss: 0.3086
# Epoch [5/40], Step [2/2], Loss: 0.5640
# Epoch [6/40], Step [1/2], Loss: 0.3779
# Epoch [6/40], Step [2/2], Loss: 0.3440
# Epoch [7/40], Step [1/2], Loss: 0.1522
# Epoch [7/40], Step [2/2], Loss: 0.2916
# Epoch [8/40], Step [1/2], Loss: 0.3053
# Epoch [8/40], Step [2/2], Loss: 0.3636
# Epoch [9/40], Step [1/2], Loss: 0.2680
# Epoch [9/40], Step [2/2], Loss: 0.2694
# Epoch [10/40], Step [1/2], Loss: 0.1143
# Epoch [10/40], Step [2/2], Loss: 0.3598
# Epoch [11/40], Step [1/2], Loss: 0.2738
# Epoch [11/40], Step [2/2], Loss: 0.2642
# Epoch [12/40], Step [1/2], Loss: 0.1902
# Epoch [12/40], Step [2/2], Loss: 0.2405
# Epoch [13/40], Step [1/2], Loss: 0.0851
# Epoch [13/40], Step [2/2], Loss: 0.3719
# Epoch [14/40], Step [1/2], Loss: 0.1900
# Epoch [14/40], Step [2/2], Loss: 0.3006
# Epoch [15/40], Step [1/2], Loss: 0.1536
# Epoch [15/40], Step [2/2], Loss: 0.2648
# Epoch [16/40], Step [1/2], Loss: 0.2292
# Epoch [16/40], Step [2/2], Loss: 0.1466
# Epoch [17/40], Step [1/2], Loss: 0.1418
# Epoch [17/40], Step [2/2], Loss: 0.3254
# Epoch [18/40], Step [1/2], Loss: 0.2551
# Epoch [18/40], Step [2/2], Loss: 0.0996
# Epoch [19/40], Step [1/2], Loss: 0.1228
# Epoch [19/40], Step [2/2], Loss: 0.3147
# Epoch [20/40], Step [1/2], Loss: 0.2255
# Epoch [20/40], Step [2/2], Loss: 0.1493
# Epoch [21/40], Step [1/2], Loss: 0.1904
# Epoch [21/40], Step [2/2], Loss: 0.1794
# Epoch [22/40], Step [1/2], Loss: 0.1779
# Epoch [22/40], Step [2/2], Loss: 0.2295
# Epoch [23/40], Step [1/2], Loss: 0.1640
# Epoch [23/40], Step [2/2], Loss: 0.2361
# Epoch [24/40], Step [1/2], Loss: 0.1661
# Epoch [24/40], Step [2/2], Loss: 0.2273
# Epoch [25/40], Step [1/2], Loss: 0.1701
# Epoch [25/40], Step [2/2], Loss: 0.2282
# Epoch [26/40], Step [1/2], Loss: 0.2414
# Epoch [26/40], Step [2/2], Loss: 0.0989
# Epoch [27/40], Step [1/2], Loss: 0.2210
# Epoch [27/40], Step [2/2], Loss: 0.1388
# Epoch [28/40], Step [1/2], Loss: 0.2438
# Epoch [28/40], Step [2/2], Loss: 0.1066
# Epoch [29/40], Step [1/2], Loss: 0.1834
# Epoch [29/40], Step [2/2], Loss: 0.1940
# Epoch [30/40], Step [1/2], Loss: 0.1026
# Epoch [30/40], Step [2/2], Loss: 0.3251
# Epoch [31/40], Step [1/2], Loss: 0.1234
# Epoch [31/40], Step [2/2], Loss: 0.2874
# Epoch [32/40], Step [1/2], Loss: 0.1100
# Epoch [32/40], Step [2/2], Loss: 0.3091
# Epoch [33/40], Step [1/2], Loss: 0.2359
# Epoch [33/40], Step [2/2], Loss: 0.1101
# Epoch [34/40], Step [1/2], Loss: 0.2631
# Epoch [34/40], Step [2/2], Loss: 0.0729
# Epoch [35/40], Step [1/2], Loss: 0.1956
# Epoch [35/40], Step [2/2], Loss: 0.1726
# Epoch [36/40], Step [1/2], Loss: 0.2043
# Epoch [36/40], Step [2/2], Loss: 0.1655
# Epoch [37/40], Step [1/2], Loss: 0.2159
# Epoch [37/40], Step [2/2], Loss: 0.1473
# Epoch [38/40], Step [1/2], Loss: 0.1395
# Epoch [38/40], Step [2/2], Loss: 0.2640
# Epoch [39/40], Step [1/2], Loss: 0.1789
# Epoch [39/40], Step [2/2], Loss: 0.2008
# Epoch [40/40], Step [1/2], Loss: 0.1688
# Epoch [40/40], Step [2/2], Loss: 0.2162
#  Time for training is 297.0755 ms
# The loss of M_trained is 0.7609, round 420
# The loss of M_current is 0.7059, round 420
# Parameter containing:
# tensor([[ 1.2785e+00, -7.9508e-02, -6.8167e+01],
#         [ 1.3140e-01,  1.0445e+00, -1.3941e+02],
#         [ 6.9173e-05, -1.9100e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# Time for blending is 347.2837, round is 420
# Time for blending is 349.1919, round is 421
# Time for blending is 353.0423, round is 422
# Time for blending is 365.4904, round is 423
# Time for blending is 350.6913, round is 424
# Time for blending is 384.7481, round is 425
# Time for blending is 351.9161, round is 426
# Time for blending is 362.8605, round is 427
# Time for blending is 357.3090, round is 428
# Time for blending is 354.9068, round is 429
# Time for blending is 352.5229, round is 430
# Time for blending is 356.0060, round is 431
# Time for blending is 348.9612, round is 432
# Time for blending is 353.6928, round is 433
# Time for blending is 347.8603, round is 434
# Time for blending is 352.0141, round is 435
# Time for blending is 365.6496, round is 436
# Time for blending is 362.4947, round is 437
# Time for blending is 360.9427, round is 438
# Time for blending is 358.7888, round is 439
# Time for blending is 361.7369, round is 440
# Time for blending is 355.4216, round is 441
# Time for blending is 352.2557, round is 442
# Time for blending is 350.4992, round is 443
# Time for blending is 363.7354, round is 444
# Time for blending is 356.3346, round is 445
# Time for blending is 360.2776, round is 446
# Time for blending is 352.6142, round is 447
# Time for blending is 369.8967, round is 448
# Time for blending is 369.1280, round is 449
# Time for blending is 363.6293, round is 450
# Time for blending is 369.6448, round is 451
# Time for blending is 365.3897, round is 452
# Time for blending is 357.8009, round is 453
# Time for blending is 359.2079, round is 454
# Time for blending is 361.3517, round is 455
# Time for blending is 355.9751, round is 456
# Time for blending is 353.8251, round is 457
# Time for blending is 356.4700, round is 458
# Time for blending is 364.5652, round is 459
# Time for blending is 350.4946, round is 460
# Time for blending is 352.2552, round is 461
# Time for blending is 352.5732, round is 462
# Time for blending is 351.5236, round is 463
# Time for blending is 351.0176, round is 464
# Time for blending is 347.9183, round is 465
# Time for blending is 358.4973, round is 466
# Time for blending is 353.6167, round is 467
# Time for blending is 347.5613, round is 468
# Time for blending is 344.1681, round is 469
# Time for blending is 349.8926, round is 470
# Time for blending is 351.3549, round is 471
# Time for blending is 366.6470, round is 472
# Time for blending is 348.3318, round is 473
# Time for blending is 357.2836, round is 474
# Time for blending is 358.9092, round is 475
# Time for blending is 351.0870, round is 476
# Time for blending is 374.6337, round is 477
# Time for blending is 371.8445, round is 478
# Time for blending is 374.5845, round is 479
# Time for matching is 3.5821, round is 480
# Epoch [1/40], Step [1/2], Loss: 0.1989
# Epoch [1/40], Step [2/2], Loss: 1.3920
# Epoch [2/40], Step [1/2], Loss: 0.1869
# Epoch [2/40], Step [2/2], Loss: 0.4592
# Epoch [3/40], Step [1/2], Loss: 0.7588
# Epoch [3/40], Step [2/2], Loss: 0.6511
# Epoch [4/40], Step [1/2], Loss: 0.2261
# Epoch [4/40], Step [2/2], Loss: 0.2022
# Epoch [5/40], Step [1/2], Loss: 0.2786
# Epoch [5/40], Step [2/2], Loss: 0.4775
# Epoch [6/40], Step [1/2], Loss: 0.3696
# Epoch [6/40], Step [2/2], Loss: 0.3423
# Epoch [7/40], Step [1/2], Loss: 0.1250
# Epoch [7/40], Step [2/2], Loss: 0.2298
# Epoch [8/40], Step [1/2], Loss: 0.2428
# Epoch [8/40], Step [2/2], Loss: 0.4043
# Epoch [9/40], Step [1/2], Loss: 0.2665
# Epoch [9/40], Step [2/2], Loss: 0.2239
# Epoch [10/40], Step [1/2], Loss: 0.1821
# Epoch [10/40], Step [2/2], Loss: 0.1486
# Epoch [11/40], Step [1/2], Loss: 0.1401
# Epoch [11/40], Step [2/2], Loss: 0.3744
# Epoch [12/40], Step [1/2], Loss: 0.1640
# Epoch [12/40], Step [2/2], Loss: 0.2209
# Epoch [13/40], Step [1/2], Loss: 0.1243
# Parameter containing:
# tensor([[ 1.2785e+00, -7.9510e-02, -6.8167e+01],
#         [ 1.3140e-01,  1.0445e+00, -1.3941e+02],
#         [ 6.9297e-05, -1.9256e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 0.3113
# Time for blending is 1097.8522, round is 480
# Time for blending is 351.1703, round is 481
# Time for blending is 386.8763, round is 482
# Time for blending is 361.9956, round is 483
# Time for blending is 352.0872, round is 484
# Time for blending is 354.2123, round is 485
# Time for blending is 365.1518, round is 486
# Time for blending is 354.3342, round is 487
# Time for blending is 355.6857, round is 488
# Time for blending is 352.5241, round is 489
# Time for blending is 350.9485, round is 490
# Time for blending is 353.1789, round is 491
# Time for blending is 355.9398, round is 492
# Time for blending is 353.4369, round is 493
# Time for blending is 350.6830, round is 494
# Time for blending is 362.7658, round is 495
# Time for blending is 359.9214, round is 496
# Time for blending is 359.0303, round is 497
# Time for blending is 352.0978, round is 498
# Time for blending is 348.7088, round is 499
# Time for blending is 348.7509, round is 500
# Time for blending is 356.0818, round is 501
# Time for blending is 359.3710, round is 502
# Time for blending is 351.9678, round is 503
# Time for blending is 356.5227, round is 504
# Time for blending is 357.9767, round is 505
# Time for blending is 352.0559, round is 506
# Time for blending is 359.9965, round is 507
# Time for blending is 351.1103, round is 508
# Time for blending is 361.5651, round is 509
# Time for blending is 357.1355, round is 510
# Time for blending is 357.2509, round is 511
# Time for blending is 365.8366, round is 512
# Time for blending is 355.7848, round is 513
# Time for blending is 365.3091, round is 514
# Time for blending is 365.9226, round is 515
# Time for blending is 362.0478, round is 516
# Time for blending is 373.4036, round is 517
# Time for blending is 371.9579, round is 518
# Time for blending is 371.4518, round is 519
# Time for blending is 361.4056, round is 520
# Time for blending is 360.6227, round is 521
# Time for blending is 347.6714, round is 522
# Time for blending is 351.5532, round is 523
# Time for blending is 382.5447, round is 524
# Time for blending is 356.0227, round is 525
# Time for blending is 375.7836, round is 526
# Time for blending is 352.1705, round is 527
# Time for blending is 356.4446, round is 528
# Time for blending is 375.6604, round is 529
# Time for blending is 350.5439, round is 530
# Time for blending is 377.9872, round is 531
# Time for blending is 350.9644, round is 532
# Time for blending is 348.8188, round is 533
# Time for blending is 350.6868, round is 534
# Time for blending is 356.9715, round is 535
# Time for blending is 352.3243, round is 536
# Time for blending is 353.0014, round is 537
# Time for blending is 348.9266, round is 538
# Time for blending is 353.2227, round is 539
# Time for matching is 3.6753, round is 540
# Epoch [1/40], Step [1/2], Loss: 1.0124
# Epoch [1/40], Step [2/2], Loss: 1.5429
# Epoch [2/40], Step [1/2], Loss: 1.0295
# Epoch [2/40], Step [2/2], Loss: 0.5397
# Epoch [3/40], Step [1/2], Loss: 1.4752
# Epoch [3/40], Step [2/2], Loss: 0.6374
# Epoch [4/40], Step [1/2], Loss: 0.6098
# Epoch [4/40], Step [2/2], Loss: 1.0715
# Epoch [5/40], Step [1/2], Loss: 0.9001
# Epoch [5/40], Step [2/2], Loss: 1.1504
# Epoch [6/40], Step [1/2], Loss: 0.7140
# Epoch [6/40], Step [2/2], Loss: 1.1485
# Epoch [7/40], Step [1/2], Loss: 0.6167
# Epoch [36/40], Step [1/2], Loss: 0.6344
# Epoch [36/40], Step [2/2], Loss: 0.9528
# Epoch [37/40], Step [1/2], Loss: 0.7280
# Epoch [37/40], Step [2/2], Loss: 0.7918
# Epoch [38/40], Step [1/2], Loss: 0.5518
# Epoch [38/40], Step [2/2], Loss: 1.0979
# Epoch [39/40], Step [1/2], Loss: 0.6834
# Epoch [39/40], Step [2/2], Loss: 0.8548
# Epoch [40/40], Step [1/2], Loss: 0.9075
# Epoch [40/40], Step [2/2], Loss: 0.4548
#  Time for training is 293.6153 ms
# The loss of M_trained is 2.0854, round 540
# The loss of M_current is 2.1713, round 540
# Parameter containing:
# tensor([[ 1.2785e+00, -7.9520e-02, -6.8167e+01],
#         [ 1.3136e-01,  1.0444e+00, -1.3941e+02],
#         [ 6.8992e-05, -1.8938e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# The best loss is 2.0854
# Time for blending is 350.3407, round is 540
# Time for blending is 349.6344, round is 541
# Time for blending is 357.0574, round is 542
# Time for blending is 364.0398, round is 543
# Time for blending is 367.9811, round is 544
# Time for blending is 365.7015, round is 545
# Time for blending is 370.0983, round is 546
# Time for blending is 364.5252, round is 547
# Time for blending is 360.7638, round is 548
# Time for blending is 357.6889, round is 549
# Time for blending is 368.3733, round is 550
# Time for blending is 355.9490, round is 551
# Time for blending is 360.0546, round is 552
# Time for blending is 358.2133, round is 553
# Time for blending is 359.6377, round is 554
# Time for blending is 359.7437, round is 555
# Time for blending is 352.9512, round is 556
# Time for blending is 355.4774, round is 557
# Time for blending is 350.0952, round is 558
# Time for blending is 353.6488, round is 559
# Time for blending is 361.5457, round is 560
# Time for blending is 349.7070, round is 561
# Time for blending is 348.1540, round is 562
# Time for blending is 352.8001, round is 563
# Time for blending is 350.4278, round is 564
# Time for blending is 349.0161, round is 565
# Time for blending is 356.7844, round is 566
# Time for blending is 353.4642, round is 567
# Time for blending is 353.6113, round is 568
# Time for blending is 352.7969, round is 569
# Time for blending is 354.8767, round is 570
# Time for blending is 360.4871, round is 571
# Time for blending is 359.1863, round is 572
# Time for blending is 358.2706, round is 573
# Time for blending is 360.9570, round is 574
# Time for blending is 358.5391, round is 575
# Time for blending is 357.3589, round is 576
# Time for blending is 355.6918, round is 577
# Time for blending is 359.2123, round is 578
# Time for blending is 361.4877, round is 579
# Time for blending is 369.4825, round is 580
# Time for blending is 351.0079, round is 581
# Time for blending is 355.6852, round is 582
# Time for blending is 367.8609, round is 583
# Time for blending is 360.0340, round is 584
# Time for blending is 359.0526, round is 585
# Time for blending is 351.9118, round is 586
# Time for blending is 360.0314, round is 587
# Time for blending is 369.1979, round is 588
# Time for blending is 362.9903, round is 589
# Time for blending is 346.0413, round is 590
# Time for blending is 357.3474, round is 591
# Time for blending is 354.4773, round is 592
# Time for blending is 361.9897, round is 593
# Time for blending is 358.6429, round is 594
# Time for blending is 360.0823, round is 595
# Time for blending is 352.9184, round is 596
# Time for blending is 356.5966, round is 597
# Time for blending is 352.4821, round is 598
# Time for blending is 357.9867, round is 599
# Time for matching is 3.5161, round is 600
# Epoch [1/40], Step [1/2], Loss: 0.2759
# Epoch [1/40], Step [2/2], Loss: 2.9621
# Epoch [30/40], Step [2/2], Loss: 0.4073
# Epoch [31/40], Step [1/2], Loss: 0.6190
# Epoch [31/40], Step [2/2], Loss: 1.0088
# Epoch [32/40], Step [1/2], Loss: 0.6124
# Epoch [32/40], Step [2/2], Loss: 1.0189
# Epoch [33/40], Step [1/2], Loss: 0.5653
# Epoch [33/40], Step [2/2], Loss: 1.1118
# Epoch [34/40], Step [1/2], Loss: 0.5483
# Epoch [34/40], Step [2/2], Loss: 1.1569
# Epoch [35/40], Step [1/2], Loss: 0.6241
# Epoch [35/40], Step [2/2], Loss: 1.0129
# Epoch [36/40], Step [1/2], Loss: 0.8991
# Epoch [36/40], Step [2/2], Loss: 0.4031
# Epoch [37/40], Step [1/2], Loss: 0.9321
# Epoch [37/40], Step [2/2], Loss: 0.3433
# Epoch [38/40], Step [1/2], Loss: 0.2908
# Epoch [38/40], Step [2/2], Loss: 1.7109
# Epoch [39/40], Step [1/2], Loss: 0.2641
# Epoch [39/40], Step [2/2], Loss: 1.7578
# Epoch [40/40], Step [1/2], Loss: 0.9007
# Epoch [40/40], Step [2/2], Loss: 0.4106
#  Time for training is 393.6307 ms
# The loss of M_trained is 2.4951, round 600
# The loss of M_current is 2.4782, round 600
# Parameter containing:
# tensor([[ 1.2785e+00, -7.9533e-02, -6.8167e+01],
#         [ 1.3132e-01,  1.0444e+00, -1.3941e+02],
#         [ 6.8806e-05, -1.8708e-05,  1.0000e+00]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)
# Time for blending is 1092.3165, round is 600
# Time for blending is 352.9447, round is 601
# Time for blending is 359.9576, round is 602
# Time for blending is 355.0076, round is 603
# Time for blending is 355.4733, round is 604
# Time for blending is 354.6398, round is 605
# Time for blending is 364.7797, round is 606
# Time for blending is 352.0855, round is 607
# Time for blending is 362.8363, round is 608
# Time for blending is 359.3116, round is 609
# Time for blending is 356.7473, round is 610
# Time for blending is 362.9145, round is 611
# Time for blending is 373.9967, round is 612
# Time for blending is 366.2009, round is 613
# Time for blending is 367.3946, round is 614
# Time for blending is 366.7153, round is 615
# Time for blending is 356.2075, round is 616
# Time for blending is 367.1115, round is 617
# Time for blending is 359.6675, round is 618
# Time for blending is 345.8091, round is 619
# Time for blending is 353.9046, round is 620
# Time for blending is 347.2478, round is 621
# Time for blending is 358.8181, round is 622
# Time for blending is 353.8765, round is 623
# Time for blending is 402.7152, round is 624
# Time for blending is 353.0419, round is 625
# Time for blending is 376.6976, round is 626
# Time for blending is 356.2586, round is 627
# Time for blending is 354.4789, round is 628
# Time for blending is 353.2736, round is 629
# Time for blending is 347.4336, round is 630
# Time for blending is 350.5962, round is 631
# Time for blending is 352.4815, round is 632
# Time for blending is 362.3878, round is 633
# Time for blending is 364.8379, round is 634
# Time for blending is 359.9548, round is 635
# Time for blending is 354.9523, round is 636

# %%
cv2.useOptimized()
# Out:
# True

# %%
e1 = cv2.getTickCount()
for i in range(10):
    i=i+1
e2 = cv2.getTickCount()
print((e2 - e1)/cv2.getTickFrequency()*1000)
# Out:
# 0.0361
